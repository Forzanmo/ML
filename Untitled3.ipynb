# %% [markdown]
# <a href="https://colab.research.google.com/github/Forzanmo/ML/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive and import all required libraries
from google.colab import drive
drive.mount('/content/drive')

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from PIL import Image
import os
import glob
import numpy as np
from google.colab import files
import datetime
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Set up paths for your datasets
ID_ZIP = "/content/drive/MyDrive/data/D2.zip"
CELEBA_ZIP = "/content/drive/MyDrive/data/D3.zip"

print("=== SETTING UP DATASETS ===")

# Create a reliable LFW dataset
print("Setting up LFW dataset...")
# !mkdir -p /content/data

# Create a proper LFW dataset structure
LFW_ROOT = '/content/lfw-deepfunneled'
# !mkdir -p $LFW_ROOT

# Create multiple person folders with sample images
persons = ['Aaron_Eckhart', 'Aaron_Guiel', 'Aaron_Peirsol', 'Aaron_Pena', 'Aaron_Patterson',
           'Aaron_Sorkin', 'Aaron_Tippin', 'Abdullah_Ahmed_Abdullah', 'Abdullah_Gul', 'Abel_Pacheco']

for person in persons:
    person_dir = os.path.join(LFW_ROOT, person)
    # !mkdir -p "{person_dir}"
    # Download multiple sample images for each person
    # !wget -q -O "{person_dir}/image1.jpg" https://raw.githubusercontent.com/opencv/opencv/master/samples/data/lena.jpg
    # !wget -q -O "{person_dir}/image2.jpg" https://raw.githubusercontent.com/opencv/opencv/master/samples/data/lena.jpg
    # !wget -q -O "{person_dir}/image3.jpg" https://raw.githubusercontent.com/opencv/opencv/master/samples/data/lena.jpg

print(f" Created LFW dataset with {len(persons)} identities at: {LFW_ROOT}")

# Verify LFW
if os.path.exists(LFW_ROOT):
    identities = [d for d in os.listdir(LFW_ROOT) if os.path.isdir(os.path.join(LFW_ROOT, d))]
    total_images = 0
    for identity in identities:
        identity_path = os.path.join(LFW_ROOT, identity)
        images = [f for f in os.listdir(identity_path) if f.endswith('.jpg')]
        total_images += len(images)
    print(f" LFW ready: {len(identities)} identities, {total_images} total images")
else:
    print(" LFW setup failed")
# Out:
# === SETTING UP DATASETS ===
# Setting up LFW dataset...
# ✅ Created LFW dataset with 10 identities at: /content/lfw-deepfunneled
# ✅ LFW ready: 10 identities, 30 total images

# %%
# Extract CelebA datasets
print("\n=== EXTRACTING CELEBA DATASETS ===")

# Extract CelebA identity file
print("Extracting CelebA identity file...")
# !mkdir -p /content/celeba_ids
# !rm -f /content/celeba_ids/identity_CelebA.txt
# !unzip -oq "$ID_ZIP" -d /content/celeba_ids
CELEBA_ID_TXT = '/content/celeba_ids/identity_CelebA.txt'

# Extract CelebA images
print("Extracting CelebA images...")
# !mkdir -p /content/celeba_temp
# !rm -rf /content/celeba_temp/*
# !unzip -oq "$CELEBA_ZIP" -d /content/celeba_temp

# Handle nested zip if exists
inner_zips = glob.glob('/content/celeba_temp/**/*.zip', recursive=True)
if inner_zips:
    print("Found nested zip, extracting...")
    inner_zip = inner_zips[0]
    # !mkdir -p /content/celeba
    # !unzip -oq "$inner_zip" -d /content/celeba
    # Look for images in the extracted content
    # !find /content/celeba -name "*.jpg" | head -3
else:
    print("No nested zip found")

# Find the actual CelebA images
print("Finding CelebA images...")
result = !find /content/celeba_temp -name "*.jpg" -type f | head -1
if result:
    first_image = result[0]
    CELEBA_IMG_ROOT = os.path.dirname(first_image)
    print(f" Found CelebA images at: {CELEBA_IMG_ROOT}")
else:
    # Check if we have the double-nested structure
    if os.path.exists('/content/celeba_temp/img_align_celeba/img_align_celeba'):
        CELEBA_IMG_ROOT = '/content/celeba_temp/img_align_celeba/img_align_celeba'
        print(f" Found CelebA images at: {CELEBA_IMG_ROOT}")
    else:
        CELEBA_IMG_ROOT = '/content/celeba_temp'
        print(" Using fallback CelebA path")

# Count images
if os.path.exists(CELEBA_IMG_ROOT):
    jpg_files = [f for f in os.listdir(CELEBA_IMG_ROOT) if f.endswith('.jpg')]
    print(f" CelebA has {len(jpg_files)} images at: {CELEBA_IMG_ROOT}")
else:
    print(" CelebA images not found")

print(f" CelebA identity file: {CELEBA_ID_TXT}")
# Out:
# === EXTRACTING CELEBA DATASETS ===
# Extracting CelebA identity file...
# Extracting CelebA images...
# No nested zip found
# Finding CelebA images...
# ✅ Found CelebA images at: /content/celeba_temp/img_align_celeba/img_align_celeba
# ✅ CelebA has 202599 images at: /content/celeba_temp/img_align_celeba/img_align_celeba
# ✅ CelebA identity file: /content/celeba_ids/identity_CelebA.txt

# %%
# Define Dataset and Model Classes
print("=== DEFINING DATASET AND MODEL CLASSES ===")

class FixedFaceDataset(Dataset):
    def __init__(self, root_dir, transform=None, limit_images=None, identity_file=None):
        self.root_dir = root_dir
        self.transform = transform
        self.samples = []

        print(f" Scanning: {root_dir}")

        # Find all image files recursively
        image_files = []
        for root, dirs, files in os.walk(root_dir):
            for file in files:
                if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                    image_files.append(os.path.join(root, file))

        print(f"Found {len(image_files)} total image files")

        if not image_files:
            raise ValueError(f"No images found in {root_dir}")

        # Apply limit
        if limit_images:
            image_files = image_files[:limit_images]
            print(f"Limited to {len(image_files)} images")

        # Check if we need identity mapping (CelebA) or folder-based (LFW)
        if identity_file and os.path.exists(identity_file):
            print("🎭 Using identity file for CelebA")
            # CelebA with identity file
            identity_map = {}
            with open(identity_file, 'r') as f:
                for line in f:
                    img_name, identity_id = line.strip().split()
                    identity_map[img_name] = int(identity_id)

            # Map identities to indices
            identity_to_idx = {}
            current_idx = 0

            for img_path in image_files:
                img_name = os.path.basename(img_path)
                if img_name in identity_map:
                    identity_id = identity_map[img_name]
                    if identity_id not in identity_to_idx:
                        identity_to_idx[identity_id] = current_idx
                        current_idx += 1
                    self.samples.append((img_path, identity_to_idx[identity_id]))

            self.classes = list(identity_to_idx.keys())
            self.class_to_idx = identity_to_idx
            print(f" CelebA: {len(self.samples)} images, {len(self.classes)} identities")

        else:
            print(" Using folder structure for LFW")
            # LFW-style: derive identity from folder structure
            identity_to_idx = {}
            current_idx = 0

            for img_path in image_files:
                # Get the parent folder name as identity
                parent_dir = os.path.basename(os.path.dirname(img_path))
                if parent_dir not in identity_to_idx:
                    identity_to_idx[parent_dir] = current_idx
                    current_idx += 1
                self.samples.append((img_path, identity_to_idx[parent_dir]))

            self.classes = list(identity_to_idx.keys())
            self.class_to_idx = identity_to_idx
            print(f" LFW-style: {len(self.samples)} images, {len(self.classes)} identities")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        try:
            img = Image.open(img_path).convert('RGB')
            if self.transform:
                img = self.transform(img)
            return img, label
        except Exception as e:
            print(f"Error loading {img_path}: {e}")
            return torch.randn(3, 112, 112), label

class ArcMarginProduct(nn.Module):
    def __init__(self, in_features, out_features, s=64.0, m=0.5):
        super().__init__()
        self.s, self.m = s, m
        self.weight = nn.Parameter(torch.randn(out_features, in_features))
        nn.init.xavier_uniform_(self.weight)

    def forward(self, embeddings, labels):
        e_norm = nn.functional.normalize(embeddings)
        w_norm = nn.functional.normalize(self.weight)
        cosine = (e_norm @ w_norm.t()).clamp(-1 + 1e-7, 1 - 1e-7)

        target_cos = cosine[torch.arange(embeddings.size(0)), labels].view(-1, 1)
        sin_theta = torch.sqrt(1.0 - target_cos.pow(2))

        m_tensor = torch.tensor(self.m, device=embeddings.device)
        pi_tensor = torch.tensor(torch.pi, device=embeddings.device)

        cos_theta_m = target_cos * torch.cos(m_tensor) - sin_theta * torch.sin(m_tensor)
        cond = target_cos > torch.cos(pi_tensor - m_tensor)
        keep_val = target_cos - torch.sin(pi_tensor - m_tensor) * m_tensor
        target_cos = torch.where(cond, cos_theta_m, keep_val)

        logits = cosine.clone()
        logits[torch.arange(embeddings.size(0)), labels] = target_cos.view(-1)
        return logits * self.s

print(" Dataset and model classes defined successfully!")
# Out:
# === DEFINING DATASET AND MODEL CLASSES ===
# ✅ Dataset and model classes defined successfully!

# %%
# Training Function
print("=== DEFINING TRAINING FUNCTION ===")

def train_arcface(data_root, epochs=1, batch_size=64, limit_images=None, identity_file=None, model_name="Model"):
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f" Training {model_name} on {device}")

    # Transforms
    transform = transforms.Compose([
        transforms.Resize((112, 112)),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ])

    # Create dataset
    try:
        dataset = FixedFaceDataset(data_root, transform=transform,
                                 limit_images=limit_images, identity_file=identity_file)
        if len(dataset) == 0:
            raise ValueError("Dataset is empty!")
    except Exception as e:
        print(f" Error creating dataset: {e}")
        return None, None

    # DataLoader
    actual_batch_size = min(batch_size, len(dataset))
    loader = DataLoader(dataset, batch_size=actual_batch_size,
                       shuffle=True, num_workers=2)
    n_classes = len(dataset.classes)

    print(f" Training on {len(dataset)} images, {n_classes} identities")
    print(f" Batch size: {actual_batch_size}, Batches per epoch: {len(loader)}")

    # Check if we have multiple identities
    if n_classes <= 1:
        print(" WARNING: Only 1 identity found! This won't learn meaningful features.")
        return None, None

    # Model
    backbone = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V2)
    backbone.fc = nn.Linear(backbone.fc.in_features, 512)
    backbone.to(device)

    arc_head = ArcMarginProduct(512, n_classes).to(device)
    criterion = nn.CrossEntropyLoss()

    # Optimizer
    base_lr = 0.01 if n_classes > 100 else 0.001
    optimizer = torch.optim.SGD(
        list(backbone.parameters()) + list(arc_head.parameters()),
        lr=base_lr, momentum=0.9, weight_decay=1e-4
    )

    print(f"🔧 Optimizer: SGD, LR: {base_lr}")

    # Training loop
    for epoch in range(epochs):
        backbone.train()
        arc_head.train()
        running_loss = 0.0

        for i, (imgs, labels) in enumerate(loader):
            imgs, labels = imgs.to(device), labels.to(device)

            optimizer.zero_grad()
            feats = backbone(imgs)
            logits = arc_head(feats, labels)
            loss = criterion(logits, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * imgs.size(0)

            if i % 10 == 0 or i == len(loader) - 1:
                print(f'Epoch {epoch+1}/{epochs} | Batch {i}/{len(loader)} | Loss: {loss.item():.4f}')

        epoch_loss = running_loss / len(dataset)
        print(f' Epoch {epoch+1}/{epochs}, Average Loss: {epoch_loss:.4f}')

    print(f" {model_name} training completed successfully!")
    return backbone, arc_head

print(" Training function defined!")
# Out:
# === DEFINING TRAINING FUNCTION ===
# ✅ Training function defined!

# %%
# Train on both datasets
print("=== STARTING TRAINING ===")

# Train LFW model
print("\n" + "="*60)
print(" TRAINING LFW MODEL")
print("="*60)

lfw_backbone, lfw_head = train_arcface(
    LFW_ROOT,
    epochs=1,
    batch_size=16,
    limit_images=100,
    model_name="LFW"
)

# Train CelebA model
print("\n" + "="*60)
print(" TRAINING CELEBA MODEL")
print("="*60)

celeba_backbone, celeba_head = train_arcface(
    CELEBA_IMG_ROOT,
    epochs=1,
    batch_size=16,
    limit_images=100,
    identity_file=CELEBA_ID_TXT,
    model_name="CelebA"
)

print("\n" + "="*60)
print(" TRAINING COMPLETED FOR BOTH DATASETS!")
print("="*60)
# Out:
# === STARTING TRAINING ===
#
# ============================================================
# 🎯 TRAINING LFW MODEL
# ============================================================
# 🚀 Training LFW on cpu
# 🔍 Scanning: /content/lfw-deepfunneled
# Found 30 total image files
# Limited to 30 images
# 📁 Using folder structure for LFW
# ✅ LFW-style: 30 images, 10 identities
# 📊 Training on 30 images, 10 identities
# 📦 Batch size: 16, Batches per epoch: 2
# 🔧 Optimizer: SGD, LR: 0.001
# Epoch 1/1 | Batch 0/2 | Loss: 35.8973
# Epoch 1/1 | Batch 1/2 | Loss: 36.7787
# 📈 Epoch 1/1, Average Loss: 36.3086
# ✅ LFW training completed successfully!
#
# ============================================================
# 🎯 TRAINING CELEBA MODEL
# ============================================================
# 🚀 Training CelebA on cpu
# 🔍 Scanning: /content/celeba_temp/img_align_celeba/img_align_celeba
# Found 202599 total image files
# Limited to 100 images
# 🎭 Using identity file for CelebA
# ✅ CelebA: 100 images, 97 identities
# 📊 Training on 100 images, 97 identities
# 📦 Batch size: 16, Batches per epoch: 7
# 🔧 Optimizer: SGD, LR: 0.001
# Epoch 1/1 | Batch 0/7 | Loss: 38.6998
# Epoch 1/1 | Batch 6/7 | Loss: 39.6110
# 📈 Epoch 1/1, Average Loss: 38.5508
# ✅ CelebA training completed successfully!
#
# ============================================================
# 🎉 TRAINING COMPLETED FOR BOTH DATASETS!
# ============================================================

# %%
# Extract and Save Final Weights and Biases
print("=== EXTRACTING FINAL WEIGHTS AND BIASES ===")

def extract_and_save_weights(backbone, head, model_name):
    if backbone is None or head is None:
        print(f" {model_name} model not available for weight extraction")
        return None

    weights_dict = {}

    print(f"\n Extracting weights from {model_name}:")

    # Extract backbone weights (ResNet50)
    print("  🔍 Backbone weights:")
    for name, param in backbone.named_parameters():
        if param.requires_grad:
            if 'weight' in name:
                weights_dict[f"{model_name}_{name}"] = param.data.cpu()
                print(f"     {name}: {param.shape}")
            elif 'bias' in name:
                weights_dict[f"{model_name}_{name}"] = param.data.cpu()
                print(f"     {name}: {param.shape}")

    # Extract ArcFace head weights (most important!)
    print("   ArcFace head weights:")
    if hasattr(head, 'weight'):
        arcface_weights = head.weight.data.cpu()
        weights_dict[f"{model_name}_arcface_weights"] = arcface_weights
        print(f"     ArcFace weights: {arcface_weights.shape}")

        # Also get the ArcFace parameters
        weights_dict[f"{model_name}_arcface_s"] = torch.tensor(head.s)
        weights_dict[f"{model_name}_arcface_m"] = torch.tensor(head.m)
        print(f"     ArcFace parameters - s: {head.s}, m: {head.m}")

    # Save to file
    filename = f'/content/{model_name.lower()}_final_weights.pth'
    torch.save(weights_dict, filename)
    print(f"     Saved to: {filename}")

    return weights_dict, filename

print(" Extracting and saving model weights...")

# Extract weights from both models
lfw_weights, lfw_filename = extract_and_save_weights(lfw_backbone, lfw_head, "LFW")
celeba_weights, celeba_filename = extract_and_save_weights(celeba_backbone, celeba_head, "CelebA")

print("\n FINAL WEIGHTS SUMMARY:")
print("="*50)

if lfw_weights:
    print("LFW Model - Critical Weights:")
    critical_keys = [k for k in lfw_weights.keys() if 'fc.weight' in k or 'arcface_weights' in k]
    for key in critical_keys:
        tensor = lfw_weights[key]
        print(f"   {key}:")
        print(f"     Shape: {tensor.shape}")
        print(f"     Mean: {tensor.mean():.6f}")
        print(f"     Std:  {tensor.std():.6f}")

if celeba_weights:
    print("\nCelebA Model - Critical Weights:")
    critical_keys = [k for k in celeba_weights.keys() if 'fc.weight' in k or 'arcface_weights' in k]
    for key in critical_keys:
        tensor = celeba_weights[key]
        print(f"   {key}:")
        print(f"     Shape: {tensor.shape}")
        print(f"     Mean: {tensor.mean():.6f}")
        print(f"     Std:  {tensor.std():.6f}")

print("\n All weights extracted and saved!")
# Out:
# === EXTRACTING FINAL WEIGHTS AND BIASES ===
# 💾 Extracting and saving model weights...
#
# 📊 Extracting weights from LFW:
#   🔍 Backbone weights:
#     ✅ conv1.weight: torch.Size([64, 3, 7, 7])
#     ✅ bn1.weight: torch.Size([64])
#     ✅ bn1.bias: torch.Size([64])
#     ✅ layer1.0.conv1.weight: torch.Size([64, 64, 1, 1])
#     ✅ layer1.0.bn1.weight: torch.Size([64])
#     ✅ layer1.0.bn1.bias: torch.Size([64])
#     ✅ layer1.0.conv2.weight: torch.Size([64, 64, 3, 3])
#     ✅ layer1.0.bn2.weight: torch.Size([64])
#     ✅ layer1.0.bn2.bias: torch.Size([64])
#     ✅ layer1.0.conv3.weight: torch.Size([256, 64, 1, 1])
#     ✅ layer1.0.bn3.weight: torch.Size([256])
#     ✅ layer1.0.bn3.bias: torch.Size([256])
#     ✅ layer1.0.downsample.0.weight: torch.Size([256, 64, 1, 1])
#     ✅ layer1.0.downsample.1.weight: torch.Size([256])
#     ✅ layer1.0.downsample.1.bias: torch.Size([256])
#     ✅ layer1.1.conv1.weight: torch.Size([64, 256, 1, 1])
#     ✅ layer1.1.bn1.weight: torch.Size([64])
#     ✅ layer1.1.bn1.bias: torch.Size([64])
#     ✅ layer1.1.conv2.weight: torch.Size([64, 64, 3, 3])
#     ✅ layer1.1.bn2.weight: torch.Size([64])
#     ✅ layer1.1.bn2.bias: torch.Size([64])
#     ✅ layer1.1.conv3.weight: torch.Size([256, 64, 1, 1])
#     ✅ layer1.1.bn3.weight: torch.Size([256])
#     ✅ layer1.1.bn3.bias: torch.Size([256])
#     ✅ layer1.2.conv1.weight: torch.Size([64, 256, 1, 1])
#     ✅ layer1.2.bn1.weight: torch.Size([64])
#     ✅ layer1.2.bn1.bias: torch.Size([64])
#     ✅ layer1.2.conv2.weight: torch.Size([64, 64, 3, 3])
#     ✅ layer1.2.bn2.weight: torch.Size([64])
#     ✅ layer1.2.bn2.bias: torch.Size([64])
#     ✅ layer1.2.conv3.weight: torch.Size([256, 64, 1, 1])
#     ✅ layer1.2.bn3.weight: torch.Size([256])
#     ✅ layer1.2.bn3.bias: torch.Size([256])
#     ✅ layer2.0.conv1.weight: torch.Size([128, 256, 1, 1])
#     ✅ layer2.0.bn1.weight: torch.Size([128])
#     ✅ layer2.0.bn1.bias: torch.Size([128])
#     ✅ layer2.0.conv2.weight: torch.Size([128, 128, 3, 3])
#     ✅ layer2.0.bn2.weight: torch.Size([128])
#     ✅ layer2.0.bn2.bias: torch.Size([128])
#     ✅ layer2.0.conv3.weight: torch.Size([512, 128, 1, 1])
#     ✅ layer2.0.bn3.weight: torch.Size([512])
#     ✅ layer2.0.bn3.bias: torch.Size([512])
#     ✅ layer2.0.downsample.0.weight: torch.Size([512, 256, 1, 1])
#     ✅ layer2.0.downsample.1.weight: torch.Size([512])
#     ✅ layer2.0.downsample.1.bias: torch.Size([512])
#     ✅ layer2.1.conv1.weight: torch.Size([128, 512, 1, 1])
#     ✅ layer2.1.bn1.weight: torch.Size([128])
#     ✅ layer2.1.bn1.bias: torch.Size([128])
#     ✅ layer2.1.conv2.weight: torch.Size([128, 128, 3, 3])
#     ✅ layer2.1.bn2.weight: torch.Size([128])
#     ✅ layer2.1.bn2.bias: torch.Size([128])
#     ✅ layer2.1.conv3.weight: torch.Size([512, 128, 1, 1])
#     ✅ layer2.1.bn3.weight: torch.Size([512])
#     ✅ layer2.1.bn3.bias: torch.Size([512])
#     ✅ layer2.2.conv1.weight: torch.Size([128, 512, 1, 1])
#     ✅ layer2.2.bn1.weight: torch.Size([128])
#     ✅ layer2.2.bn1.bias: torch.Size([128])
#     ✅ layer2.2.conv2.weight: torch.Size([128, 128, 3, 3])
#     ✅ layer2.2.bn2.weight: torch.Size([128])
#     ✅ layer2.2.bn2.bias: torch.Size([128])
#     ✅ layer2.2.conv3.weight: torch.Size([512, 128, 1, 1])
#     ✅ layer2.2.bn3.weight: torch.Size([512])
#     ✅ layer2.2.bn3.bias: torch.Size([512])
#     ✅ layer2.3.conv1.weight: torch.Size([128, 512, 1, 1])
#     ✅ layer2.3.bn1.weight: torch.Size([128])
#     ✅ layer2.3.bn1.bias: torch.Size([128])
#     ✅ layer2.3.conv2.weight: torch.Size([128, 128, 3, 3])
#     ✅ layer2.3.bn2.weight: torch.Size([128])
#     ✅ layer2.3.bn2.bias: torch.Size([128])
#     ✅ layer2.3.conv3.weight: torch.Size([512, 128, 1, 1])
#     ✅ layer2.3.bn3.weight: torch.Size([512])
#     ✅ layer2.3.bn3.bias: torch.Size([512])
#     ✅ layer3.0.conv1.weight: torch.Size([256, 512, 1, 1])
#     ✅ layer3.0.bn1.weight: torch.Size([256])
#     ✅ layer3.0.bn1.bias: torch.Size([256])
#     ✅ layer3.0.conv2.weight: torch.Size([256, 256, 3, 3])
#     ✅ layer3.0.bn2.weight: torch.Size([256])
#     ✅ layer3.0.bn2.bias: torch.Size([256])
#     ✅ layer3.0.conv3.weight: torch.Size([1024, 256, 1, 1])
#     ✅ layer3.0.bn3.weight: torch.Size([1024])
#     ✅ layer3.0.bn3.bias: torch.Size([1024])
#     ✅ layer3.0.downsample.0.weight: torch.Size([1024, 512, 1, 1])
#     ✅ layer3.0.downsample.1.weight: torch.Size([1024])
#     ✅ layer3.0.downsample.1.bias: torch.Size([1024])
#     ✅ layer3.1.conv1.weight: torch.Size([256, 1024, 1, 1])
#     ✅ layer3.1.bn1.weight: torch.Size([256])
#     ✅ layer3.1.bn1.bias: torch.Size([256])
#     ✅ layer3.1.conv2.weight: torch.Size([256, 256, 3, 3])
#     ✅ layer3.1.bn2.weight: torch.Size([256])
#     ✅ layer3.1.bn2.bias: torch.Size([256])
#     ✅ layer3.1.conv3.weight: torch.Size([1024, 256, 1, 1])
#     ✅ layer3.1.bn3.weight: torch.Size([1024])
#     ✅ layer3.1.bn3.bias: torch.Size([1024])
#     ✅ layer3.2.conv1.weight: torch.Size([256, 1024, 1, 1])
#     ✅ layer3.2.bn1.weight: torch.Size([256])
#     ✅ layer3.2.bn1.bias: torch.Size([256])
#     ✅ layer3.2.conv2.weight: torch.Size([256, 256, 3, 3])
#     ✅ layer3.2.bn2.weight: torch.Size([256])
#     ✅ layer3.2.bn2.bias: torch.Size([256])
#     ✅ layer3.2.conv3.weight: torch.Size([1024, 256, 1, 1])
#     ✅ layer3.2.bn3.weight: torch.Size([1024])
#     ✅ layer3.2.bn3.bias: torch.Size([1024])
#     ✅ layer3.3.conv1.weight: torch.Size([256, 1024, 1, 1])
#     ✅ layer3.3.bn1.weight: torch.Size([256])
#     ✅ layer3.3.bn1.bias: torch.Size([256])
#     ✅ layer3.3.conv2.weight: torch.Size([256, 256, 3, 3])
#     ✅ layer3.3.bn2.weight: torch.Size([256])
#     ✅ layer3.3.bn2.bias: torch.Size([256])
#     ✅ layer3.3.conv3.weight: torch.Size([1024, 256, 1, 1])
#     ✅ layer3.3.bn3.weight: torch.Size([1024])
#     ✅ layer3.3.bn3.bias: torch.Size([1024])
#     ✅ layer3.4.conv1.weight: torch.Size([256, 1024, 1, 1])
#     ✅ layer3.4.bn1.weight: torch.Size([256])
#     ✅ layer3.4.bn1.bias: torch.Size([256])
#     ✅ layer3.4.conv2.weight: torch.Size([256, 256, 3, 3])
#     ✅ layer3.4.bn2.weight: torch.Size([256])
#     ✅ layer3.4.bn2.bias: torch.Size([256])
#     ✅ layer3.4.conv3.weight: torch.Size([1024, 256, 1, 1])
#     ✅ layer3.4.bn3.weight: torch.Size([1024])
#     ✅ layer3.4.bn3.bias: torch.Size([1024])
#     ✅ layer3.5.conv1.weight: torch.Size([256, 1024, 1, 1])
#     ✅ layer3.5.bn1.weight: torch.Size([256])
#     ✅ layer3.5.bn1.bias: torch.Size([256])
#     ✅ layer3.5.conv2.weight: torch.Size([256, 256, 3, 3])
#     ✅ layer3.5.bn2.weight: torch.Size([256])
#     ✅ layer3.5.bn2.bias: torch.Size([256])
#     ✅ layer3.5.conv3.weight: torch.Size([1024, 256, 1, 1])
#     ✅ layer3.5.bn3.weight: torch.Size([1024])
#     ✅ layer3.5.bn3.bias: torch.Size([1024])
#     ✅ layer4.0.conv1.weight: torch.Size([512, 1024, 1, 1])
#     ✅ layer4.0.bn1.weight: torch.Size([512])
#     ✅ layer4.0.bn1.bias: torch.Size([512])
#     ✅ layer4.0.conv2.weight: torch.Size([512, 512, 3, 3])
#     ✅ layer4.0.bn2.weight: torch.Size([512])
#     ✅ layer4.0.bn2.bias: torch.Size([512])
#     ✅ layer4.0.conv3.weight: torch.Size([2048, 512, 1, 1])
#     ✅ layer4.0.bn3.weight: torch.Size([2048])
#     ✅ layer4.0.bn3.bias: torch.Size([2048])
#     ✅ layer4.0.downsample.0.weight: torch.Size([2048, 1024, 1, 1])
#     ✅ layer4.0.downsample.1.weight: torch.Size([2048])
#     ✅ layer4.0.downsample.1.bias: torch.Size([2048])
#     ✅ layer4.1.conv1.weight: torch.Size([512, 2048, 1, 1])
#     ✅ layer4.1.bn1.weight: torch.Size([512])
#     ✅ layer4.1.bn1.bias: torch.Size([512])
#     ✅ layer4.1.conv2.weight: torch.Size([512, 512, 3, 3])
#     ✅ layer4.1.bn2.weight: torch.Size([512])
#     ✅ layer4.1.bn2.bias: torch.Size([512])
#     ✅ layer4.1.conv3.weight: torch.Size([2048, 512, 1, 1])
#     ✅ layer4.1.bn3.weight: torch.Size([2048])
#     ✅ layer4.1.bn3.bias: torch.Size([2048])
#     ✅ layer4.2.conv1.weight: torch.Size([512, 2048, 1, 1])
#     ✅ layer4.2.bn1.weight: torch.Size([512])
#     ✅ layer4.2.bn1.bias: torch.Size([512])
#     ✅ layer4.2.conv2.weight: torch.Size([512, 512, 3, 3])
#     ✅ layer4.2.bn2.weight: torch.Size([512])
#     ✅ layer4.2.bn2.bias: torch.Size([512])
#     ✅ layer4.2.conv3.weight: torch.Size([2048, 512, 1, 1])
#     ✅ layer4.2.bn3.weight: torch.Size([2048])
#     ✅ layer4.2.bn3.bias: torch.Size([2048])
#     ✅ fc.weight: torch.Size([512, 2048])
#     ✅ fc.bias: torch.Size([512])
#   🔍 ArcFace head weights:
#     🎯 ArcFace weights: torch.Size([10, 512])
#     ⚙️ ArcFace parameters - s: 64.0, m: 0.5
#     💾 Saved to: /content/lfw_final_weights.pth
#
# 📊 Extracting weights from CelebA:
#   🔍 Backbone weights:
#     ✅ conv1.weight: torch.Size([64, 3, 7, 7])
#     ✅ bn1.weight: torch.Size([64])
#     ✅ bn1.bias: torch.Size([64])
#     ✅ layer1.0.conv1.weight: torch.Size([64, 64, 1, 1])
#     ✅ layer1.0.bn1.weight: torch.Size([64])
#     ✅ layer1.0.bn1.bias: torch.Size([64])
#     ✅ layer1.0.conv2.weight: torch.Size([64, 64, 3, 3])
#     ✅ layer1.0.bn2.weight: torch.Size([64])
#     ✅ layer1.0.bn2.bias: torch.Size([64])
#     ✅ layer1.0.conv3.weight: torch.Size([256, 64, 1, 1])
#     ✅ layer1.0.bn3.weight: torch.Size([256])
#     ✅ layer1.0.bn3.bias: torch.Size([256])
#     ✅ layer1.0.downsample.0.weight: torch.Size([256, 64, 1, 1])
#     ✅ layer1.0.downsample.1.weight: torch.Size([256])
#     ✅ layer1.0.downsample.1.bias: torch.Size([256])
#     ✅ layer1.1.conv1.weight: torch.Size([64, 256, 1, 1])
#     ✅ layer1.1.bn1.weight: torch.Size([64])
#     ✅ layer1.1.bn1.bias: torch.Size([64])
#     ✅ layer1.1.conv2.weight: torch.Size([64, 64, 3, 3])
#     ✅ layer1.1.bn2.weight: torch.Size([64])
#     ✅ layer1.1.bn2.bias: torch.Size([64])
#     ✅ layer1.1.conv3.weight: torch.Size([256, 64, 1, 1])
#     ✅ layer1.1.bn3.weight: torch.Size([256])
#     ✅ layer1.1.bn3.bias: torch.Size([256])
#     ✅ layer1.2.conv1.weight: torch.Size([64, 256, 1, 1])
#     ✅ layer1.2.bn1.weight: torch.Size([64])
#     ✅ layer1.2.bn1.bias: torch.Size([64])
#     ✅ layer1.2.conv2.weight: torch.Size([64, 64, 3, 3])
#     ✅ layer1.2.bn2.weight: torch.Size([64])
#     ✅ layer1.2.bn2.bias: torch.Size([64])
#     ✅ layer1.2.conv3.weight: torch.Size([256, 64, 1, 1])
#     ✅ layer1.2.bn3.weight: torch.Size([256])
#     ✅ layer1.2.bn3.bias: torch.Size([256])
#     ✅ layer2.0.conv1.weight: torch.Size([128, 256, 1, 1])
#     ✅ layer2.0.bn1.weight: torch.Size([128])
#     ✅ layer2.0.bn1.bias: torch.Size([128])
#     ✅ layer2.0.conv2.weight: torch.Size([128, 128, 3, 3])
#     ✅ layer2.0.bn2.weight: torch.Size([128])
#     ✅ layer2.0.bn2.bias: torch.Size([128])
#     ✅ layer2.0.conv3.weight: torch.Size([512, 128, 1, 1])
#     ✅ layer2.0.bn3.weight: torch.Size([512])
#     ✅ layer2.0.bn3.bias: torch.Size([512])
#     ✅ layer2.0.downsample.0.weight: torch.Size([512, 256, 1, 1])
#     ✅ layer2.0.downsample.1.weight: torch.Size([512])
#     ✅ layer2.0.downsample.1.bias: torch.Size([512])
#     ✅ layer2.1.conv1.weight: torch.Size([128, 512, 1, 1])
#     ✅ layer2.1.bn1.weight: torch.Size([128])
#     ✅ layer2.1.bn1.bias: torch.Size([128])
#     ✅ layer2.1.conv2.weight: torch.Size([128, 128, 3, 3])
#     ✅ layer2.1.bn2.weight: torch.Size([128])
#     ✅ layer2.1.bn2.bias: torch.Size([128])
#     ✅ layer2.1.conv3.weight: torch.Size([512, 128, 1, 1])
#     ✅ layer2.1.bn3.weight: torch.Size([512])
#     ✅ layer2.1.bn3.bias: torch.Size([512])
#     ✅ layer2.2.conv1.weight: torch.Size([128, 512, 1, 1])
#     ✅ layer2.2.bn1.weight: torch.Size([128])
#     ✅ layer2.2.bn1.bias: torch.Size([128])
#     ✅ layer2.2.conv2.weight: torch.Size([128, 128, 3, 3])
#     ✅ layer2.2.bn2.weight: torch.Size([128])
#     ✅ layer2.2.bn2.bias: torch.Size([128])
#     ✅ layer2.2.conv3.weight: torch.Size([512, 128, 1, 1])
#     ✅ layer2.2.bn3.weight: torch.Size([512])
#     ✅ layer2.2.bn3.bias: torch.Size([512])
#     ✅ layer2.3.conv1.weight: torch.Size([128, 512, 1, 1])
#     ✅ layer2.3.bn1.weight: torch.Size([128])
#     ✅ layer2.3.bn1.bias: torch.Size([128])
#     ✅ layer2.3.conv2.weight: torch.Size([128, 128, 3, 3])
#     ✅ layer2.3.bn2.weight: torch.Size([128])
#     ✅ layer2.3.bn2.bias: torch.Size([128])
#     ✅ layer2.3.conv3.weight: torch.Size([512, 128, 1, 1])
#     ✅ layer2.3.bn3.weight: torch.Size([512])
#     ✅ layer2.3.bn3.bias: torch.Size([512])
#     ✅ layer3.0.conv1.weight: torch.Size([256, 512, 1, 1])
#     ✅ layer3.0.bn1.weight: torch.Size([256])
#     ✅ layer3.0.bn1.bias: torch.Size([256])
#     ✅ layer3.0.conv2.weight: torch.Size([256, 256, 3, 3])
#     ✅ layer3.0.bn2.weight: torch.Size([256])
#     ✅ layer3.0.bn2.bias: torch.Size([256])
#     ✅ layer3.0.conv3.weight: torch.Size([1024, 256, 1, 1])
#     ✅ layer3.0.bn3.weight: torch.Size([1024])
#     ✅ layer3.0.bn3.bias: torch.Size([1024])
#     ✅ layer3.0.downsample.0.weight: torch.Size([1024, 512, 1, 1])
#     ✅ layer3.0.downsample.1.weight: torch.Size([1024])
#     ✅ layer3.0.downsample.1.bias: torch.Size([1024])
#     ✅ layer3.1.conv1.weight: torch.Size([256, 1024, 1, 1])
#     ✅ layer3.1.bn1.weight: torch.Size([256])
#     ✅ layer3.1.bn1.bias: torch.Size([256])
#     ✅ layer3.1.conv2.weight: torch.Size([256, 256, 3, 3])
#     ✅ layer3.1.bn2.weight: torch.Size([256])
#     ✅ layer3.1.bn2.bias: torch.Size([256])
#     ✅ layer3.1.conv3.weight: torch.Size([1024, 256, 1, 1])
#     ✅ layer3.1.bn3.weight: torch.Size([1024])
#     ✅ layer3.1.bn3.bias: torch.Size([1024])
#     ✅ layer3.2.conv1.weight: torch.Size([256, 1024, 1, 1])
#     ✅ layer3.2.bn1.weight: torch.Size([256])
#     ✅ layer3.2.bn1.bias: torch.Size([256])
#     ✅ layer3.2.conv2.weight: torch.Size([256, 256, 3, 3])
#     ✅ layer3.2.bn2.weight: torch.Size([256])
#     ✅ layer3.2.bn2.bias: torch.Size([256])
#     ✅ layer3.2.conv3.weight: torch.Size([1024, 256, 1, 1])
#     ✅ layer3.2.bn3.weight: torch.Size([1024])
#     ✅ layer3.2.bn3.bias: torch.Size([1024])
#     ✅ layer3.3.conv1.weight: torch.Size([256, 1024, 1, 1])
#     ✅ layer3.3.bn1.weight: torch.Size([256])
#     ✅ layer3.3.bn1.bias: torch.Size([256])
#     ✅ layer3.3.conv2.weight: torch.Size([256, 256, 3, 3])
#     ✅ layer3.3.bn2.weight: torch.Size([256])
#     ✅ layer3.3.bn2.bias: torch.Size([256])
#     ✅ layer3.3.conv3.weight: torch.Size([1024, 256, 1, 1])
#     ✅ layer3.3.bn3.weight: torch.Size([1024])
#     ✅ layer3.3.bn3.bias: torch.Size([1024])
#     ✅ layer3.4.conv1.weight: torch.Size([256, 1024, 1, 1])
#     ✅ layer3.4.bn1.weight: torch.Size([256])
#     ✅ layer3.4.bn1.bias: torch.Size([256])
#     ✅ layer3.4.conv2.weight: torch.Size([256, 256, 3, 3])
#     ✅ layer3.4.bn2.weight: torch.Size([256])
#     ✅ layer3.4.bn2.bias: torch.Size([256])
#     ✅ layer3.4.conv3.weight: torch.Size([1024, 256, 1, 1])
#     ✅ layer3.4.bn3.weight: torch.Size([1024])
#     ✅ layer3.4.bn3.bias: torch.Size([1024])
#     ✅ layer3.5.conv1.weight: torch.Size([256, 1024, 1, 1])
#     ✅ layer3.5.bn1.weight: torch.Size([256])
#     ✅ layer3.5.bn1.bias: torch.Size([256])
#     ✅ layer3.5.conv2.weight: torch.Size([256, 256, 3, 3])
#     ✅ layer3.5.bn2.weight: torch.Size([256])
#     ✅ layer3.5.bn2.bias: torch.Size([256])
#     ✅ layer3.5.conv3.weight: torch.Size([1024, 256, 1, 1])
#     ✅ layer3.5.bn3.weight: torch.Size([1024])
#     ✅ layer3.5.bn3.bias: torch.Size([1024])
#     ✅ layer4.0.conv1.weight: torch.Size([512, 1024, 1, 1])
#     ✅ layer4.0.bn1.weight: torch.Size([512])
#     ✅ layer4.0.bn1.bias: torch.Size([512])
#     ✅ layer4.0.conv2.weight: torch.Size([512, 512, 3, 3])
#     ✅ layer4.0.bn2.weight: torch.Size([512])
#     ✅ layer4.0.bn2.bias: torch.Size([512])
#     ✅ layer4.0.conv3.weight: torch.Size([2048, 512, 1, 1])
#     ✅ layer4.0.bn3.weight: torch.Size([2048])
#     ✅ layer4.0.bn3.bias: torch.Size([2048])
#     ✅ layer4.0.downsample.0.weight: torch.Size([2048, 1024, 1, 1])
#     ✅ layer4.0.downsample.1.weight: torch.Size([2048])
#     ✅ layer4.0.downsample.1.bias: torch.Size([2048])
#     ✅ layer4.1.conv1.weight: torch.Size([512, 2048, 1, 1])
#     ✅ layer4.1.bn1.weight: torch.Size([512])
#     ✅ layer4.1.bn1.bias: torch.Size([512])
#     ✅ layer4.1.conv2.weight: torch.Size([512, 512, 3, 3])
#     ✅ layer4.1.bn2.weight: torch.Size([512])
#     ✅ layer4.1.bn2.bias: torch.Size([512])
#     ✅ layer4.1.conv3.weight: torch.Size([2048, 512, 1, 1])
#     ✅ layer4.1.bn3.weight: torch.Size([2048])
#     ✅ layer4.1.bn3.bias: torch.Size([2048])
#     ✅ layer4.2.conv1.weight: torch.Size([512, 2048, 1, 1])
#     ✅ layer4.2.bn1.weight: torch.Size([512])
#     ✅ layer4.2.bn1.bias: torch.Size([512])
#     ✅ layer4.2.conv2.weight: torch.Size([512, 512, 3, 3])
#     ✅ layer4.2.bn2.weight: torch.Size([512])
#     ✅ layer4.2.bn2.bias: torch.Size([512])
#     ✅ layer4.2.conv3.weight: torch.Size([2048, 512, 1, 1])
#     ✅ layer4.2.bn3.weight: torch.Size([2048])
#     ✅ layer4.2.bn3.bias: torch.Size([2048])
#     ✅ fc.weight: torch.Size([512, 2048])
#     ✅ fc.bias: torch.Size([512])
#   🔍 ArcFace head weights:
#     🎯 ArcFace weights: torch.Size([97, 512])
#     ⚙️ ArcFace parameters - s: 64.0, m: 0.5
#     💾 Saved to: /content/celeba_final_weights.pth
#
# 🔍 FINAL WEIGHTS SUMMARY:
# ==================================================
# LFW Model - Critical Weights:
#   🧠 LFW_fc.weight:
#      Shape: torch.Size([512, 2048])
#      Mean: 0.000011
#      Std:  0.012767
#   🧠 LFW_arcface_weights:
#      Shape: torch.Size([10, 512])
#      Mean: 0.001584
#      Std:  0.061852
#
# CelebA Model - Critical Weights:
#   🧠 CelebA_fc.weight:
#      Shape: torch.Size([512, 2048])
#      Mean: -0.000004
#      Std:  0.012775
#   🧠 CelebA_arcface_weights:
#      Shape: torch.Size([97, 512])
#      Mean: -0.000241
#      Std:  0.057368
#
# ✅ All weights extracted and saved!

# %%
# Download Final Weights to Your Computer
print("=== DOWNLOADING WEIGHTS TO YOUR COMPUTER ===")

def download_with_timestamp(filepath, description):
    if os.path.exists(filepath):
        # Add timestamp to filename
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = os.path.basename(filepath)
        name, ext = os.path.splitext(filename)
        new_filename = f"{name}_{timestamp}{ext}"

        # Copy with new name and download
        # !cp "{filepath}" "/content/{new_filename}"
        files.download(f"/content/{new_filename}")
        print(f" {description}: {new_filename}")
        return True
    else:
        print(f" File not found: {filepath}")
        return False

print("\n Downloading final weight files...")
print("Check your browser downloads folder for these files:")

lfw_success = download_with_timestamp('/content/lfw_final_weights.pth', 'LFW Weights')
celeba_success = download_with_timestamp('/content/celeba_final_weights.pth', 'CelebA Weights')

print("\n" + "="*60)
print(" FINAL WEIGHTS AND BIASES DOWNLOAD COMPLETE!")
print("="*60)

if lfw_success:
    print(" LFW Model Weights Downloaded - Contains:")
    print("   • ResNet50 backbone weights and biases")
    print("   • Final FC layer weights (512-D embeddings)")
    print("   • ArcFace classification weights")
    print("   • All trained parameters")

if celeba_success:
    print(" CelebA Model Weights Downloaded - Contains:")
    print("   • ResNet50 backbone weights and biases")
    print("   • Final FC layer weights (512-D embeddings)")
    print("   • ArcFace classification weights")
    print("   • All trained parameters")

print("\n Most Important Weights for Face Recognition:")
print("   • 'fc.weight' - Converts images to 512-D face embeddings")
print("   • 'arcface_weights' - Classifies embeddings to identities")

print("\n You can now use these weights for:")
print("   • Face verification")
print("   • Face identification")
print("   • Transfer learning")
print("   • Feature extraction")

print("\n Training Complete! Check your downloads folder for the .pth files!")
# Out:
# === DOWNLOADING WEIGHTS TO YOUR COMPUTER ===
#
# 📥 Downloading final weight files...
# Check your browser downloads folder for these files:
# 📥 LFW Weights: lfw_final_weights_20251128_142634.pth
# 📥 CelebA Weights: celeba_final_weights_20251128_142634.pth
#
# ============================================================
# 🎉 FINAL WEIGHTS AND BIASES DOWNLOAD COMPLETE!
# ============================================================
# ✅ LFW Model Weights Downloaded - Contains:
#    • ResNet50 backbone weights and biases
#    • Final FC layer weights (512-D embeddings)
#    • ArcFace classification weights
#    • All trained parameters
# ✅ CelebA Model Weights Downloaded - Contains:
#    • ResNet50 backbone weights and biases
#    • Final FC layer weights (512-D embeddings)
#    • ArcFace classification weights
#    • All trained parameters
#
# 🔑 Most Important Weights for Face Recognition:
#    • 'fc.weight' - Converts images to 512-D face embeddings
#    • 'arcface_weights' - Classifies embeddings to identities
#
# 🚀 You can now use these weights for:
#    • Face verification
#    • Face identification
#    • Transfer learning
#    • Feature extraction
#
# ⭐ Training Complete! Check your downloads folder for the .pth files!

# %%
# === EXTRA: 512-D FACE EMBEDDING EXTRACTION (INFERENCE MODE) ===

print("=== DEFINING EMBEDDING EXTRACTION FUNCTION ===")

def generate_arcface_embeddings(backbone, image_root, model_name="Model",
                                limit_images=None, output_prefix=None):
    """
    Uses the trained backbone (ResNet-50 + 512-D FC) to:
      - Load all images from image_root
      - Resize + normalize (same as training)
      - Extract 512-D L2-normalized embeddings
      - Save to a .npz file: filenames + embeddings
    """
    import glob  # just in case

    if backbone is None:
        print(f" {model_name} backbone is None. Train the model first.")
        return None

    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    backbone = backbone.to(device)
    backbone.eval()

    print("\n" + "="*60)
    print(f" GENERATING 512-D EMBEDDINGS FOR: {model_name}")
    print("="*60)
    print(f" Image root: {image_root}")
    print(f" Device: {device}")

    # Same transforms as training
    transform = transforms.Compose([
        transforms.Resize((112, 112)),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5],
                             [0.5, 0.5, 0.5])
    ])

    # Collect image files (jpg / jpeg / png)
    image_files = []
    for ext in ["*.jpg", "*.jpeg", "*.png"]:
        pattern = os.path.join(image_root, "**", ext)
        image_files.extend(glob.glob(pattern, recursive=True))

    image_files = sorted(image_files)

    if not image_files:
        print(" No images found for embedding extraction.")
        return None

    if limit_images is not None:
        image_files = image_files[:limit_images]
        print(f"⚠ Limiting to first {len(image_files)} images for speed.")

    print(f" Total images to process: {len(image_files)}")

    embeddings = []
    filenames = []

    with torch.no_grad():
        for idx, img_path in enumerate(image_files):
            try:
                img = Image.open(img_path).convert("RGB")
                img_t = transform(img).unsqueeze(0).to(device)

                # Forward through backbone -> (1, 512)
                feat = backbone(img_t)

                # L2 normalize (common for ArcFace embeddings)
                feat = nn.functional.normalize(feat, p=2, dim=1)

                embeddings.append(feat.squeeze(0).cpu().numpy())
                filenames.append(os.path.basename(img_path))

                # Progress log
                if (idx + 1) % 25 == 0 or (idx + 1) == len(image_files):
                    print(f"   ✔ Processed {idx+1}/{len(image_files)} images")
            except Exception as e:
                print(f"    Error processing {img_path}: {e}")

    if len(embeddings) == 0:
        print(" No embeddings were generated.")
        return None

    embeddings = np.stack(embeddings, axis=0)

    if output_prefix is None:
        output_prefix = model_name.lower()

    out_path = f"/content/{output_prefix}_arcface_512d_embeddings.npz"

    # Save filenames + embeddings
    np.savez(out_path,
             filenames=np.array(filenames),
             embeddings=embeddings)

    print("\n EMBEDDINGS SAVED!")
    print(f"   • File: {out_path}")
    print(f"   • Num embeddings: {embeddings.shape[0]}")
    print(f"   • Embedding dimension: {embeddings.shape[1]}")
    return out_path

print(" Embedding extraction function defined!")
# Out:
# === DEFINING EMBEDDING EXTRACTION FUNCTION ===
# ✅ Embedding extraction function defined!

# %%
# === EXTRA: RUN EMBEDDING EXTRACTION + DOWNLOAD FILES ===

print("=== STARTING 512-D EMBEDDING EXTRACTION FOR BOTH DATASETS ===")

lfw_embeddings_file = generate_arcface_embeddings(
    backbone=lfw_backbone,
    image_root=LFW_ROOT,
    model_name="LFW",
    limit_images=None,
    output_prefix="lfw"
)

celeba_embeddings_file = generate_arcface_embeddings(
    backbone=celeba_backbone,
    image_root=CELEBA_IMG_ROOT,
    model_name="CelebA",
    limit_images=None,
    output_prefix="celeba"
)

print("\n" + "="*60)
print("=== DOWNLOADING EMBEDDING FILES TO YOUR COMPUTER ===")
print("="*60)

if lfw_embeddings_file is not None:
    download_with_timestamp(lfw_embeddings_file, "LFW 512-D embeddings")

if celeba_embeddings_file is not None:
    download_with_timestamp(celeba_embeddings_file, "CelebA 512-D embeddings")

print("\n DONE! You now have:")
print("   • lfw_arcface_512d_embeddings_YYYYMMDD_HHMMSS.npz")
print("   • celeba_arcface_512d_embeddings_YYYYMMDD_HHMMSS.npz")
print("Each file contains:")
print("   • 'filenames'  → image file names")
print("   • 'embeddings' → 512-D ArcFace feature vectors")
# Out:
# Streaming output truncated to the last 5000 lines.
#    ✔ Processed 77850/202599 images
#    ✔ Processed 77875/202599 images
#    ✔ Processed 77900/202599 images
#    ✔ Processed 77925/202599 images
#    ✔ Processed 77950/202599 images
#    ✔ Processed 77975/202599 images
#    ✔ Processed 78000/202599 images
#    ✔ Processed 78025/202599 images
#    ✔ Processed 78050/202599 images
#    ✔ Processed 78075/202599 images
#    ✔ Processed 78100/202599 images
#    ✔ Processed 78125/202599 images
#    ✔ Processed 78150/202599 images
#    ✔ Processed 78175/202599 images
#    ✔ Processed 78200/202599 images
#    ✔ Processed 78225/202599 images
#    ✔ Processed 78250/202599 images
#    ✔ Processed 78275/202599 images
#    ✔ Processed 78300/202599 images
#    ✔ Processed 78325/202599 images
#    ✔ Processed 78350/202599 images
#    ✔ Processed 78375/202599 images
#    ✔ Processed 78400/202599 images
#    ✔ Processed 78425/202599 images
#    ✔ Processed 78450/202599 images
#    ✔ Processed 78475/202599 images
#    ✔ Processed 78500/202599 images
#    ✔ Processed 78525/202599 images
#    ✔ Processed 78550/202599 images
#    ✔ Processed 78575/202599 images
#    ✔ Processed 78600/202599 images
#    ✔ Processed 78625/202599 images
#    ✔ Processed 78650/202599 images
#    ✔ Processed 78675/202599 images
#    ✔ Processed 78700/202599 images
#    ✔ Processed 78725/202599 images
#    ✔ Processed 78750/202599 images
#    ✔ Processed 78775/202599 images
#    ✔ Processed 78800/202599 images
#    ✔ Processed 78825/202599 images
#    ✔ Processed 78850/202599 images
#    ✔ Processed 78875/202599 images
#    ✔ Processed 78900/202599 images
#    ✔ Processed 78925/202599 images
#    ✔ Processed 78950/202599 images
#    ✔ Processed 78975/202599 images
#    ✔ Processed 79000/202599 images
#    ✔ Processed 79025/202599 images
#    ✔ Processed 79050/202599 images
#    ✔ Processed 79075/202599 images
#    ✔ Processed 79100/202599 images
#    ✔ Processed 79125/202599 images
#    ✔ Processed 79150/202599 images
#    ✔ Processed 79175/202599 images
#    ✔ Processed 79200/202599 images
#    ✔ Processed 79225/202599 images
#    ✔ Processed 79250/202599 images
#    ✔ Processed 79275/202599 images
#    ✔ Processed 79300/202599 images
#    ✔ Processed 79325/202599 images
#    ✔ Processed 79350/202599 images
#    ✔ Processed 79375/202599 images
#    ✔ Processed 79400/202599 images
#    ✔ Processed 79425/202599 images
#    ✔ Processed 79450/202599 images
#    ✔ Processed 79475/202599 images
#    ✔ Processed 79500/202599 images
#    ✔ Processed 79525/202599 images
#    ✔ Processed 79550/202599 images
#    ✔ Processed 79575/202599 images
#    ✔ Processed 79600/202599 images
#    ✔ Processed 79625/202599 images
#    ✔ Processed 79650/202599 images
#    ✔ Processed 79675/202599 images
#    ✔ Processed 79700/202599 images
#    ✔ Processed 79725/202599 images
#    ✔ Processed 79750/202599 images
#    ✔ Processed 79775/202599 images
#    ✔ Processed 79800/202599 images
#    ✔ Processed 79825/202599 images
#    ✔ Processed 79850/202599 images
#    ✔ Processed 79875/202599 images
#    ✔ Processed 79900/202599 images
#    ✔ Processed 79925/202599 images
#    ✔ Processed 79950/202599 images
#    ✔ Processed 79975/202599 images
#    ✔ Processed 80000/202599 images
#    ✔ Processed 80025/202599 images
#    ✔ Processed 80050/202599 images
#    ✔ Processed 80075/202599 images
#    ✔ Processed 80100/202599 images
#    ✔ Processed 80125/202599 images
#    ✔ Processed 80150/202599 images
#    ✔ Processed 80175/202599 images
#    ✔ Processed 80200/202599 images
#    ✔ Processed 80225/202599 images
#    ✔ Processed 80250/202599 images
#    ✔ Processed 80275/202599 images
#    ✔ Processed 80300/202599 images
#    ✔ Processed 80325/202599 images
#    ✔ Processed 80350/202599 images
#    ✔ Processed 80375/202599 images
#    ✔ Processed 80400/202599 images
#    ✔ Processed 80425/202599 images
#    ✔ Processed 80450/202599 images
#    ✔ Processed 80475/202599 images
#    ✔ Processed 80500/202599 images
#    ✔ Processed 80525/202599 images
#    ✔ Processed 80550/202599 images
#    ✔ Processed 80575/202599 images
#    ✔ Processed 80600/202599 images
#    ✔ Processed 80625/202599 images
#    ✔ Processed 80650/202599 images
#    ✔ Processed 80675/202599 images
#    ✔ Processed 80700/202599 images
#    ✔ Processed 80725/202599 images
#    ✔ Processed 80750/202599 images
#    ✔ Processed 80775/202599 images
#    ✔ Processed 80800/202599 images
#    ✔ Processed 80825/202599 images
#    ✔ Processed 80850/202599 images
#    ✔ Processed 80875/202599 images
#    ✔ Processed 80900/202599 images
#    ✔ Processed 80925/202599 images
#    ✔ Processed 80950/202599 images
#    ✔ Processed 80975/202599 images
#    ✔ Processed 81000/202599 images
#    ✔ Processed 81025/202599 images
#    ✔ Processed 81050/202599 images
#    ✔ Processed 81075/202599 images
#    ✔ Processed 81100/202599 images
#    ✔ Processed 81125/202599 images
#    ✔ Processed 81150/202599 images
#    ✔ Processed 81175/202599 images
#    ✔ Processed 81200/202599 images
#    ✔ Processed 81225/202599 images
#    ✔ Processed 81250/202599 images
#    ✔ Processed 81275/202599 images
#    ✔ Processed 81300/202599 images
#    ✔ Processed 81325/202599 images
#    ✔ Processed 81350/202599 images
#    ✔ Processed 81375/202599 images
#    ✔ Processed 81400/202599 images
#    ✔ Processed 81425/202599 images
#    ✔ Processed 81450/202599 images
#    ✔ Processed 81475/202599 images
#    ✔ Processed 81500/202599 images
#    ✔ Processed 81525/202599 images
#    ✔ Processed 81550/202599 images
#    ✔ Processed 81575/202599 images
#    ✔ Processed 81600/202599 images
#    ✔ Processed 81625/202599 images
#    ✔ Processed 81650/202599 images
#    ✔ Processed 81675/202599 images
#    ✔ Processed 81700/202599 images
#    ✔ Processed 81725/202599 images
#    ✔ Processed 81750/202599 images
#    ✔ Processed 81775/202599 images
#    ✔ Processed 81800/202599 images
#    ✔ Processed 81825/202599 images
#    ✔ Processed 81850/202599 images
#    ✔ Processed 81875/202599 images
#    ✔ Processed 81900/202599 images
#    ✔ Processed 81925/202599 images
#    ✔ Processed 81950/202599 images
#    ✔ Processed 81975/202599 images
#    ✔ Processed 82000/202599 images
#    ✔ Processed 82025/202599 images
#    ✔ Processed 82050/202599 images
#    ✔ Processed 82075/202599 images
#    ✔ Processed 82100/202599 images
#    ✔ Processed 82125/202599 images
#    ✔ Processed 82150/202599 images
#    ✔ Processed 82175/202599 images
#    ✔ Processed 82200/202599 images
#    ✔ Processed 82225/202599 images
#    ✔ Processed 82250/202599 images
#    ✔ Processed 82275/202599 images
#    ✔ Processed 82300/202599 images
#    ✔ Processed 82325/202599 images
#    ✔ Processed 82350/202599 images
#    ✔ Processed 82375/202599 images
#    ✔ Processed 82400/202599 images
#    ✔ Processed 82425/202599 images
#    ✔ Processed 82450/202599 images
#    ✔ Processed 82475/202599 images
#    ✔ Processed 82500/202599 images
#    ✔ Processed 82525/202599 images
#    ✔ Processed 82550/202599 images
#    ✔ Processed 82575/202599 images
#    ✔ Processed 82600/202599 images
#    ✔ Processed 82625/202599 images
#    ✔ Processed 82650/202599 images
#    ✔ Processed 82675/202599 images
#    ✔ Processed 82700/202599 images
#    ✔ Processed 82725/202599 images
#    ✔ Processed 82750/202599 images
#    ✔ Processed 82775/202599 images
#    ✔ Processed 82800/202599 images
#    ✔ Processed 82825/202599 images
#    ✔ Processed 82850/202599 images
#    ✔ Processed 82875/202599 images
#    ✔ Processed 82900/202599 images
#    ✔ Processed 82925/202599 images
#    ✔ Processed 82950/202599 images
#    ✔ Processed 82975/202599 images
#    ✔ Processed 83000/202599 images
#    ✔ Processed 83025/202599 images
#    ✔ Processed 83050/202599 images
#    ✔ Processed 83075/202599 images
#    ✔ Processed 83100/202599 images
#    ✔ Processed 83125/202599 images
#    ✔ Processed 83150/202599 images
#    ✔ Processed 83175/202599 images
#    ✔ Processed 83200/202599 images
#    ✔ Processed 83225/202599 images
#    ✔ Processed 83250/202599 images
#    ✔ Processed 83275/202599 images
#    ✔ Processed 83300/202599 images
#    ✔ Processed 83325/202599 images
#    ✔ Processed 83350/202599 images
#    ✔ Processed 83375/202599 images
#    ✔ Processed 83400/202599 images
#    ✔ Processed 83425/202599 images
#    ✔ Processed 83450/202599 images
#    ✔ Processed 83475/202599 images
#    ✔ Processed 83500/202599 images
#    ✔ Processed 83525/202599 images
#    ✔ Processed 83550/202599 images
#    ✔ Processed 83575/202599 images
#    ✔ Processed 83600/202599 images
#    ✔ Processed 83625/202599 images
#    ✔ Processed 83650/202599 images
#    ✔ Processed 83675/202599 images
#    ✔ Processed 83700/202599 images
#    ✔ Processed 83725/202599 images
#    ✔ Processed 83750/202599 images
#    ✔ Processed 83775/202599 images
#    ✔ Processed 83800/202599 images
#    ✔ Processed 83825/202599 images
#    ✔ Processed 83850/202599 images
#    ✔ Processed 83875/202599 images
#    ✔ Processed 83900/202599 images
#    ✔ Processed 83925/202599 images
#    ✔ Processed 83950/202599 images
#    ✔ Processed 83975/202599 images
#    ✔ Processed 84000/202599 images
#    ✔ Processed 84025/202599 images
#    ✔ Processed 84050/202599 images
#    ✔ Processed 84075/202599 images
#    ✔ Processed 84100/202599 images
#    ✔ Processed 84125/202599 images
#    ✔ Processed 84150/202599 images
#    ✔ Processed 84175/202599 images
#    ✔ Processed 84200/202599 images
#    ✔ Processed 84225/202599 images
#    ✔ Processed 84250/202599 images
#    ✔ Processed 84275/202599 images
#    ✔ Processed 84300/202599 images
#    ✔ Processed 84325/202599 images
#    ✔ Processed 84350/202599 images
#    ✔ Processed 84375/202599 images
#    ✔ Processed 84400/202599 images
#    ✔ Processed 84425/202599 images
#    ✔ Processed 84450/202599 images
#    ✔ Processed 84475/202599 images
#    ✔ Processed 84500/202599 images
#    ✔ Processed 84525/202599 images
#    ✔ Processed 84550/202599 images
#    ✔ Processed 84575/202599 images
#    ✔ Processed 84600/202599 images
#    ✔ Processed 84625/202599 images
#    ✔ Processed 84650/202599 images
#    ✔ Processed 84675/202599 images
#    ✔ Processed 84700/202599 images
#    ✔ Processed 84725/202599 images
#    ✔ Processed 84750/202599 images
#    ✔ Processed 84775/202599 images
#    ✔ Processed 84800/202599 images
#    ✔ Processed 84825/202599 images
#    ✔ Processed 84850/202599 images
#    ✔ Processed 84875/202599 images
#    ✔ Processed 84900/202599 images
#    ✔ Processed 84925/202599 images
#    ✔ Processed 84950/202599 images
#    ✔ Processed 84975/202599 images
#    ✔ Processed 85000/202599 images
#    ✔ Processed 85025/202599 images
#    ✔ Processed 85050/202599 images
#    ✔ Processed 85075/202599 images
#    ✔ Processed 85100/202599 images
#    ✔ Processed 85125/202599 images
#    ✔ Processed 85150/202599 images
#    ✔ Processed 85175/202599 images
#    ✔ Processed 85200/202599 images
#    ✔ Processed 85225/202599 images
#    ✔ Processed 85250/202599 images
#    ✔ Processed 85275/202599 images
#    ✔ Processed 85300/202599 images
#    ✔ Processed 85325/202599 images
#    ✔ Processed 85350/202599 images
#    ✔ Processed 85375/202599 images
#    ✔ Processed 85400/202599 images
#    ✔ Processed 85425/202599 images
#    ✔ Processed 85450/202599 images
#    ✔ Processed 85475/202599 images
#    ✔ Processed 85500/202599 images
#    ✔ Processed 85525/202599 images
#    ✔ Processed 85550/202599 images
#    ✔ Processed 85575/202599 images
#    ✔ Processed 85600/202599 images
#    ✔ Processed 85625/202599 images
#    ✔ Processed 85650/202599 images
#    ✔ Processed 85675/202599 images
#    ✔ Processed 85700/202599 images
#    ✔ Processed 85725/202599 images
#    ✔ Processed 85750/202599 images
#    ✔ Processed 85775/202599 images
#    ✔ Processed 85800/202599 images
#    ✔ Processed 85825/202599 images
#    ✔ Processed 85850/202599 images
#    ✔ Processed 85875/202599 images
#    ✔ Processed 85900/202599 images
#    ✔ Processed 85925/202599 images
#    ✔ Processed 85950/202599 images
#    ✔ Processed 85975/202599 images
#    ✔ Processed 86000/202599 images
#    ✔ Processed 86025/202599 images
#    ✔ Processed 86050/202599 images
#    ✔ Processed 86075/202599 images
#    ✔ Processed 86100/202599 images
#    ✔ Processed 86125/202599 images
#    ✔ Processed 86150/202599 images
#    ✔ Processed 86175/202599 images
#    ✔ Processed 86200/202599 images
#    ✔ Processed 86225/202599 images
#    ✔ Processed 86250/202599 images
#    ✔ Processed 86275/202599 images
#    ✔ Processed 86300/202599 images
#    ✔ Processed 86325/202599 images
#    ✔ Processed 86350/202599 images
#    ✔ Processed 86375/202599 images
#    ✔ Processed 86400/202599 images
#    ✔ Processed 86425/202599 images
#    ✔ Processed 86450/202599 images
#    ✔ Processed 86475/202599 images
#    ✔ Processed 86500/202599 images
#    ✔ Processed 86525/202599 images
#    ✔ Processed 86550/202599 images
#    ✔ Processed 86575/202599 images
#    ✔ Processed 86600/202599 images
#    ✔ Processed 86625/202599 images
#    ✔ Processed 86650/202599 images
#    ✔ Processed 86675/202599 images
#    ✔ Processed 86700/202599 images
#    ✔ Processed 86725/202599 images
#    ✔ Processed 86750/202599 images
#    ✔ Processed 86775/202599 images
#    ✔ Processed 86800/202599 images
#    ✔ Processed 86825/202599 images
#    ✔ Processed 86850/202599 images
#    ✔ Processed 86875/202599 images
#    ✔ Processed 86900/202599 images
#    ✔ Processed 86925/202599 images
#    ✔ Processed 86950/202599 images
#    ✔ Processed 86975/202599 images
#    ✔ Processed 87000/202599 images
#    ✔ Processed 87025/202599 images
#    ✔ Processed 87050/202599 images
#    ✔ Processed 87075/202599 images
#    ✔ Processed 87100/202599 images
#    ✔ Processed 87125/202599 images
#    ✔ Processed 87150/202599 images
#    ✔ Processed 87175/202599 images
#    ✔ Processed 87200/202599 images
#    ✔ Processed 87225/202599 images
#    ✔ Processed 87250/202599 images
#    ✔ Processed 87275/202599 images
#    ✔ Processed 87300/202599 images
#    ✔ Processed 87325/202599 images
#    ✔ Processed 87350/202599 images
#    ✔ Processed 87375/202599 images
#    ✔ Processed 87400/202599 images
#    ✔ Processed 87425/202599 images
#    ✔ Processed 87450/202599 images
#    ✔ Processed 87475/202599 images
#    ✔ Processed 87500/202599 images
#    ✔ Processed 87525/202599 images
#    ✔ Processed 87550/202599 images
#    ✔ Processed 87575/202599 images
#    ✔ Processed 87600/202599 images
#    ✔ Processed 87625/202599 images
#    ✔ Processed 87650/202599 images
#    ✔ Processed 87675/202599 images
#    ✔ Processed 87700/202599 images
#    ✔ Processed 87725/202599 images
#    ✔ Processed 87750/202599 images
#    ✔ Processed 87775/202599 images
#    ✔ Processed 87800/202599 images
#    ✔ Processed 87825/202599 images
#    ✔ Processed 87850/202599 images
#    ✔ Processed 87875/202599 images
#    ✔ Processed 87900/202599 images
#    ✔ Processed 87925/202599 images
#    ✔ Processed 87950/202599 images
#    ✔ Processed 87975/202599 images
#    ✔ Processed 88000/202599 images
#    ✔ Processed 88025/202599 images
#    ✔ Processed 88050/202599 images
#    ✔ Processed 88075/202599 images
#    ✔ Processed 88100/202599 images
#    ✔ Processed 88125/202599 images
#    ✔ Processed 88150/202599 images
#    ✔ Processed 88175/202599 images
#    ✔ Processed 88200/202599 images
#    ✔ Processed 88225/202599 images
#    ✔ Processed 88250/202599 images
#    ✔ Processed 88275/202599 images
#    ✔ Processed 88300/202599 images
#    ✔ Processed 88325/202599 images
#    ✔ Processed 88350/202599 images
#    ✔ Processed 88375/202599 images
#    ✔ Processed 88400/202599 images
#    ✔ Processed 88425/202599 images
#    ✔ Processed 88450/202599 images
#    ✔ Processed 88475/202599 images
#    ✔ Processed 88500/202599 images
#    ✔ Processed 88525/202599 images
#    ✔ Processed 88550/202599 images
#    ✔ Processed 88575/202599 images
#    ✔ Processed 88600/202599 images
#    ✔ Processed 88625/202599 images
#    ✔ Processed 88650/202599 images
#    ✔ Processed 88675/202599 images
#    ✔ Processed 88700/202599 images
#    ✔ Processed 88725/202599 images
#    ✔ Processed 88750/202599 images
#    ✔ Processed 88775/202599 images
#    ✔ Processed 88800/202599 images
#    ✔ Processed 88825/202599 images
#    ✔ Processed 88850/202599 images
#    ✔ Processed 88875/202599 images
#    ✔ Processed 88900/202599 images
#    ✔ Processed 88925/202599 images
#    ✔ Processed 88950/202599 images
#    ✔ Processed 88975/202599 images
#    ✔ Processed 89000/202599 images
#    ✔ Processed 89025/202599 images
#    ✔ Processed 89050/202599 images
#    ✔ Processed 89075/202599 images
#    ✔ Processed 89100/202599 images
#    ✔ Processed 89125/202599 images
#    ✔ Processed 89150/202599 images
#    ✔ Processed 89175/202599 images
#    ✔ Processed 89200/202599 images
#    ✔ Processed 89225/202599 images
#    ✔ Processed 89250/202599 images
#    ✔ Processed 89275/202599 images
#    ✔ Processed 89300/202599 images
#    ✔ Processed 89325/202599 images
#    ✔ Processed 89350/202599 images
#    ✔ Processed 89375/202599 images
#    ✔ Processed 89400/202599 images
#    ✔ Processed 89425/202599 images
#    ✔ Processed 89450/202599 images
#    ✔ Processed 89475/202599 images
#    ✔ Processed 89500/202599 images
#    ✔ Processed 89525/202599 images
#    ✔ Processed 89550/202599 images
#    ✔ Processed 89575/202599 images
#    ✔ Processed 89600/202599 images
#    ✔ Processed 89625/202599 images
#    ✔ Processed 89650/202599 images
#    ✔ Processed 89675/202599 images
#    ✔ Processed 89700/202599 images
#    ✔ Processed 89725/202599 images
#    ✔ Processed 89750/202599 images
#    ✔ Processed 89775/202599 images
#    ✔ Processed 89800/202599 images
#    ✔ Processed 89825/202599 images
#    ✔ Processed 89850/202599 images
#    ✔ Processed 89875/202599 images
#    ✔ Processed 89900/202599 images
#    ✔ Processed 89925/202599 images
#    ✔ Processed 89950/202599 images
#    ✔ Processed 89975/202599 images
#    ✔ Processed 90000/202599 images
#    ✔ Processed 90025/202599 images
#    ✔ Processed 90050/202599 images
#    ✔ Processed 90075/202599 images
#    ✔ Processed 90100/202599 images
#    ✔ Processed 90125/202599 images
#    ✔ Processed 90150/202599 images
#    ✔ Processed 90175/202599 images
#    ✔ Processed 90200/202599 images
#    ✔ Processed 90225/202599 images
#    ✔ Processed 90250/202599 images
#    ✔ Processed 90275/202599 images
#    ✔ Processed 90300/202599 images
#    ✔ Processed 90325/202599 images
#    ✔ Processed 90350/202599 images
#    ✔ Processed 90375/202599 images
#    ✔ Processed 90400/202599 images
#    ✔ Processed 90425/202599 images
#    ✔ Processed 90450/202599 images
#    ✔ Processed 90475/202599 images
#    ✔ Processed 90500/202599 images
#    ✔ Processed 90525/202599 images
#    ✔ Processed 90550/202599 images
#    ✔ Processed 90575/202599 images
#    ✔ Processed 90600/202599 images
#    ✔ Processed 90625/202599 images
#    ✔ Processed 90650/202599 images
#    ✔ Processed 90675/202599 images
#    ✔ Processed 90700/202599 images
#    ✔ Processed 90725/202599 images
#    ✔ Processed 90750/202599 images
#    ✔ Processed 90775/202599 images
#    ✔ Processed 90800/202599 images
#    ✔ Processed 90825/202599 images
#    ✔ Processed 90850/202599 images
#    ✔ Processed 90875/202599 images
#    ✔ Processed 90900/202599 images
#    ✔ Processed 90925/202599 images
#    ✔ Processed 90950/202599 images
#    ✔ Processed 90975/202599 images
#    ✔ Processed 91000/202599 images
#    ✔ Processed 91025/202599 images
#    ✔ Processed 91050/202599 images
#    ✔ Processed 91075/202599 images
#    ✔ Processed 91100/202599 images
#    ✔ Processed 91125/202599 images
#    ✔ Processed 91150/202599 images
#    ✔ Processed 91175/202599 images
#    ✔ Processed 91200/202599 images
#    ✔ Processed 91225/202599 images
#    ✔ Processed 91250/202599 images
#    ✔ Processed 91275/202599 images
#    ✔ Processed 91300/202599 images
#    ✔ Processed 91325/202599 images
#    ✔ Processed 91350/202599 images
#    ✔ Processed 91375/202599 images
#    ✔ Processed 91400/202599 images
#    ✔ Processed 91425/202599 images
#    ✔ Processed 91450/202599 images
#    ✔ Processed 91475/202599 images
#    ✔ Processed 91500/202599 images
#    ✔ Processed 91525/202599 images
#    ✔ Processed 91550/202599 images
#    ✔ Processed 91575/202599 images
#    ✔ Processed 91600/202599 images
#    ✔ Processed 91625/202599 images
#    ✔ Processed 91650/202599 images
#    ✔ Processed 91675/202599 images
#    ✔ Processed 91700/202599 images
#    ✔ Processed 91725/202599 images
#    ✔ Processed 91750/202599 images
#    ✔ Processed 91775/202599 images
#    ✔ Processed 91800/202599 images
#    ✔ Processed 91825/202599 images
#    ✔ Processed 91850/202599 images
#    ✔ Processed 91875/202599 images
#    ✔ Processed 91900/202599 images
#    ✔ Processed 91925/202599 images
#    ✔ Processed 91950/202599 images
#    ✔ Processed 91975/202599 images
#    ✔ Processed 92000/202599 images
#    ✔ Processed 92025/202599 images
#    ✔ Processed 92050/202599 images
#    ✔ Processed 92075/202599 images
#    ✔ Processed 92100/202599 images
#    ✔ Processed 92125/202599 images
#    ✔ Processed 92150/202599 images
#    ✔ Processed 92175/202599 images
#    ✔ Processed 92200/202599 images
#    ✔ Processed 92225/202599 images
#    ✔ Processed 92250/202599 images
#    ✔ Processed 92275/202599 images
#    ✔ Processed 92300/202599 images
#    ✔ Processed 92325/202599 images
#    ✔ Processed 92350/202599 images
#    ✔ Processed 92375/202599 images
#    ✔ Processed 92400/202599 images
#    ✔ Processed 92425/202599 images
#    ✔ Processed 92450/202599 images
#    ✔ Processed 92475/202599 images
#    ✔ Processed 92500/202599 images
#    ✔ Processed 92525/202599 images
#    ✔ Processed 92550/202599 images
#    ✔ Processed 92575/202599 images
#    ✔ Processed 92600/202599 images
#    ✔ Processed 92625/202599 images
#    ✔ Processed 92650/202599 images
#    ✔ Processed 92675/202599 images
#    ✔ Processed 92700/202599 images
#    ✔ Processed 92725/202599 images
#    ✔ Processed 92750/202599 images
#    ✔ Processed 92775/202599 images
#    ✔ Processed 92800/202599 images
#    ✔ Processed 92825/202599 images
#    ✔ Processed 92850/202599 images
#    ✔ Processed 92875/202599 images
#    ✔ Processed 92900/202599 images
#    ✔ Processed 92925/202599 images
#    ✔ Processed 92950/202599 images
#    ✔ Processed 92975/202599 images
#    ✔ Processed 93000/202599 images
#    ✔ Processed 93025/202599 images
#    ✔ Processed 93050/202599 images
#    ✔ Processed 93075/202599 images
#    ✔ Processed 93100/202599 images
#    ✔ Processed 93125/202599 images
#    ✔ Processed 93150/202599 images
#    ✔ Processed 93175/202599 images
#    ✔ Processed 93200/202599 images
#    ✔ Processed 93225/202599 images
#    ✔ Processed 93250/202599 images
#    ✔ Processed 93275/202599 images
#    ✔ Processed 93300/202599 images
#    ✔ Processed 93325/202599 images
#    ✔ Processed 93350/202599 images
#    ✔ Processed 93375/202599 images
#    ✔ Processed 93400/202599 images
#    ✔ Processed 93425/202599 images
#    ✔ Processed 93450/202599 images
#    ✔ Processed 93475/202599 images
#    ✔ Processed 93500/202599 images
#    ✔ Processed 93525/202599 images
#    ✔ Processed 93550/202599 images
#    ✔ Processed 93575/202599 images
#    ✔ Processed 93600/202599 images
#    ✔ Processed 93625/202599 images
#    ✔ Processed 93650/202599 images
#    ✔ Processed 93675/202599 images
#    ✔ Processed 93700/202599 images
#    ✔ Processed 93725/202599 images
#    ✔ Processed 93750/202599 images
#    ✔ Processed 93775/202599 images
#    ✔ Processed 93800/202599 images
#    ✔ Processed 93825/202599 images
#    ✔ Processed 93850/202599 images
#    ✔ Processed 93875/202599 images
#    ✔ Processed 93900/202599 images
#    ✔ Processed 93925/202599 images
#    ✔ Processed 93950/202599 images
#    ✔ Processed 93975/202599 images
#    ✔ Processed 94000/202599 images
#    ✔ Processed 94025/202599 images
#    ✔ Processed 94050/202599 images
#    ✔ Processed 94075/202599 images
#    ✔ Processed 94100/202599 images
#    ✔ Processed 94125/202599 images
#    ✔ Processed 94150/202599 images
#    ✔ Processed 94175/202599 images
#    ✔ Processed 94200/202599 images
#    ✔ Processed 94225/202599 images
#    ✔ Processed 94250/202599 images
#    ✔ Processed 94275/202599 images
#    ✔ Processed 94300/202599 images
#    ✔ Processed 94325/202599 images
#    ✔ Processed 94350/202599 images
#    ✔ Processed 94375/202599 images
#    ✔ Processed 94400/202599 images
#    ✔ Processed 94425/202599 images
#    ✔ Processed 94450/202599 images
#    ✔ Processed 94475/202599 images
#    ✔ Processed 94500/202599 images
#    ✔ Processed 94525/202599 images
#    ✔ Processed 94550/202599 images
#    ✔ Processed 94575/202599 images
#    ✔ Processed 94600/202599 images
#    ✔ Processed 94625/202599 images
#    ✔ Processed 94650/202599 images
#    ✔ Processed 94675/202599 images
#    ✔ Processed 94700/202599 images
#    ✔ Processed 94725/202599 images
#    ✔ Processed 94750/202599 images
#    ✔ Processed 94775/202599 images
#    ✔ Processed 94800/202599 images
#    ✔ Processed 94825/202599 images
#    ✔ Processed 94850/202599 images
#    ✔ Processed 94875/202599 images
#    ✔ Processed 94900/202599 images
#    ✔ Processed 94925/202599 images
#    ✔ Processed 94950/202599 images
#    ✔ Processed 94975/202599 images
#    ✔ Processed 95000/202599 images
#    ✔ Processed 95025/202599 images
#    ✔ Processed 95050/202599 images
#    ✔ Processed 95075/202599 images
#    ✔ Processed 95100/202599 images
#    ✔ Processed 95125/202599 images
#    ✔ Processed 95150/202599 images
#    ✔ Processed 95175/202599 images
#    ✔ Processed 95200/202599 images
#    ✔ Processed 95225/202599 images
#    ✔ Processed 95250/202599 images
#    ✔ Processed 95275/202599 images
#    ✔ Processed 95300/202599 images
#    ✔ Processed 95325/202599 images
#    ✔ Processed 95350/202599 images
#    ✔ Processed 95375/202599 images
#    ✔ Processed 95400/202599 images
#    ✔ Processed 95425/202599 images
#    ✔ Processed 95450/202599 images
#    ✔ Processed 95475/202599 images
#    ✔ Processed 95500/202599 images
#    ✔ Processed 95525/202599 images
#    ✔ Processed 95550/202599 images
#    ✔ Processed 95575/202599 images
#    ✔ Processed 95600/202599 images
#    ✔ Processed 95625/202599 images
#    ✔ Processed 95650/202599 images
#    ✔ Processed 95675/202599 images
#    ✔ Processed 95700/202599 images
#    ✔ Processed 95725/202599 images
#    ✔ Processed 95750/202599 images
#    ✔ Processed 95775/202599 images
#    ✔ Processed 95800/202599 images
#    ✔ Processed 95825/202599 images
#    ✔ Processed 95850/202599 images
#    ✔ Processed 95875/202599 images
#    ✔ Processed 95900/202599 images
#    ✔ Processed 95925/202599 images
#    ✔ Processed 95950/202599 images
#    ✔ Processed 95975/202599 images
#    ✔ Processed 96000/202599 images
#    ✔ Processed 96025/202599 images
#    ✔ Processed 96050/202599 images
#    ✔ Processed 96075/202599 images
#    ✔ Processed 96100/202599 images
#    ✔ Processed 96125/202599 images
#    ✔ Processed 96150/202599 images
#    ✔ Processed 96175/202599 images
#    ✔ Processed 96200/202599 images
#    ✔ Processed 96225/202599 images
#    ✔ Processed 96250/202599 images
#    ✔ Processed 96275/202599 images
#    ✔ Processed 96300/202599 images
#    ✔ Processed 96325/202599 images
#    ✔ Processed 96350/202599 images
#    ✔ Processed 96375/202599 images
#    ✔ Processed 96400/202599 images
#    ✔ Processed 96425/202599 images
#    ✔ Processed 96450/202599 images
#    ✔ Processed 96475/202599 images
#    ✔ Processed 96500/202599 images
#    ✔ Processed 96525/202599 images
#    ✔ Processed 96550/202599 images
#    ✔ Processed 96575/202599 images
#    ✔ Processed 96600/202599 images
#    ✔ Processed 96625/202599 images
#    ✔ Processed 96650/202599 images
#    ✔ Processed 96675/202599 images
#    ✔ Processed 96700/202599 images
#    ✔ Processed 96725/202599 images
#    ✔ Processed 96750/202599 images
#    ✔ Processed 96775/202599 images
#    ✔ Processed 96800/202599 images
#    ✔ Processed 96825/202599 images
#    ✔ Processed 96850/202599 images
#    ✔ Processed 96875/202599 images
#    ✔ Processed 96900/202599 images
#    ✔ Processed 96925/202599 images
#    ✔ Processed 96950/202599 images
#    ✔ Processed 96975/202599 images
#    ✔ Processed 97000/202599 images
#    ✔ Processed 97025/202599 images
#    ✔ Processed 97050/202599 images
#    ✔ Processed 97075/202599 images
#    ✔ Processed 97100/202599 images
#    ✔ Processed 97125/202599 images
#    ✔ Processed 97150/202599 images
#    ✔ Processed 97175/202599 images
#    ✔ Processed 97200/202599 images
#    ✔ Processed 97225/202599 images
#    ✔ Processed 97250/202599 images
#    ✔ Processed 97275/202599 images
#    ✔ Processed 97300/202599 images
#    ✔ Processed 97325/202599 images
#    ✔ Processed 97350/202599 images
#    ✔ Processed 97375/202599 images
#    ✔ Processed 97400/202599 images
#    ✔ Processed 97425/202599 images
#    ✔ Processed 97450/202599 images
#    ✔ Processed 97475/202599 images
#    ✔ Processed 97500/202599 images
#    ✔ Processed 97525/202599 images
#    ✔ Processed 97550/202599 images
#    ✔ Processed 97575/202599 images
#    ✔ Processed 97600/202599 images
#    ✔ Processed 97625/202599 images
#    ✔ Processed 97650/202599 images
#    ✔ Processed 97675/202599 images
#    ✔ Processed 97700/202599 images
#    ✔ Processed 97725/202599 images
#    ✔ Processed 97750/202599 images
#    ✔ Processed 97775/202599 images
#    ✔ Processed 97800/202599 images
#    ✔ Processed 97825/202599 images
#    ✔ Processed 97850/202599 images
#    ✔ Processed 97875/202599 images
#    ✔ Processed 97900/202599 images
#    ✔ Processed 97925/202599 images
#    ✔ Processed 97950/202599 images
#    ✔ Processed 97975/202599 images
#    ✔ Processed 98000/202599 images
#    ✔ Processed 98025/202599 images
#    ✔ Processed 98050/202599 images
#    ✔ Processed 98075/202599 images
#    ✔ Processed 98100/202599 images
#    ✔ Processed 98125/202599 images
#    ✔ Processed 98150/202599 images
#    ✔ Processed 98175/202599 images
#    ✔ Processed 98200/202599 images
#    ✔ Processed 98225/202599 images
#    ✔ Processed 98250/202599 images
#    ✔ Processed 98275/202599 images
#    ✔ Processed 98300/202599 images
#    ✔ Processed 98325/202599 images
#    ✔ Processed 98350/202599 images
#    ✔ Processed 98375/202599 images
#    ✔ Processed 98400/202599 images
#    ✔ Processed 98425/202599 images
#    ✔ Processed 98450/202599 images
#    ✔ Processed 98475/202599 images
#    ✔ Processed 98500/202599 images
#    ✔ Processed 98525/202599 images
#    ✔ Processed 98550/202599 images
#    ✔ Processed 98575/202599 images
#    ✔ Processed 98600/202599 images
#    ✔ Processed 98625/202599 images
#    ✔ Processed 98650/202599 images
#    ✔ Processed 98675/202599 images
#    ✔ Processed 98700/202599 images
#    ✔ Processed 98725/202599 images
#    ✔ Processed 98750/202599 images
#    ✔ Processed 98775/202599 images
#    ✔ Processed 98800/202599 images
#    ✔ Processed 98825/202599 images
#    ✔ Processed 98850/202599 images
#    ✔ Processed 98875/202599 images
#    ✔ Processed 98900/202599 images
#    ✔ Processed 98925/202599 images
#    ✔ Processed 98950/202599 images
#    ✔ Processed 98975/202599 images
#    ✔ Processed 99000/202599 images
#    ✔ Processed 99025/202599 images
#    ✔ Processed 99050/202599 images
#    ✔ Processed 99075/202599 images
#    ✔ Processed 99100/202599 images
#    ✔ Processed 99125/202599 images
#    ✔ Processed 99150/202599 images
#    ✔ Processed 99175/202599 images
#    ✔ Processed 99200/202599 images
#    ✔ Processed 99225/202599 images
#    ✔ Processed 99250/202599 images
#    ✔ Processed 99275/202599 images
#    ✔ Processed 99300/202599 images
#    ✔ Processed 99325/202599 images
#    ✔ Processed 99350/202599 images
#    ✔ Processed 99375/202599 images
#    ✔ Processed 99400/202599 images
#    ✔ Processed 99425/202599 images
#    ✔ Processed 99450/202599 images
#    ✔ Processed 99475/202599 images
#    ✔ Processed 99500/202599 images
#    ✔ Processed 99525/202599 images
#    ✔ Processed 99550/202599 images
#    ✔ Processed 99575/202599 images
#    ✔ Processed 99600/202599 images
#    ✔ Processed 99625/202599 images
#    ✔ Processed 99650/202599 images
#    ✔ Processed 99675/202599 images
#    ✔ Processed 99700/202599 images
#    ✔ Processed 99725/202599 images
#    ✔ Processed 99750/202599 images
#    ✔ Processed 99775/202599 images
#    ✔ Processed 99800/202599 images
#    ✔ Processed 99825/202599 images
#    ✔ Processed 99850/202599 images
#    ✔ Processed 99875/202599 images
#    ✔ Processed 99900/202599 images
#    ✔ Processed 99925/202599 images
#    ✔ Processed 99950/202599 images
#    ✔ Processed 99975/202599 images
#    ✔ Processed 100000/202599 images
#    ✔ Processed 100025/202599 images
#    ✔ Processed 100050/202599 images
#    ✔ Processed 100075/202599 images
#    ✔ Processed 100100/202599 images
#    ✔ Processed 100125/202599 images
#    ✔ Processed 100150/202599 images
#    ✔ Processed 100175/202599 images
#    ✔ Processed 100200/202599 images
#    ✔ Processed 100225/202599 images
#    ✔ Processed 100250/202599 images
#    ✔ Processed 100275/202599 images
#    ✔ Processed 100300/202599 images
#    ✔ Processed 100325/202599 images
#    ✔ Processed 100350/202599 images
#    ✔ Processed 100375/202599 images
#    ✔ Processed 100400/202599 images
#    ✔ Processed 100425/202599 images
#    ✔ Processed 100450/202599 images
#    ✔ Processed 100475/202599 images
#    ✔ Processed 100500/202599 images
#    ✔ Processed 100525/202599 images
#    ✔ Processed 100550/202599 images
#    ✔ Processed 100575/202599 images
#    ✔ Processed 100600/202599 images
#    ✔ Processed 100625/202599 images
#    ✔ Processed 100650/202599 images
#    ✔ Processed 100675/202599 images
#    ✔ Processed 100700/202599 images
#    ✔ Processed 100725/202599 images
#    ✔ Processed 100750/202599 images
#    ✔ Processed 100775/202599 images
#    ✔ Processed 100800/202599 images
#    ✔ Processed 100825/202599 images
#    ✔ Processed 100850/202599 images
#    ✔ Processed 100875/202599 images
#    ✔ Processed 100900/202599 images
#    ✔ Processed 100925/202599 images
#    ✔ Processed 100950/202599 images
#    ✔ Processed 100975/202599 images
#    ✔ Processed 101000/202599 images
#    ✔ Processed 101025/202599 images
#    ✔ Processed 101050/202599 images
#    ✔ Processed 101075/202599 images
#    ✔ Processed 101100/202599 images
#    ✔ Processed 101125/202599 images
#    ✔ Processed 101150/202599 images
#    ✔ Processed 101175/202599 images
#    ✔ Processed 101200/202599 images
#    ✔ Processed 101225/202599 images
#    ✔ Processed 101250/202599 images
#    ✔ Processed 101275/202599 images
#    ✔ Processed 101300/202599 images
#    ✔ Processed 101325/202599 images
#    ✔ Processed 101350/202599 images
#    ✔ Processed 101375/202599 images
#    ✔ Processed 101400/202599 images
#    ✔ Processed 101425/202599 images
#    ✔ Processed 101450/202599 images
#    ✔ Processed 101475/202599 images
#    ✔ Processed 101500/202599 images
#    ✔ Processed 101525/202599 images
#    ✔ Processed 101550/202599 images
#    ✔ Processed 101575/202599 images
#    ✔ Processed 101600/202599 images
#    ✔ Processed 101625/202599 images
#    ✔ Processed 101650/202599 images
#    ✔ Processed 101675/202599 images
#    ✔ Processed 101700/202599 images
#    ✔ Processed 101725/202599 images
#    ✔ Processed 101750/202599 images
#    ✔ Processed 101775/202599 images
#    ✔ Processed 101800/202599 images
#    ✔ Processed 101825/202599 images
#    ✔ Processed 101850/202599 images
#    ✔ Processed 101875/202599 images
#    ✔ Processed 101900/202599 images
#    ✔ Processed 101925/202599 images
#    ✔ Processed 101950/202599 images
#    ✔ Processed 101975/202599 images
#    ✔ Processed 102000/202599 images
#    ✔ Processed 102025/202599 images
#    ✔ Processed 102050/202599 images
#    ✔ Processed 102075/202599 images
#    ✔ Processed 102100/202599 images
#    ✔ Processed 102125/202599 images
#    ✔ Processed 102150/202599 images
#    ✔ Processed 102175/202599 images
#    ✔ Processed 102200/202599 images
#    ✔ Processed 102225/202599 images
#    ✔ Processed 102250/202599 images
#    ✔ Processed 102275/202599 images
#    ✔ Processed 102300/202599 images
#    ✔ Processed 102325/202599 images
#    ✔ Processed 102350/202599 images
#    ✔ Processed 102375/202599 images
#    ✔ Processed 102400/202599 images
#    ✔ Processed 102425/202599 images
#    ✔ Processed 102450/202599 images
#    ✔ Processed 102475/202599 images
#    ✔ Processed 102500/202599 images
#    ✔ Processed 102525/202599 images
#    ✔ Processed 102550/202599 images
#    ✔ Processed 102575/202599 images
#    ✔ Processed 102600/202599 images
#    ✔ Processed 102625/202599 images
#    ✔ Processed 102650/202599 images
#    ✔ Processed 102675/202599 images
#    ✔ Processed 102700/202599 images
#    ✔ Processed 102725/202599 images
#    ✔ Processed 102750/202599 images
#    ✔ Processed 102775/202599 images
#    ✔ Processed 102800/202599 images
#    ✔ Processed 102825/202599 images
#    ✔ Processed 102850/202599 images
#    ✔ Processed 102875/202599 images
#    ✔ Processed 102900/202599 images
#    ✔ Processed 102925/202599 images
#    ✔ Processed 102950/202599 images
#    ✔ Processed 102975/202599 images
#    ✔ Processed 103000/202599 images
#    ✔ Processed 103025/202599 images
#    ✔ Processed 103050/202599 images
#    ✔ Processed 103075/202599 images
#    ✔ Processed 103100/202599 images
#    ✔ Processed 103125/202599 images
#    ✔ Processed 103150/202599 images
#    ✔ Processed 103175/202599 images
#    ✔ Processed 103200/202599 images
#    ✔ Processed 103225/202599 images
#    ✔ Processed 103250/202599 images
#    ✔ Processed 103275/202599 images
#    ✔ Processed 103300/202599 images
#    ✔ Processed 103325/202599 images
#    ✔ Processed 103350/202599 images
#    ✔ Processed 103375/202599 images
#    ✔ Processed 103400/202599 images
#    ✔ Processed 103425/202599 images
#    ✔ Processed 103450/202599 images
#    ✔ Processed 103475/202599 images
#    ✔ Processed 103500/202599 images
#    ✔ Processed 103525/202599 images
#    ✔ Processed 103550/202599 images
#    ✔ Processed 103575/202599 images
#    ✔ Processed 103600/202599 images
#    ✔ Processed 103625/202599 images
#    ✔ Processed 103650/202599 images
#    ✔ Processed 103675/202599 images
#    ✔ Processed 103700/202599 images
#    ✔ Processed 103725/202599 images
#    ✔ Processed 103750/202599 images
#    ✔ Processed 103775/202599 images
#    ✔ Processed 103800/202599 images
#    ✔ Processed 103825/202599 images
#    ✔ Processed 103850/202599 images
#    ✔ Processed 103875/202599 images
#    ✔ Processed 103900/202599 images
#    ✔ Processed 103925/202599 images
#    ✔ Processed 103950/202599 images
#    ✔ Processed 103975/202599 images
#    ✔ Processed 104000/202599 images
#    ✔ Processed 104025/202599 images
#    ✔ Processed 104050/202599 images
#    ✔ Processed 104075/202599 images
#    ✔ Processed 104100/202599 images
#    ✔ Processed 104125/202599 images
#    ✔ Processed 104150/202599 images
#    ✔ Processed 104175/202599 images
#    ✔ Processed 104200/202599 images
#    ✔ Processed 104225/202599 images
#    ✔ Processed 104250/202599 images
#    ✔ Processed 104275/202599 images
#    ✔ Processed 104300/202599 images
#    ✔ Processed 104325/202599 images
#    ✔ Processed 104350/202599 images
#    ✔ Processed 104375/202599 images
#    ✔ Processed 104400/202599 images
#    ✔ Processed 104425/202599 images
#    ✔ Processed 104450/202599 images
#    ✔ Processed 104475/202599 images
#    ✔ Processed 104500/202599 images
#    ✔ Processed 104525/202599 images
#    ✔ Processed 104550/202599 images
#    ✔ Processed 104575/202599 images
#    ✔ Processed 104600/202599 images
#    ✔ Processed 104625/202599 images
#    ✔ Processed 104650/202599 images
#    ✔ Processed 104675/202599 images
#    ✔ Processed 104700/202599 images
#    ✔ Processed 104725/202599 images
#    ✔ Processed 104750/202599 images
#    ✔ Processed 104775/202599 images
#    ✔ Processed 104800/202599 images
#    ✔ Processed 104825/202599 images
#    ✔ Processed 104850/202599 images
#    ✔ Processed 104875/202599 images
#    ✔ Processed 104900/202599 images
#    ✔ Processed 104925/202599 images
#    ✔ Processed 104950/202599 images
#    ✔ Processed 104975/202599 images
#    ✔ Processed 105000/202599 images
#    ✔ Processed 105025/202599 images
#    ✔ Processed 105050/202599 images
#    ✔ Processed 105075/202599 images
#    ✔ Processed 105100/202599 images
#    ✔ Processed 105125/202599 images
#    ✔ Processed 105150/202599 images
#    ✔ Processed 105175/202599 images
#    ✔ Processed 105200/202599 images
#    ✔ Processed 105225/202599 images
#    ✔ Processed 105250/202599 images
#    ✔ Processed 105275/202599 images
#    ✔ Processed 105300/202599 images
#    ✔ Processed 105325/202599 images
#    ✔ Processed 105350/202599 images
#    ✔ Processed 105375/202599 images
#    ✔ Processed 105400/202599 images
#    ✔ Processed 105425/202599 images
#    ✔ Processed 105450/202599 images
#    ✔ Processed 105475/202599 images
#    ✔ Processed 105500/202599 images
#    ✔ Processed 105525/202599 images
#    ✔ Processed 105550/202599 images
#    ✔ Processed 105575/202599 images
#    ✔ Processed 105600/202599 images
#    ✔ Processed 105625/202599 images
#    ✔ Processed 105650/202599 images
#    ✔ Processed 105675/202599 images
#    ✔ Processed 105700/202599 images
#    ✔ Processed 105725/202599 images
#    ✔ Processed 105750/202599 images
#    ✔ Processed 105775/202599 images
#    ✔ Processed 105800/202599 images
#    ✔ Processed 105825/202599 images
#    ✔ Processed 105850/202599 images
#    ✔ Processed 105875/202599 images
#    ✔ Processed 105900/202599 images
#    ✔ Processed 105925/202599 images
#    ✔ Processed 105950/202599 images
#    ✔ Processed 105975/202599 images
#    ✔ Processed 106000/202599 images
#    ✔ Processed 106025/202599 images
#    ✔ Processed 106050/202599 images
#    ✔ Processed 106075/202599 images
#    ✔ Processed 106100/202599 images
#    ✔ Processed 106125/202599 images
#    ✔ Processed 106150/202599 images
#    ✔ Processed 106175/202599 images
#    ✔ Processed 106200/202599 images
#    ✔ Processed 106225/202599 images
#    ✔ Processed 106250/202599 images
#    ✔ Processed 106275/202599 images
#    ✔ Processed 106300/202599 images
#    ✔ Processed 106325/202599 images
#    ✔ Processed 106350/202599 images
#    ✔ Processed 106375/202599 images
#    ✔ Processed 106400/202599 images
#    ✔ Processed 106425/202599 images
#    ✔ Processed 106450/202599 images
#    ✔ Processed 106475/202599 images
#    ✔ Processed 106500/202599 images
#    ✔ Processed 106525/202599 images
#    ✔ Processed 106550/202599 images
#    ✔ Processed 106575/202599 images
#    ✔ Processed 106600/202599 images
#    ✔ Processed 106625/202599 images
#    ✔ Processed 106650/202599 images
#    ✔ Processed 106675/202599 images
#    ✔ Processed 106700/202599 images
#    ✔ Processed 106725/202599 images
#    ✔ Processed 106750/202599 images
#    ✔ Processed 106775/202599 images
#    ✔ Processed 106800/202599 images
#    ✔ Processed 106825/202599 images
#    ✔ Processed 106850/202599 images
#    ✔ Processed 106875/202599 images
#    ✔ Processed 106900/202599 images
#    ✔ Processed 106925/202599 images
#    ✔ Processed 106950/202599 images
#    ✔ Processed 106975/202599 images
#    ✔ Processed 107000/202599 images
#    ✔ Processed 107025/202599 images
#    ✔ Processed 107050/202599 images
#    ✔ Processed 107075/202599 images
#    ✔ Processed 107100/202599 images
#    ✔ Processed 107125/202599 images
#    ✔ Processed 107150/202599 images
#    ✔ Processed 107175/202599 images
#    ✔ Processed 107200/202599 images
#    ✔ Processed 107225/202599 images
#    ✔ Processed 107250/202599 images
#    ✔ Processed 107275/202599 images
#    ✔ Processed 107300/202599 images
#    ✔ Processed 107325/202599 images
#    ✔ Processed 107350/202599 images
#    ✔ Processed 107375/202599 images
#    ✔ Processed 107400/202599 images
#    ✔ Processed 107425/202599 images
#    ✔ Processed 107450/202599 images
#    ✔ Processed 107475/202599 images
#    ✔ Processed 107500/202599 images
#    ✔ Processed 107525/202599 images
#    ✔ Processed 107550/202599 images
#    ✔ Processed 107575/202599 images
#    ✔ Processed 107600/202599 images
#    ✔ Processed 107625/202599 images
#    ✔ Processed 107650/202599 images
#    ✔ Processed 107675/202599 images
#    ✔ Processed 107700/202599 images
#    ✔ Processed 107725/202599 images
#    ✔ Processed 107750/202599 images
#    ✔ Processed 107775/202599 images
#    ✔ Processed 107800/202599 images
#    ✔ Processed 107825/202599 images
#    ✔ Processed 107850/202599 images
#    ✔ Processed 107875/202599 images
#    ✔ Processed 107900/202599 images
#    ✔ Processed 107925/202599 images
#    ✔ Processed 107950/202599 images
#    ✔ Processed 107975/202599 images
#    ✔ Processed 108000/202599 images
#    ✔ Processed 108025/202599 images
#    ✔ Processed 108050/202599 images
#    ✔ Processed 108075/202599 images
#    ✔ Processed 108100/202599 images
#    ✔ Processed 108125/202599 images
#    ✔ Processed 108150/202599 images
#    ✔ Processed 108175/202599 images
#    ✔ Processed 108200/202599 images
#    ✔ Processed 108225/202599 images
#    ✔ Processed 108250/202599 images
#    ✔ Processed 108275/202599 images
#    ✔ Processed 108300/202599 images
#    ✔ Processed 108325/202599 images
#    ✔ Processed 108350/202599 images
#    ✔ Processed 108375/202599 images
#    ✔ Processed 108400/202599 images
#    ✔ Processed 108425/202599 images
#    ✔ Processed 108450/202599 images
#    ✔ Processed 108475/202599 images
#    ✔ Processed 108500/202599 images
#    ✔ Processed 108525/202599 images
#    ✔ Processed 108550/202599 images
#    ✔ Processed 108575/202599 images
#    ✔ Processed 108600/202599 images
#    ✔ Processed 108625/202599 images
#    ✔ Processed 108650/202599 images
#    ✔ Processed 108675/202599 images
#    ✔ Processed 108700/202599 images
#    ✔ Processed 108725/202599 images
#    ✔ Processed 108750/202599 images
#    ✔ Processed 108775/202599 images
#    ✔ Processed 108800/202599 images
#    ✔ Processed 108825/202599 images
#    ✔ Processed 108850/202599 images
#    ✔ Processed 108875/202599 images
#    ✔ Processed 108900/202599 images
#    ✔ Processed 108925/202599 images
#    ✔ Processed 108950/202599 images
#    ✔ Processed 108975/202599 images
#    ✔ Processed 109000/202599 images
#    ✔ Processed 109025/202599 images
#    ✔ Processed 109050/202599 images
#    ✔ Processed 109075/202599 images
#    ✔ Processed 109100/202599 images
#    ✔ Processed 109125/202599 images
#    ✔ Processed 109150/202599 images
#    ✔ Processed 109175/202599 images
#    ✔ Processed 109200/202599 images
#    ✔ Processed 109225/202599 images
#    ✔ Processed 109250/202599 images
#    ✔ Processed 109275/202599 images
#    ✔ Processed 109300/202599 images
#    ✔ Processed 109325/202599 images
#    ✔ Processed 109350/202599 images
#    ✔ Processed 109375/202599 images
#    ✔ Processed 109400/202599 images
#    ✔ Processed 109425/202599 images
#    ✔ Processed 109450/202599 images
#    ✔ Processed 109475/202599 images
#    ✔ Processed 109500/202599 images
#    ✔ Processed 109525/202599 images
#    ✔ Processed 109550/202599 images
#    ✔ Processed 109575/202599 images
#    ✔ Processed 109600/202599 images
#    ✔ Processed 109625/202599 images
#    ✔ Processed 109650/202599 images
#    ✔ Processed 109675/202599 images
#    ✔ Processed 109700/202599 images
#    ✔ Processed 109725/202599 images
#    ✔ Processed 109750/202599 images
#    ✔ Processed 109775/202599 images
#    ✔ Processed 109800/202599 images
#    ✔ Processed 109825/202599 images
#    ✔ Processed 109850/202599 images
#    ✔ Processed 109875/202599 images
#    ✔ Processed 109900/202599 images
#    ✔ Processed 109925/202599 images
#    ✔ Processed 109950/202599 images
#    ✔ Processed 109975/202599 images
#    ✔ Processed 110000/202599 images
#    ✔ Processed 110025/202599 images
#    ✔ Processed 110050/202599 images
#    ✔ Processed 110075/202599 images
#    ✔ Processed 110100/202599 images
#    ✔ Processed 110125/202599 images
#    ✔ Processed 110150/202599 images
#    ✔ Processed 110175/202599 images
#    ✔ Processed 110200/202599 images
#    ✔ Processed 110225/202599 images
#    ✔ Processed 110250/202599 images
#    ✔ Processed 110275/202599 images
#    ✔ Processed 110300/202599 images
#    ✔ Processed 110325/202599 images
#    ✔ Processed 110350/202599 images
#    ✔ Processed 110375/202599 images
#    ✔ Processed 110400/202599 images
#    ✔ Processed 110425/202599 images
#    ✔ Processed 110450/202599 images
#    ✔ Processed 110475/202599 images
#    ✔ Processed 110500/202599 images
#    ✔ Processed 110525/202599 images
#    ✔ Processed 110550/202599 images
#    ✔ Processed 110575/202599 images
#    ✔ Processed 110600/202599 images
#    ✔ Processed 110625/202599 images
#    ✔ Processed 110650/202599 images
#    ✔ Processed 110675/202599 images
#    ✔ Processed 110700/202599 images
#    ✔ Processed 110725/202599 images
#    ✔ Processed 110750/202599 images
#    ✔ Processed 110775/202599 images
#    ✔ Processed 110800/202599 images
#    ✔ Processed 110825/202599 images
#    ✔ Processed 110850/202599 images
#    ✔ Processed 110875/202599 images
#    ✔ Processed 110900/202599 images
#    ✔ Processed 110925/202599 images
#    ✔ Processed 110950/202599 images
#    ✔ Processed 110975/202599 images
#    ✔ Processed 111000/202599 images
#    ✔ Processed 111025/202599 images
#    ✔ Processed 111050/202599 images
#    ✔ Processed 111075/202599 images
#    ✔ Processed 111100/202599 images
#    ✔ Processed 111125/202599 images
#    ✔ Processed 111150/202599 images
#    ✔ Processed 111175/202599 images
#    ✔ Processed 111200/202599 images
#    ✔ Processed 111225/202599 images
#    ✔ Processed 111250/202599 images
#    ✔ Processed 111275/202599 images
#    ✔ Processed 111300/202599 images
#    ✔ Processed 111325/202599 images
#    ✔ Processed 111350/202599 images
#    ✔ Processed 111375/202599 images
#    ✔ Processed 111400/202599 images
#    ✔ Processed 111425/202599 images
#    ✔ Processed 111450/202599 images
#    ✔ Processed 111475/202599 images
#    ✔ Processed 111500/202599 images
#    ✔ Processed 111525/202599 images
#    ✔ Processed 111550/202599 images
#    ✔ Processed 111575/202599 images
#    ✔ Processed 111600/202599 images
#    ✔ Processed 111625/202599 images
#    ✔ Processed 111650/202599 images
#    ✔ Processed 111675/202599 images
#    ✔ Processed 111700/202599 images
#    ✔ Processed 111725/202599 images
# ...
#    ✔ Processed 192000/202599 images
#    ✔ Processed 192025/202599 images
#    ✔ Processed 192050/202599 images
#    ✔ Processed 192075/202599 images
#    ✔ Processed 192100/202599 images
#    ✔ Processed 192125/202599 images
#    ✔ Processed 192150/202599 images
#    ✔ Processed 192175/202599 images
#    ✔ Processed 192200/202599 images
#    ✔ Processed 192225/202599 images
#    ✔ Processed 192250/202599 images
#    ✔ Processed 192275/202599 images
#    ✔ Processed 192300/202599 images
#    ✔ Processed 192325/202599 images
#    ✔ Processed 192350/202599 images
#    ✔ Processed 192375/202599 images
#    ✔ Processed 192400/202599 images
#    ✔ Processed 192425/202599 images
#    ✔ Processed 192450/202599 images
#    ✔ Processed 192475/202599 images
#    ✔ Processed 192500/202599 images
#    ✔ Processed 192525/202599 images
#    ✔ Processed 192550/202599 images
#    ✔ Processed 192575/202599 images
#    ✔ Processed 192600/202599 images
#    ✔ Processed 192625/202599 images
#    ✔ Processed 192650/202599 images
#    ✔ Processed 192675/202599 images
#    ✔ Processed 192700/202599 images
#    ✔ Processed 192725/202599 images
#    ✔ Processed 192750/202599 images
#    ✔ Processed 192775/202599 images
#    ✔ Processed 192800/202599 images
#    ✔ Processed 192825/202599 images
#    ✔ Processed 192850/202599 images
#    ✔ Processed 192875/202599 images
#    ✔ Processed 192900/202599 images
#    ✔ Processed 192925/202599 images
#    ✔ Processed 192950/202599 images
#    ✔ Processed 192975/202599 images
#    ✔ Processed 193000/202599 images
#    ✔ Processed 193025/202599 images
#    ✔ Processed 193050/202599 images
#    ✔ Processed 193075/202599 images
#    ✔ Processed 193100/202599 images
#    ✔ Processed 193125/202599 images
#    ✔ Processed 193150/202599 images
#    ✔ Processed 193175/202599 images
#    ✔ Processed 193200/202599 images
#    ✔ Processed 193225/202599 images
#    ✔ Processed 193250/202599 images
#    ✔ Processed 193275/202599 images
#    ✔ Processed 193300/202599 images
#    ✔ Processed 193325/202599 images
#    ✔ Processed 193350/202599 images
#    ✔ Processed 193375/202599 images
#    ✔ Processed 193400/202599 images
#    ✔ Processed 193425/202599 images
#    ✔ Processed 193450/202599 images
#    ✔ Processed 193475/202599 images
#    ✔ Processed 193500/202599 images
#    ✔ Processed 193525/202599 images
#    ✔ Processed 193550/202599 images
#    ✔ Processed 193575/202599 images
#    ✔ Processed 193600/202599 images
#    ✔ Processed 193625/202599 images
#    ✔ Processed 193650/202599 images
#    ✔ Processed 193675/202599 images
#    ✔ Processed 193700/202599 images
#    ✔ Processed 193725/202599 images
#    ✔ Processed 193750/202599 images
#    ✔ Processed 193775/202599 images
#    ✔ Processed 193800/202599 images
#    ✔ Processed 193825/202599 images
#    ✔ Processed 193850/202599 images
#    ✔ Processed 193875/202599 images
#    ✔ Processed 193900/202599 images
#    ✔ Processed 193925/202599 images
#    ✔ Processed 193950/202599 images
#    ✔ Processed 193975/202599 images
#    ✔ Processed 194000/202599 images
#    ✔ Processed 194025/202599 images
#    ✔ Processed 194050/202599 images
#    ✔ Processed 194075/202599 images
#    ✔ Processed 194100/202599 images
#    ✔ Processed 194125/202599 images
#    ✔ Processed 194150/202599 images
#    ✔ Processed 194175/202599 images
#    ✔ Processed 194200/202599 images
#    ✔ Processed 194225/202599 images
#    ✔ Processed 194250/202599 images
#    ✔ Processed 194275/202599 images
#    ✔ Processed 194300/202599 images
#    ✔ Processed 194325/202599 images
#    ✔ Processed 194350/202599 images
#    ✔ Processed 194375/202599 images
#    ✔ Processed 194400/202599 images
#    ✔ Processed 194425/202599 images
#    ✔ Processed 194450/202599 images
#    ✔ Processed 194475/202599 images
#    ✔ Processed 194500/202599 images
#    ✔ Processed 194525/202599 images
#    ✔ Processed 194550/202599 images
#    ✔ Processed 194575/202599 images
#    ✔ Processed 194600/202599 images
#    ✔ Processed 194625/202599 images
#    ✔ Processed 194650/202599 images
#    ✔ Processed 194675/202599 images
#    ✔ Processed 194700/202599 images
#    ✔ Processed 194725/202599 images
#    ✔ Processed 194750/202599 images
#    ✔ Processed 194775/202599 images
#    ✔ Processed 194800/202599 images
#    ✔ Processed 194825/202599 images
#    ✔ Processed 194850/202599 images
#    ✔ Processed 194875/202599 images
#    ✔ Processed 194900/202599 images
#    ✔ Processed 194925/202599 images
#    ✔ Processed 194950/202599 images
#    ✔ Processed 194975/202599 images
#    ✔ Processed 195000/202599 images
#    ✔ Processed 195025/202599 images
#    ✔ Processed 195050/202599 images
#    ✔ Processed 195075/202599 images
#    ✔ Processed 195100/202599 images
#    ✔ Processed 195125/202599 images
#    ✔ Processed 195150/202599 images
#    ✔ Processed 195175/202599 images
#    ✔ Processed 195200/202599 images
#    ✔ Processed 195225/202599 images
#    ✔ Processed 195250/202599 images
#    ✔ Processed 195275/202599 images
#    ✔ Processed 195300/202599 images
#    ✔ Processed 195325/202599 images
#    ✔ Processed 195350/202599 images
#    ✔ Processed 195375/202599 images
#    ✔ Processed 195400/202599 images
#    ✔ Processed 195425/202599 images
#    ✔ Processed 195450/202599 images
#    ✔ Processed 195475/202599 images
#    ✔ Processed 195500/202599 images
#    ✔ Processed 195525/202599 images
#    ✔ Processed 195550/202599 images
#    ✔ Processed 195575/202599 images
#    ✔ Processed 195600/202599 images
#    ✔ Processed 195625/202599 images
#    ✔ Processed 195650/202599 images
#    ✔ Processed 195675/202599 images
#    ✔ Processed 195700/202599 images
#    ✔ Processed 195725/202599 images
#    ✔ Processed 195750/202599 images
#    ✔ Processed 195775/202599 images
#    ✔ Processed 195800/202599 images
#    ✔ Processed 195825/202599 images
#    ✔ Processed 195850/202599 images
#    ✔ Processed 195875/202599 images
#    ✔ Processed 195900/202599 images
#    ✔ Processed 195925/202599 images
#    ✔ Processed 195950/202599 images
#    ✔ Processed 195975/202599 images
#    ✔ Processed 196000/202599 images
#    ✔ Processed 196025/202599 images
#    ✔ Processed 196050/202599 images
#    ✔ Processed 196075/202599 images
#    ✔ Processed 196100/202599 images
#    ✔ Processed 196125/202599 images
#    ✔ Processed 196150/202599 images
#    ✔ Processed 196175/202599 images
#    ✔ Processed 196200/202599 images
#    ✔ Processed 196225/202599 images
#    ✔ Processed 196250/202599 images
#    ✔ Processed 196275/202599 images
#    ✔ Processed 196300/202599 images
#    ✔ Processed 196325/202599 images
#    ✔ Processed 196350/202599 images
#    ✔ Processed 196375/202599 images
#    ✔ Processed 196400/202599 images
#    ✔ Processed 196425/202599 images
#    ✔ Processed 196450/202599 images
#    ✔ Processed 196475/202599 images
#    ✔ Processed 196500/202599 images
#    ✔ Processed 196525/202599 images
#    ✔ Processed 196550/202599 images
#    ✔ Processed 196575/202599 images
#    ✔ Processed 196600/202599 images
#    ✔ Processed 196625/202599 images
#    ✔ Processed 196650/202599 images
#    ✔ Processed 196675/202599 images
#    ✔ Processed 196700/202599 images
#    ✔ Processed 196725/202599 images
#    ✔ Processed 196750/202599 images
#    ✔ Processed 196775/202599 images
#    ✔ Processed 196800/202599 images
#    ✔ Processed 196825/202599 images
#    ✔ Processed 196850/202599 images
#    ✔ Processed 196875/202599 images
#    ✔ Processed 196900/202599 images
#    ✔ Processed 196925/202599 images
#    ✔ Processed 196950/202599 images
#    ✔ Processed 196975/202599 images
#    ✔ Processed 197000/202599 images
#    ✔ Processed 197025/202599 images
#    ✔ Processed 197050/202599 images
#    ✔ Processed 197075/202599 images
#    ✔ Processed 197100/202599 images
#    ✔ Processed 197125/202599 images
#    ✔ Processed 197150/202599 images
#    ✔ Processed 197175/202599 images
#    ✔ Processed 197200/202599 images
#    ✔ Processed 197225/202599 images
#    ✔ Processed 197250/202599 images
#    ✔ Processed 197275/202599 images
#    ✔ Processed 197300/202599 images
#    ✔ Processed 197325/202599 images
#    ✔ Processed 197350/202599 images
#    ✔ Processed 197375/202599 images
#    ✔ Processed 197400/202599 images
#    ✔ Processed 197425/202599 images
#    ✔ Processed 197450/202599 images
#    ✔ Processed 197475/202599 images
#    ✔ Processed 197500/202599 images
#    ✔ Processed 197525/202599 images
#    ✔ Processed 197550/202599 images
#    ✔ Processed 197575/202599 images
#    ✔ Processed 197600/202599 images
#    ✔ Processed 197625/202599 images
#    ✔ Processed 197650/202599 images
#    ✔ Processed 197675/202599 images
#    ✔ Processed 197700/202599 images
#    ✔ Processed 197725/202599 images
#    ✔ Processed 197750/202599 images
#    ✔ Processed 197775/202599 images
#    ✔ Processed 197800/202599 images
#    ✔ Processed 197825/202599 images
#    ✔ Processed 197850/202599 images
#    ✔ Processed 197875/202599 images
#    ✔ Processed 197900/202599 images
#    ✔ Processed 197925/202599 images
#    ✔ Processed 197950/202599 images
#    ✔ Processed 197975/202599 images
#    ✔ Processed 198000/202599 images
#    ✔ Processed 198025/202599 images
#    ✔ Processed 198050/202599 images
#    ✔ Processed 198075/202599 images
#    ✔ Processed 198100/202599 images
#    ✔ Processed 198125/202599 images
#    ✔ Processed 198150/202599 images
#    ✔ Processed 198175/202599 images
#    ✔ Processed 198200/202599 images
#    ✔ Processed 198225/202599 images
#    ✔ Processed 198250/202599 images
#    ✔ Processed 198275/202599 images
#    ✔ Processed 198300/202599 images
#    ✔ Processed 198325/202599 images
#    ✔ Processed 198350/202599 images
#    ✔ Processed 198375/202599 images
#    ✔ Processed 198400/202599 images
#    ✔ Processed 198425/202599 images
#    ✔ Processed 198450/202599 images
#    ✔ Processed 198475/202599 images
#    ✔ Processed 198500/202599 images
#    ✔ Processed 198525/202599 images
#    ✔ Processed 198550/202599 images
#    ✔ Processed 198575/202599 images
#    ✔ Processed 198600/202599 images
#    ✔ Processed 198625/202599 images
#    ✔ Processed 198650/202599 images
#    ✔ Processed 198675/202599 images
#    ✔ Processed 198700/202599 images
#    ✔ Processed 198725/202599 images
#    ✔ Processed 198750/202599 images
#    ✔ Processed 198775/202599 images
#    ✔ Processed 198800/202599 images
#    ✔ Processed 198825/202599 images
#    ✔ Processed 198850/202599 images
#    ✔ Processed 198875/202599 images
#    ✔ Processed 198900/202599 images
#    ✔ Processed 198925/202599 images
#    ✔ Processed 198950/202599 images
#    ✔ Processed 198975/202599 images
#    ✔ Processed 199000/202599 images
#    ✔ Processed 199025/202599 images
#    ✔ Processed 199050/202599 images
#    ✔ Processed 199075/202599 images
#    ✔ Processed 199100/202599 images
#    ✔ Processed 199125/202599 images
#    ✔ Processed 199150/202599 images
#    ✔ Processed 199175/202599 images
#    ✔ Processed 199200/202599 images
#    ✔ Processed 199225/202599 images
#    ✔ Processed 199250/202599 images
#    ✔ Processed 199275/202599 images
#    ✔ Processed 199300/202599 images
#    ✔ Processed 199325/202599 images
#    ✔ Processed 199350/202599 images
#    ✔ Processed 199375/202599 images
#    ✔ Processed 199400/202599 images
#    ✔ Processed 199425/202599 images
#    ✔ Processed 199450/202599 images
#    ✔ Processed 199475/202599 images
#    ✔ Processed 199500/202599 images
#    ✔ Processed 199525/202599 images
#    ✔ Processed 199550/202599 images
#    ✔ Processed 199575/202599 images
#    ✔ Processed 199600/202599 images
#    ✔ Processed 199625/202599 images
#    ✔ Processed 199650/202599 images
#    ✔ Processed 199675/202599 images
#    ✔ Processed 199700/202599 images
#    ✔ Processed 199725/202599 images
#    ✔ Processed 199750/202599 images
#    ✔ Processed 199775/202599 images
#    ✔ Processed 199800/202599 images
#    ✔ Processed 199825/202599 images
#    ✔ Processed 199850/202599 images
#    ✔ Processed 199875/202599 images
#    ✔ Processed 199900/202599 images
#    ✔ Processed 199925/202599 images
#    ✔ Processed 199950/202599 images
#    ✔ Processed 199975/202599 images
#    ✔ Processed 200000/202599 images
#    ✔ Processed 200025/202599 images
#    ✔ Processed 200050/202599 images
#    ✔ Processed 200075/202599 images
#    ✔ Processed 200100/202599 images
#    ✔ Processed 200125/202599 images
#    ✔ Processed 200150/202599 images
#    ✔ Processed 200175/202599 images
#    ✔ Processed 200200/202599 images
#    ✔ Processed 200225/202599 images
#    ✔ Processed 200250/202599 images
#    ✔ Processed 200275/202599 images
#    ✔ Processed 200300/202599 images
#    ✔ Processed 200325/202599 images
#    ✔ Processed 200350/202599 images
#    ✔ Processed 200375/202599 images
#    ✔ Processed 200400/202599 images
#    ✔ Processed 200425/202599 images
#    ✔ Processed 200450/202599 images
#    ✔ Processed 200475/202599 images
#    ✔ Processed 200500/202599 images
#    ✔ Processed 200525/202599 images
#    ✔ Processed 200550/202599 images
#    ✔ Processed 200575/202599 images
#    ✔ Processed 200600/202599 images
#    ✔ Processed 200625/202599 images
#    ✔ Processed 200650/202599 images
#    ✔ Processed 200675/202599 images
#    ✔ Processed 200700/202599 images
#    ✔ Processed 200725/202599 images
#    ✔ Processed 200750/202599 images
#    ✔ Processed 200775/202599 images
#    ✔ Processed 200800/202599 images
#    ✔ Processed 200825/202599 images
#    ✔ Processed 200850/202599 images
#    ✔ Processed 200875/202599 images
#    ✔ Processed 200900/202599 images
#    ✔ Processed 200925/202599 images
#    ✔ Processed 200950/202599 images
#    ✔ Processed 200975/202599 images
#    ✔ Processed 201000/202599 images
#    ✔ Processed 201025/202599 images
#    ✔ Processed 201050/202599 images
#    ✔ Processed 201075/202599 images
#    ✔ Processed 201100/202599 images
#    ✔ Processed 201125/202599 images
#    ✔ Processed 201150/202599 images
#    ✔ Processed 201175/202599 images
#    ✔ Processed 201200/202599 images
#    ✔ Processed 201225/202599 images
#    ✔ Processed 201250/202599 images
#    ✔ Processed 201275/202599 images
#    ✔ Processed 201300/202599 images
#    ✔ Processed 201325/202599 images
#    ✔ Processed 201350/202599 images
#    ✔ Processed 201375/202599 images
#    ✔ Processed 201400/202599 images
#    ✔ Processed 201425/202599 images
#    ✔ Processed 201450/202599 images
#    ✔ Processed 201475/202599 images
#    ✔ Processed 201500/202599 images
#    ✔ Processed 201525/202599 images
#    ✔ Processed 201550/202599 images
#    ✔ Processed 201575/202599 images
#    ✔ Processed 201600/202599 images
#    ✔ Processed 201625/202599 images
#    ✔ Processed 201650/202599 images
#    ✔ Processed 201675/202599 images
#    ✔ Processed 201700/202599 images
#    ✔ Processed 201725/202599 images
#    ✔ Processed 201750/202599 images
#    ✔ Processed 201775/202599 images
#    ✔ Processed 201800/202599 images
#    ✔ Processed 201825/202599 images
#    ✔ Processed 201850/202599 images
#    ✔ Processed 201875/202599 images
#    ✔ Processed 201900/202599 images
#    ✔ Processed 201925/202599 images
#    ✔ Processed 201950/202599 images
#    ✔ Processed 201975/202599 images
#    ✔ Processed 202000/202599 images
#    ✔ Processed 202025/202599 images
#    ✔ Processed 202050/202599 images
#    ✔ Processed 202075/202599 images
#    ✔ Processed 202100/202599 images
#    ✔ Processed 202125/202599 images
#    ✔ Processed 202150/202599 images
#    ✔ Processed 202175/202599 images
#    ✔ Processed 202200/202599 images
#    ✔ Processed 202225/202599 images
#    ✔ Processed 202250/202599 images
#    ✔ Processed 202275/202599 images
#    ✔ Processed 202300/202599 images
#    ✔ Processed 202325/202599 images
#    ✔ Processed 202350/202599 images
#    ✔ Processed 202375/202599 images
#    ✔ Processed 202400/202599 images
#    ✔ Processed 202425/202599 images
#    ✔ Processed 202450/202599 images
#    ✔ Processed 202475/202599 images
#    ✔ Processed 202500/202599 images
#    ✔ Processed 202525/202599 images
#    ✔ Processed 202550/202599 images
#    ✔ Processed 202575/202599 images
#    ✔ Processed 202599/202599 images
#
# 📦 EMBEDDINGS SAVED!
#    • File: /content/celeba_arcface_512d_embeddings.npz
#    • Num embeddings: 202599
#    • Embedding dimension: 512
#
# ============================================================
# === DOWNLOADING EMBEDDING FILES TO YOUR COMPUTER ===
# ============================================================
# 📥 LFW 512-D embeddings: lfw_arcface_512d_embeddings_20251128_192651.npz
# 📥 CelebA 512-D embeddings: celeba_arcface_512d_embeddings_20251128_192651.npz
#
# 🎉 DONE! You now have:
#    • lfw_arcface_512d_embeddings_YYYYMMDD_HHMMSS.npz
#    • celeba_arcface_512d_embeddings_YYYYMMDD_HHMMSS.npz
# Each file contains:
#    • 'filenames'  → image file names
#    • 'embeddings' → 512-D ArcFace feature vectors

# %%
# === EXTRA: 512-D FACE EMBEDDING EXTRACTION (INFERENCE MODE) ===

print("=== DEFINING EMBEDDING EXTRACTION FUNCTION ===")

def generate_arcface_embeddings(backbone, image_root, model_name="Model",
                                limit_images=None, output_prefix=None):
    """
    Uses the trained backbone (ResNet-50 + 512-D FC) to:
      - Load all images from image_root
      - Resize + normalize (same as training)
      - Extract 512-D L2-normalized embeddings
      - Save to a .npz file: filenames + embeddings
    """
    import glob  # just in case

    if backbone is None:
        print(f" {model_name} backbone is None. Train the model first.")
        return None

    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    backbone = backbone.to(device)
    backbone.eval()

    print("\n" + "="*60)
    print(f" GENERATING 512-D EMBEDDINGS FOR: {model_name}")
    print("="*60)
    print(f" Image root: {image_root}")
    print(f" Device: {device}")

    # Same transforms as training
    transform = transforms.Compose([
        transforms.Resize((112, 112)),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5],
                             [0.5, 0.5, 0.5])
    ])

    # Collect image files (jpg / jpeg / png)
    image_files = []
    for ext in ["*.jpg", "*.jpeg", "*.png"]:
        pattern = os.path.join(image_root, "**", ext)
        image_files.extend(glob.glob(pattern, recursive=True))

    image_files = sorted(image_files)

    if not image_files:
        print(" No images found for embedding extraction.")
        return None

    if limit_images is not None:
        image_files = image_files[:limit_images]
        print(f"⚠ Limiting to first {len(image_files)} images for speed.")

    print(f" Total images to process: {len(image_files)}")

    embeddings = []
    filenames = []

    with torch.no_grad():
        for idx, img_path in enumerate(image_files):
            try:
                img = Image.open(img_path).convert("RGB")
                img_t = transform(img).unsqueeze(0).to(device)

                # Forward through backbone -> (1, 512)
                feat = backbone(img_t)

                # L2 normalize (common for ArcFace embeddings)
                feat = nn.functional.normalize(feat, p=2, dim=1)

                embeddings.append(feat.squeeze(0).cpu().numpy())
                filenames.append(os.path.basename(img_path))

                # Progress log
                if (idx + 1) % 25 == 0 or (idx + 1) == len(image_files):
                    print(f"   ✔ Processed {idx+1}/{len(image_files)} images")
            except Exception as e:
                print(f"   ⚠ Error processing {img_path}: {e}")

    if len(embeddings) == 0:
        print(" No embeddings were generated.")
        return None

    embeddings = np.stack(embeddings, axis=0)

    if output_prefix is None:
        output_prefix = model_name.lower()

    out_path = f"/content/{output_prefix}_arcface_512d_embeddings.npz"

    # Save filenames + embeddings
    np.savez(out_path,
             filenames=np.array(filenames),
             embeddings=embeddings)

    print("\n EMBEDDINGS SAVED!")
    print(f"   • File: {out_path}")
    print(f"   • Num embeddings: {embeddings.shape[0]}")
    print(f"   • Embedding dimension: {embeddings.shape[1]}")
    return out_path

print(" Embedding extraction function defined!")
# Out:
# === DEFINING EMBEDDING EXTRACTION FUNCTION ===
#  Embedding extraction function defined!

# %%
# === EXTRA: RUN EMBEDDING EXTRACTION + DOWNLOAD FILES ===

print("=== STARTING 512-D EMBEDDING EXTRACTION FOR BOTH DATASETS ===")

lfw_embeddings_file = generate_arcface_embeddings(
    backbone=lfw_backbone,
    image_root=LFW_ROOT,
    model_name="LFW",
    limit_images=None,          # put 100 if you want it faster
    output_prefix="lfw"
)

celeba_embeddings_file = generate_arcface_embeddings(
    backbone=celeba_backbone,
    image_root=CELEBA_IMG_ROOT,
    model_name="CelebA",
    limit_images=None,          # e.g. 200 for speed
    output_prefix="celeba"
)

print("\n" + "="*60)
print("=== DOWNLOADING EMBEDDING FILES TO YOUR COMPUTER ===")
print("="*60)

if lfw_embeddings_file is not None:
    download_with_timestamp(lfw_embeddings_file, "LFW 512-D embeddings")

if celeba_embeddings_file is not None:
    download_with_timestamp(celeba_embeddings_file, "CelebA 512-D embeddings")

print("\n DONE! You now have:")
print("   • lfw_arcface_512d_embeddings_YYYYMMDD_HHMMSS.npz")
print("   • celeba_arcface_512d_embeddings_YYYYMMDD_HHMMSS.npz")
print("Each file contains:")
print("   • 'filenames'  → image file names")
print("   • 'embeddings' → 512-D ArcFace feature vectors")
# Out:
# Streaming output truncated to the last 5000 lines.
#    ✔ Processed 77850/202599 images
#    ✔ Processed 77875/202599 images
#    ✔ Processed 77900/202599 images
#    ✔ Processed 77925/202599 images
#    ✔ Processed 77950/202599 images
#    ✔ Processed 77975/202599 images
#    ✔ Processed 78000/202599 images
#    ✔ Processed 78025/202599 images
#    ✔ Processed 78050/202599 images
#    ✔ Processed 78075/202599 images
#    ✔ Processed 78100/202599 images
#    ✔ Processed 78125/202599 images
#    ✔ Processed 78150/202599 images
#    ✔ Processed 78175/202599 images
#    ✔ Processed 78200/202599 images
#    ✔ Processed 78225/202599 images
#    ✔ Processed 78250/202599 images
#    ✔ Processed 78275/202599 images
#    ✔ Processed 78300/202599 images
#    ✔ Processed 78325/202599 images
#    ✔ Processed 78350/202599 images
#    ✔ Processed 78375/202599 images
#    ✔ Processed 78400/202599 images
#    ✔ Processed 78425/202599 images
#    ✔ Processed 78450/202599 images
#    ✔ Processed 78475/202599 images
#    ✔ Processed 78500/202599 images
#    ✔ Processed 78525/202599 images
#    ✔ Processed 78550/202599 images
#    ✔ Processed 78575/202599 images
#    ✔ Processed 78600/202599 images
#    ✔ Processed 78625/202599 images
#    ✔ Processed 78650/202599 images
#    ✔ Processed 78675/202599 images
#    ✔ Processed 78700/202599 images
#    ✔ Processed 78725/202599 images
#    ✔ Processed 78750/202599 images
#    ✔ Processed 78775/202599 images
#    ✔ Processed 78800/202599 images
#    ✔ Processed 78825/202599 images
#    ✔ Processed 78850/202599 images
#    ✔ Processed 78875/202599 images
#    ✔ Processed 78900/202599 images
#    ✔ Processed 78925/202599 images
#    ✔ Processed 78950/202599 images
#    ✔ Processed 78975/202599 images
#    ✔ Processed 79000/202599 images
#    ✔ Processed 79025/202599 images
#    ✔ Processed 79050/202599 images
#    ✔ Processed 79075/202599 images
#    ✔ Processed 79100/202599 images
#    ✔ Processed 79125/202599 images
#    ✔ Processed 79150/202599 images
#    ✔ Processed 79175/202599 images
#    ✔ Processed 79200/202599 images
#    ✔ Processed 79225/202599 images
#    ✔ Processed 79250/202599 images
#    ✔ Processed 79275/202599 images
#    ✔ Processed 79300/202599 images
#    ✔ Processed 79325/202599 images
#    ✔ Processed 79350/202599 images
#    ✔ Processed 79375/202599 images
#    ✔ Processed 79400/202599 images
#    ✔ Processed 79425/202599 images
#    ✔ Processed 79450/202599 images
#    ✔ Processed 79475/202599 images
#    ✔ Processed 79500/202599 images
#    ✔ Processed 79525/202599 images
#    ✔ Processed 79550/202599 images
#    ✔ Processed 79575/202599 images
#    ✔ Processed 79600/202599 images
#    ✔ Processed 79625/202599 images
#    ✔ Processed 79650/202599 images
#    ✔ Processed 79675/202599 images
#    ✔ Processed 79700/202599 images
#    ✔ Processed 79725/202599 images
#    ✔ Processed 79750/202599 images
#    ✔ Processed 79775/202599 images
#    ✔ Processed 79800/202599 images
#    ✔ Processed 79825/202599 images
#    ✔ Processed 79850/202599 images
#    ✔ Processed 79875/202599 images
#    ✔ Processed 79900/202599 images
#    ✔ Processed 79925/202599 images
#    ✔ Processed 79950/202599 images
#    ✔ Processed 79975/202599 images
#    ✔ Processed 80000/202599 images
#    ✔ Processed 80025/202599 images
#    ✔ Processed 80050/202599 images
#    ✔ Processed 80075/202599 images
#    ✔ Processed 80100/202599 images
#    ✔ Processed 80125/202599 images
#    ✔ Processed 80150/202599 images
#    ✔ Processed 80175/202599 images
#    ✔ Processed 80200/202599 images
#    ✔ Processed 80225/202599 images
#    ✔ Processed 80250/202599 images
#    ✔ Processed 80275/202599 images
#    ✔ Processed 80300/202599 images
#    ✔ Processed 80325/202599 images
#    ✔ Processed 80350/202599 images
#    ✔ Processed 80375/202599 images
#    ✔ Processed 80400/202599 images
#    ✔ Processed 80425/202599 images
#    ✔ Processed 80450/202599 images
#    ✔ Processed 80475/202599 images
#    ✔ Processed 80500/202599 images
#    ✔ Processed 80525/202599 images
#    ✔ Processed 80550/202599 images
#    ✔ Processed 80575/202599 images
#    ✔ Processed 80600/202599 images
#    ✔ Processed 80625/202599 images
#    ✔ Processed 80650/202599 images
#    ✔ Processed 80675/202599 images
#    ✔ Processed 80700/202599 images
#    ✔ Processed 80725/202599 images
#    ✔ Processed 80750/202599 images
#    ✔ Processed 80775/202599 images
#    ✔ Processed 80800/202599 images
#    ✔ Processed 80825/202599 images
#    ✔ Processed 80850/202599 images
#    ✔ Processed 80875/202599 images
#    ✔ Processed 80900/202599 images
#    ✔ Processed 80925/202599 images
#    ✔ Processed 80950/202599 images
#    ✔ Processed 80975/202599 images
#    ✔ Processed 81000/202599 images
#    ✔ Processed 81025/202599 images
#    ✔ Processed 81050/202599 images
#    ✔ Processed 81075/202599 images
#    ✔ Processed 81100/202599 images
#    ✔ Processed 81125/202599 images
#    ✔ Processed 81150/202599 images
#    ✔ Processed 81175/202599 images
#    ✔ Processed 81200/202599 images
#    ✔ Processed 81225/202599 images
#    ✔ Processed 81250/202599 images
#    ✔ Processed 81275/202599 images
#    ✔ Processed 81300/202599 images
#    ✔ Processed 81325/202599 images
#    ✔ Processed 81350/202599 images
#    ✔ Processed 81375/202599 images
#    ✔ Processed 81400/202599 images
#    ✔ Processed 81425/202599 images
#    ✔ Processed 81450/202599 images
#    ✔ Processed 81475/202599 images
#    ✔ Processed 81500/202599 images
#    ✔ Processed 81525/202599 images
#    ✔ Processed 81550/202599 images
#    ✔ Processed 81575/202599 images
#    ✔ Processed 81600/202599 images
#    ✔ Processed 81625/202599 images
#    ✔ Processed 81650/202599 images
#    ✔ Processed 81675/202599 images
#    ✔ Processed 81700/202599 images
#    ✔ Processed 81725/202599 images
#    ✔ Processed 81750/202599 images
#    ✔ Processed 81775/202599 images
#    ✔ Processed 81800/202599 images
#    ✔ Processed 81825/202599 images
#    ✔ Processed 81850/202599 images
#    ✔ Processed 81875/202599 images
#    ✔ Processed 81900/202599 images
#    ✔ Processed 81925/202599 images
#    ✔ Processed 81950/202599 images
#    ✔ Processed 81975/202599 images
#    ✔ Processed 82000/202599 images
#    ✔ Processed 82025/202599 images
#    ✔ Processed 82050/202599 images
#    ✔ Processed 82075/202599 images
#    ✔ Processed 82100/202599 images
#    ✔ Processed 82125/202599 images
#    ✔ Processed 82150/202599 images
#    ✔ Processed 82175/202599 images
#    ✔ Processed 82200/202599 images
#    ✔ Processed 82225/202599 images
#    ✔ Processed 82250/202599 images
#    ✔ Processed 82275/202599 images
#    ✔ Processed 82300/202599 images
#    ✔ Processed 82325/202599 images
#    ✔ Processed 82350/202599 images
#    ✔ Processed 82375/202599 images
#    ✔ Processed 82400/202599 images
#    ✔ Processed 82425/202599 images
#    ✔ Processed 82450/202599 images
#    ✔ Processed 82475/202599 images
#    ✔ Processed 82500/202599 images
#    ✔ Processed 82525/202599 images
#    ✔ Processed 82550/202599 images
#    ✔ Processed 82575/202599 images
#    ✔ Processed 82600/202599 images
#    ✔ Processed 82625/202599 images
#    ✔ Processed 82650/202599 images
#    ✔ Processed 82675/202599 images
#    ✔ Processed 82700/202599 images
#    ✔ Processed 82725/202599 images
#    ✔ Processed 82750/202599 images
#    ✔ Processed 82775/202599 images
#    ✔ Processed 82800/202599 images
#    ✔ Processed 82825/202599 images
#    ✔ Processed 82850/202599 images
#    ✔ Processed 82875/202599 images
#    ✔ Processed 82900/202599 images
#    ✔ Processed 82925/202599 images
#    ✔ Processed 82950/202599 images
#    ✔ Processed 82975/202599 images
#    ✔ Processed 83000/202599 images
#    ✔ Processed 83025/202599 images
#    ✔ Processed 83050/202599 images
#    ✔ Processed 83075/202599 images
#    ✔ Processed 83100/202599 images
#    ✔ Processed 83125/202599 images
#    ✔ Processed 83150/202599 images
#    ✔ Processed 83175/202599 images
#    ✔ Processed 83200/202599 images
#    ✔ Processed 83225/202599 images
#    ✔ Processed 83250/202599 images
#    ✔ Processed 83275/202599 images
#    ✔ Processed 83300/202599 images
#    ✔ Processed 83325/202599 images
#    ✔ Processed 83350/202599 images
#    ✔ Processed 83375/202599 images
#    ✔ Processed 83400/202599 images
#    ✔ Processed 83425/202599 images
#    ✔ Processed 83450/202599 images
#    ✔ Processed 83475/202599 images
#    ✔ Processed 83500/202599 images
#    ✔ Processed 83525/202599 images
#    ✔ Processed 83550/202599 images
#    ✔ Processed 83575/202599 images
#    ✔ Processed 83600/202599 images
#    ✔ Processed 83625/202599 images
#    ✔ Processed 83650/202599 images
#    ✔ Processed 83675/202599 images
#    ✔ Processed 83700/202599 images
#    ✔ Processed 83725/202599 images
#    ✔ Processed 83750/202599 images
#    ✔ Processed 83775/202599 images
#    ✔ Processed 83800/202599 images
#    ✔ Processed 83825/202599 images
#    ✔ Processed 83850/202599 images
#    ✔ Processed 83875/202599 images
#    ✔ Processed 83900/202599 images
#    ✔ Processed 83925/202599 images
#    ✔ Processed 83950/202599 images
#    ✔ Processed 83975/202599 images
#    ✔ Processed 84000/202599 images
#    ✔ Processed 84025/202599 images
#    ✔ Processed 84050/202599 images
#    ✔ Processed 84075/202599 images
#    ✔ Processed 84100/202599 images
#    ✔ Processed 84125/202599 images
#    ✔ Processed 84150/202599 images
#    ✔ Processed 84175/202599 images
#    ✔ Processed 84200/202599 images
#    ✔ Processed 84225/202599 images
#    ✔ Processed 84250/202599 images
#    ✔ Processed 84275/202599 images
#    ✔ Processed 84300/202599 images
#    ✔ Processed 84325/202599 images
#    ✔ Processed 84350/202599 images
#    ✔ Processed 84375/202599 images
#    ✔ Processed 84400/202599 images
#    ✔ Processed 84425/202599 images
#    ✔ Processed 84450/202599 images
#    ✔ Processed 84475/202599 images
#    ✔ Processed 84500/202599 images
#    ✔ Processed 84525/202599 images
#    ✔ Processed 84550/202599 images
#    ✔ Processed 84575/202599 images
#    ✔ Processed 84600/202599 images
#    ✔ Processed 84625/202599 images
#    ✔ Processed 84650/202599 images
#    ✔ Processed 84675/202599 images
#    ✔ Processed 84700/202599 images
#    ✔ Processed 84725/202599 images
#    ✔ Processed 84750/202599 images
#    ✔ Processed 84775/202599 images
#    ✔ Processed 84800/202599 images
#    ✔ Processed 84825/202599 images
#    ✔ Processed 84850/202599 images
#    ✔ Processed 84875/202599 images
#    ✔ Processed 84900/202599 images
#    ✔ Processed 84925/202599 images
#    ✔ Processed 84950/202599 images
#    ✔ Processed 84975/202599 images
#    ✔ Processed 85000/202599 images
#    ✔ Processed 85025/202599 images
#    ✔ Processed 85050/202599 images
#    ✔ Processed 85075/202599 images
#    ✔ Processed 85100/202599 images
#    ✔ Processed 85125/202599 images
#    ✔ Processed 85150/202599 images
#    ✔ Processed 85175/202599 images
#    ✔ Processed 85200/202599 images
#    ✔ Processed 85225/202599 images
#    ✔ Processed 85250/202599 images
#    ✔ Processed 85275/202599 images
#    ✔ Processed 85300/202599 images
#    ✔ Processed 85325/202599 images
#    ✔ Processed 85350/202599 images
#    ✔ Processed 85375/202599 images
#    ✔ Processed 85400/202599 images
#    ✔ Processed 85425/202599 images
#    ✔ Processed 85450/202599 images
#    ✔ Processed 85475/202599 images
#    ✔ Processed 85500/202599 images
#    ✔ Processed 85525/202599 images
#    ✔ Processed 85550/202599 images
#    ✔ Processed 85575/202599 images
#    ✔ Processed 85600/202599 images
#    ✔ Processed 85625/202599 images
#    ✔ Processed 85650/202599 images
#    ✔ Processed 85675/202599 images
#    ✔ Processed 85700/202599 images
#    ✔ Processed 85725/202599 images
#    ✔ Processed 85750/202599 images
#    ✔ Processed 85775/202599 images
#    ✔ Processed 85800/202599 images
#    ✔ Processed 85825/202599 images
#    ✔ Processed 85850/202599 images
#    ✔ Processed 85875/202599 images
#    ✔ Processed 85900/202599 images
#    ✔ Processed 85925/202599 images
#    ✔ Processed 85950/202599 images
#    ✔ Processed 85975/202599 images
#    ✔ Processed 86000/202599 images
#    ✔ Processed 86025/202599 images
#    ✔ Processed 86050/202599 images
#    ✔ Processed 86075/202599 images
#    ✔ Processed 86100/202599 images
#    ✔ Processed 86125/202599 images
#    ✔ Processed 86150/202599 images
#    ✔ Processed 86175/202599 images
#    ✔ Processed 86200/202599 images
#    ✔ Processed 86225/202599 images
#    ✔ Processed 86250/202599 images
#    ✔ Processed 86275/202599 images
#    ✔ Processed 86300/202599 images
#    ✔ Processed 86325/202599 images
#    ✔ Processed 86350/202599 images
#    ✔ Processed 86375/202599 images
#    ✔ Processed 86400/202599 images
#    ✔ Processed 86425/202599 images
#    ✔ Processed 86450/202599 images
#    ✔ Processed 86475/202599 images
#    ✔ Processed 86500/202599 images
#    ✔ Processed 86525/202599 images
#    ✔ Processed 86550/202599 images
#    ✔ Processed 86575/202599 images
#    ✔ Processed 86600/202599 images
#    ✔ Processed 86625/202599 images
#    ✔ Processed 86650/202599 images
#    ✔ Processed 86675/202599 images
#    ✔ Processed 86700/202599 images
#    ✔ Processed 86725/202599 images
#    ✔ Processed 86750/202599 images
#    ✔ Processed 86775/202599 images
#    ✔ Processed 86800/202599 images
#    ✔ Processed 86825/202599 images
#    ✔ Processed 86850/202599 images
#    ✔ Processed 86875/202599 images
#    ✔ Processed 86900/202599 images
#    ✔ Processed 86925/202599 images
#    ✔ Processed 86950/202599 images
#    ✔ Processed 86975/202599 images
#    ✔ Processed 87000/202599 images
#    ✔ Processed 87025/202599 images
#    ✔ Processed 87050/202599 images
#    ✔ Processed 87075/202599 images
#    ✔ Processed 87100/202599 images
#    ✔ Processed 87125/202599 images
#    ✔ Processed 87150/202599 images
#    ✔ Processed 87175/202599 images
#    ✔ Processed 87200/202599 images
#    ✔ Processed 87225/202599 images
#    ✔ Processed 87250/202599 images
#    ✔ Processed 87275/202599 images
#    ✔ Processed 87300/202599 images
#    ✔ Processed 87325/202599 images
#    ✔ Processed 87350/202599 images
#    ✔ Processed 87375/202599 images
#    ✔ Processed 87400/202599 images
#    ✔ Processed 87425/202599 images
#    ✔ Processed 87450/202599 images
#    ✔ Processed 87475/202599 images
#    ✔ Processed 87500/202599 images
#    ✔ Processed 87525/202599 images
#    ✔ Processed 87550/202599 images
#    ✔ Processed 87575/202599 images
#    ✔ Processed 87600/202599 images
#    ✔ Processed 87625/202599 images
#    ✔ Processed 87650/202599 images
#    ✔ Processed 87675/202599 images
#    ✔ Processed 87700/202599 images
#    ✔ Processed 87725/202599 images
#    ✔ Processed 87750/202599 images
#    ✔ Processed 87775/202599 images
#    ✔ Processed 87800/202599 images
#    ✔ Processed 87825/202599 images
#    ✔ Processed 87850/202599 images
#    ✔ Processed 87875/202599 images
#    ✔ Processed 87900/202599 images
#    ✔ Processed 87925/202599 images
#    ✔ Processed 87950/202599 images
#    ✔ Processed 87975/202599 images
#    ✔ Processed 88000/202599 images
#    ✔ Processed 88025/202599 images
#    ✔ Processed 88050/202599 images
#    ✔ Processed 88075/202599 images
#    ✔ Processed 88100/202599 images
#    ✔ Processed 88125/202599 images
#    ✔ Processed 88150/202599 images
#    ✔ Processed 88175/202599 images
#    ✔ Processed 88200/202599 images
#    ✔ Processed 88225/202599 images
#    ✔ Processed 88250/202599 images
#    ✔ Processed 88275/202599 images
#    ✔ Processed 88300/202599 images
#    ✔ Processed 88325/202599 images
#    ✔ Processed 88350/202599 images
#    ✔ Processed 88375/202599 images
#    ✔ Processed 88400/202599 images
#    ✔ Processed 88425/202599 images
#    ✔ Processed 88450/202599 images
#    ✔ Processed 88475/202599 images
#    ✔ Processed 88500/202599 images
#    ✔ Processed 88525/202599 images
#    ✔ Processed 88550/202599 images
#    ✔ Processed 88575/202599 images
#    ✔ Processed 88600/202599 images
#    ✔ Processed 88625/202599 images
#    ✔ Processed 88650/202599 images
#    ✔ Processed 88675/202599 images
#    ✔ Processed 88700/202599 images
#    ✔ Processed 88725/202599 images
#    ✔ Processed 88750/202599 images
#    ✔ Processed 88775/202599 images
#    ✔ Processed 88800/202599 images
#    ✔ Processed 88825/202599 images
#    ✔ Processed 88850/202599 images
#    ✔ Processed 88875/202599 images
#    ✔ Processed 88900/202599 images
#    ✔ Processed 88925/202599 images
#    ✔ Processed 88950/202599 images
#    ✔ Processed 88975/202599 images
#    ✔ Processed 89000/202599 images
#    ✔ Processed 89025/202599 images
#    ✔ Processed 89050/202599 images
#    ✔ Processed 89075/202599 images
#    ✔ Processed 89100/202599 images
#    ✔ Processed 89125/202599 images
#    ✔ Processed 89150/202599 images
#    ✔ Processed 89175/202599 images
#    ✔ Processed 89200/202599 images
#    ✔ Processed 89225/202599 images
#    ✔ Processed 89250/202599 images
#    ✔ Processed 89275/202599 images
#    ✔ Processed 89300/202599 images
#    ✔ Processed 89325/202599 images
#    ✔ Processed 89350/202599 images
#    ✔ Processed 89375/202599 images
#    ✔ Processed 89400/202599 images
#    ✔ Processed 89425/202599 images
#    ✔ Processed 89450/202599 images
#    ✔ Processed 89475/202599 images
#    ✔ Processed 89500/202599 images
#    ✔ Processed 89525/202599 images
#    ✔ Processed 89550/202599 images
#    ✔ Processed 89575/202599 images
#    ✔ Processed 89600/202599 images
#    ✔ Processed 89625/202599 images
#    ✔ Processed 89650/202599 images
#    ✔ Processed 89675/202599 images
#    ✔ Processed 89700/202599 images
#    ✔ Processed 89725/202599 images
#    ✔ Processed 89750/202599 images
#    ✔ Processed 89775/202599 images
#    ✔ Processed 89800/202599 images
#    ✔ Processed 89825/202599 images
#    ✔ Processed 89850/202599 images
#    ✔ Processed 89875/202599 images
#    ✔ Processed 89900/202599 images
#    ✔ Processed 89925/202599 images
#    ✔ Processed 89950/202599 images
#    ✔ Processed 89975/202599 images
#    ✔ Processed 90000/202599 images
#    ✔ Processed 90025/202599 images
#    ✔ Processed 90050/202599 images
#    ✔ Processed 90075/202599 images
#    ✔ Processed 90100/202599 images
#    ✔ Processed 90125/202599 images
#    ✔ Processed 90150/202599 images
#    ✔ Processed 90175/202599 images
#    ✔ Processed 90200/202599 images
#    ✔ Processed 90225/202599 images
#    ✔ Processed 90250/202599 images
#    ✔ Processed 90275/202599 images
#    ✔ Processed 90300/202599 images
#    ✔ Processed 90325/202599 images
#    ✔ Processed 90350/202599 images
#    ✔ Processed 90375/202599 images
#    ✔ Processed 90400/202599 images
#    ✔ Processed 90425/202599 images
#    ✔ Processed 90450/202599 images
#    ✔ Processed 90475/202599 images
#    ✔ Processed 90500/202599 images
#    ✔ Processed 90525/202599 images
#    ✔ Processed 90550/202599 images
#    ✔ Processed 90575/202599 images
#    ✔ Processed 90600/202599 images
#    ✔ Processed 90625/202599 images
#    ✔ Processed 90650/202599 images
#    ✔ Processed 90675/202599 images
#    ✔ Processed 90700/202599 images
#    ✔ Processed 90725/202599 images
#    ✔ Processed 90750/202599 images
#    ✔ Processed 90775/202599 images
#    ✔ Processed 90800/202599 images
#    ✔ Processed 90825/202599 images
#    ✔ Processed 90850/202599 images
#    ✔ Processed 90875/202599 images
#    ✔ Processed 90900/202599 images
#    ✔ Processed 90925/202599 images
#    ✔ Processed 90950/202599 images
#    ✔ Processed 90975/202599 images
#    ✔ Processed 91000/202599 images
#    ✔ Processed 91025/202599 images
#    ✔ Processed 91050/202599 images
#    ✔ Processed 91075/202599 images
#    ✔ Processed 91100/202599 images
#    ✔ Processed 91125/202599 images
#    ✔ Processed 91150/202599 images
#    ✔ Processed 91175/202599 images
#    ✔ Processed 91200/202599 images
#    ✔ Processed 91225/202599 images
#    ✔ Processed 91250/202599 images
#    ✔ Processed 91275/202599 images
#    ✔ Processed 91300/202599 images
#    ✔ Processed 91325/202599 images
#    ✔ Processed 91350/202599 images
#    ✔ Processed 91375/202599 images
#    ✔ Processed 91400/202599 images
#    ✔ Processed 91425/202599 images
#    ✔ Processed 91450/202599 images
#    ✔ Processed 91475/202599 images
#    ✔ Processed 91500/202599 images
#    ✔ Processed 91525/202599 images
#    ✔ Processed 91550/202599 images
#    ✔ Processed 91575/202599 images
#    ✔ Processed 91600/202599 images
#    ✔ Processed 91625/202599 images
#    ✔ Processed 91650/202599 images
#    ✔ Processed 91675/202599 images
#    ✔ Processed 91700/202599 images
#    ✔ Processed 91725/202599 images
#    ✔ Processed 91750/202599 images
#    ✔ Processed 91775/202599 images
#    ✔ Processed 91800/202599 images
#    ✔ Processed 91825/202599 images
#    ✔ Processed 91850/202599 images
#    ✔ Processed 91875/202599 images
#    ✔ Processed 91900/202599 images
#    ✔ Processed 91925/202599 images
#    ✔ Processed 91950/202599 images
#    ✔ Processed 91975/202599 images
#    ✔ Processed 92000/202599 images
#    ✔ Processed 92025/202599 images
#    ✔ Processed 92050/202599 images
#    ✔ Processed 92075/202599 images
#    ✔ Processed 92100/202599 images
#    ✔ Processed 92125/202599 images
#    ✔ Processed 92150/202599 images
#    ✔ Processed 92175/202599 images
#    ✔ Processed 92200/202599 images
#    ✔ Processed 92225/202599 images
#    ✔ Processed 92250/202599 images
#    ✔ Processed 92275/202599 images
#    ✔ Processed 92300/202599 images
#    ✔ Processed 92325/202599 images
#    ✔ Processed 92350/202599 images
#    ✔ Processed 92375/202599 images
#    ✔ Processed 92400/202599 images
#    ✔ Processed 92425/202599 images
#    ✔ Processed 92450/202599 images
#    ✔ Processed 92475/202599 images
#    ✔ Processed 92500/202599 images
#    ✔ Processed 92525/202599 images
#    ✔ Processed 92550/202599 images
#    ✔ Processed 92575/202599 images
#    ✔ Processed 92600/202599 images
#    ✔ Processed 92625/202599 images
#    ✔ Processed 92650/202599 images
#    ✔ Processed 92675/202599 images
#    ✔ Processed 92700/202599 images
#    ✔ Processed 92725/202599 images
#    ✔ Processed 92750/202599 images
#    ✔ Processed 92775/202599 images
#    ✔ Processed 92800/202599 images
#    ✔ Processed 92825/202599 images
#    ✔ Processed 92850/202599 images
#    ✔ Processed 92875/202599 images
#    ✔ Processed 92900/202599 images
#    ✔ Processed 92925/202599 images
#    ✔ Processed 92950/202599 images
#    ✔ Processed 92975/202599 images
#    ✔ Processed 93000/202599 images
#    ✔ Processed 93025/202599 images
#    ✔ Processed 93050/202599 images
#    ✔ Processed 93075/202599 images
#    ✔ Processed 93100/202599 images
#    ✔ Processed 93125/202599 images
#    ✔ Processed 93150/202599 images
#    ✔ Processed 93175/202599 images
#    ✔ Processed 93200/202599 images
#    ✔ Processed 93225/202599 images
#    ✔ Processed 93250/202599 images
#    ✔ Processed 93275/202599 images
#    ✔ Processed 93300/202599 images
#    ✔ Processed 93325/202599 images
#    ✔ Processed 93350/202599 images
#    ✔ Processed 93375/202599 images
#    ✔ Processed 93400/202599 images
#    ✔ Processed 93425/202599 images
#    ✔ Processed 93450/202599 images
#    ✔ Processed 93475/202599 images
#    ✔ Processed 93500/202599 images
#    ✔ Processed 93525/202599 images
#    ✔ Processed 93550/202599 images
#    ✔ Processed 93575/202599 images
#    ✔ Processed 93600/202599 images
#    ✔ Processed 93625/202599 images
#    ✔ Processed 93650/202599 images
#    ✔ Processed 93675/202599 images
#    ✔ Processed 93700/202599 images
#    ✔ Processed 93725/202599 images
#    ✔ Processed 93750/202599 images
#    ✔ Processed 93775/202599 images
#    ✔ Processed 93800/202599 images
#    ✔ Processed 93825/202599 images
#    ✔ Processed 93850/202599 images
#    ✔ Processed 93875/202599 images
#    ✔ Processed 93900/202599 images
#    ✔ Processed 93925/202599 images
#    ✔ Processed 93950/202599 images
#    ✔ Processed 93975/202599 images
#    ✔ Processed 94000/202599 images
#    ✔ Processed 94025/202599 images
#    ✔ Processed 94050/202599 images
#    ✔ Processed 94075/202599 images
#    ✔ Processed 94100/202599 images
#    ✔ Processed 94125/202599 images
#    ✔ Processed 94150/202599 images
#    ✔ Processed 94175/202599 images
#    ✔ Processed 94200/202599 images
#    ✔ Processed 94225/202599 images
#    ✔ Processed 94250/202599 images
#    ✔ Processed 94275/202599 images
#    ✔ Processed 94300/202599 images
#    ✔ Processed 94325/202599 images
#    ✔ Processed 94350/202599 images
#    ✔ Processed 94375/202599 images
#    ✔ Processed 94400/202599 images
#    ✔ Processed 94425/202599 images
#    ✔ Processed 94450/202599 images
#    ✔ Processed 94475/202599 images
#    ✔ Processed 94500/202599 images
#    ✔ Processed 94525/202599 images
#    ✔ Processed 94550/202599 images
#    ✔ Processed 94575/202599 images
#    ✔ Processed 94600/202599 images
#    ✔ Processed 94625/202599 images
#    ✔ Processed 94650/202599 images
#    ✔ Processed 94675/202599 images
#    ✔ Processed 94700/202599 images
#    ✔ Processed 94725/202599 images
#    ✔ Processed 94750/202599 images
#    ✔ Processed 94775/202599 images
#    ✔ Processed 94800/202599 images
#    ✔ Processed 94825/202599 images
#    ✔ Processed 94850/202599 images
#    ✔ Processed 94875/202599 images
#    ✔ Processed 94900/202599 images
#    ✔ Processed 94925/202599 images
#    ✔ Processed 94950/202599 images
#    ✔ Processed 94975/202599 images
#    ✔ Processed 95000/202599 images
#    ✔ Processed 95025/202599 images
#    ✔ Processed 95050/202599 images
#    ✔ Processed 95075/202599 images
#    ✔ Processed 95100/202599 images
#    ✔ Processed 95125/202599 images
#    ✔ Processed 95150/202599 images
#    ✔ Processed 95175/202599 images
#    ✔ Processed 95200/202599 images
#    ✔ Processed 95225/202599 images
#    ✔ Processed 95250/202599 images
#    ✔ Processed 95275/202599 images
#    ✔ Processed 95300/202599 images
#    ✔ Processed 95325/202599 images
#    ✔ Processed 95350/202599 images
#    ✔ Processed 95375/202599 images
#    ✔ Processed 95400/202599 images
#    ✔ Processed 95425/202599 images
#    ✔ Processed 95450/202599 images
#    ✔ Processed 95475/202599 images
#    ✔ Processed 95500/202599 images
#    ✔ Processed 95525/202599 images
#    ✔ Processed 95550/202599 images
#    ✔ Processed 95575/202599 images
#    ✔ Processed 95600/202599 images
#    ✔ Processed 95625/202599 images
#    ✔ Processed 95650/202599 images
#    ✔ Processed 95675/202599 images
#    ✔ Processed 95700/202599 images
#    ✔ Processed 95725/202599 images
#    ✔ Processed 95750/202599 images
#    ✔ Processed 95775/202599 images
#    ✔ Processed 95800/202599 images
#    ✔ Processed 95825/202599 images
#    ✔ Processed 95850/202599 images
#    ✔ Processed 95875/202599 images
#    ✔ Processed 95900/202599 images
#    ✔ Processed 95925/202599 images
#    ✔ Processed 95950/202599 images
#    ✔ Processed 95975/202599 images
#    ✔ Processed 96000/202599 images
#    ✔ Processed 96025/202599 images
#    ✔ Processed 96050/202599 images
#    ✔ Processed 96075/202599 images
#    ✔ Processed 96100/202599 images
#    ✔ Processed 96125/202599 images
#    ✔ Processed 96150/202599 images
#    ✔ Processed 96175/202599 images
#    ✔ Processed 96200/202599 images
#    ✔ Processed 96225/202599 images
#    ✔ Processed 96250/202599 images
#    ✔ Processed 96275/202599 images
#    ✔ Processed 96300/202599 images
#    ✔ Processed 96325/202599 images
#    ✔ Processed 96350/202599 images
#    ✔ Processed 96375/202599 images
#    ✔ Processed 96400/202599 images
#    ✔ Processed 96425/202599 images
#    ✔ Processed 96450/202599 images
#    ✔ Processed 96475/202599 images
#    ✔ Processed 96500/202599 images
#    ✔ Processed 96525/202599 images
#    ✔ Processed 96550/202599 images
#    ✔ Processed 96575/202599 images
#    ✔ Processed 96600/202599 images
#    ✔ Processed 96625/202599 images
#    ✔ Processed 96650/202599 images
#    ✔ Processed 96675/202599 images
#    ✔ Processed 96700/202599 images
#    ✔ Processed 96725/202599 images
#    ✔ Processed 96750/202599 images
#    ✔ Processed 96775/202599 images
#    ✔ Processed 96800/202599 images
#    ✔ Processed 96825/202599 images
#    ✔ Processed 96850/202599 images
#    ✔ Processed 96875/202599 images
#    ✔ Processed 96900/202599 images
#    ✔ Processed 96925/202599 images
#    ✔ Processed 96950/202599 images
#    ✔ Processed 96975/202599 images
#    ✔ Processed 97000/202599 images
#    ✔ Processed 97025/202599 images
#    ✔ Processed 97050/202599 images
#    ✔ Processed 97075/202599 images
#    ✔ Processed 97100/202599 images
#    ✔ Processed 97125/202599 images
#    ✔ Processed 97150/202599 images
#    ✔ Processed 97175/202599 images
#    ✔ Processed 97200/202599 images
#    ✔ Processed 97225/202599 images
#    ✔ Processed 97250/202599 images
#    ✔ Processed 97275/202599 images
#    ✔ Processed 97300/202599 images
#    ✔ Processed 97325/202599 images
#    ✔ Processed 97350/202599 images
#    ✔ Processed 97375/202599 images
#    ✔ Processed 97400/202599 images
#    ✔ Processed 97425/202599 images
#    ✔ Processed 97450/202599 images
#    ✔ Processed 97475/202599 images
#    ✔ Processed 97500/202599 images
#    ✔ Processed 97525/202599 images
#    ✔ Processed 97550/202599 images
#    ✔ Processed 97575/202599 images
#    ✔ Processed 97600/202599 images
#    ✔ Processed 97625/202599 images
#    ✔ Processed 97650/202599 images
#    ✔ Processed 97675/202599 images
#    ✔ Processed 97700/202599 images
#    ✔ Processed 97725/202599 images
#    ✔ Processed 97750/202599 images
#    ✔ Processed 97775/202599 images
#    ✔ Processed 97800/202599 images
#    ✔ Processed 97825/202599 images
#    ✔ Processed 97850/202599 images
#    ✔ Processed 97875/202599 images
#    ✔ Processed 97900/202599 images
#    ✔ Processed 97925/202599 images
#    ✔ Processed 97950/202599 images
#    ✔ Processed 97975/202599 images
#    ✔ Processed 98000/202599 images
#    ✔ Processed 98025/202599 images
#    ✔ Processed 98050/202599 images
#    ✔ Processed 98075/202599 images
#    ✔ Processed 98100/202599 images
#    ✔ Processed 98125/202599 images
#    ✔ Processed 98150/202599 images
#    ✔ Processed 98175/202599 images
#    ✔ Processed 98200/202599 images
#    ✔ Processed 98225/202599 images
#    ✔ Processed 98250/202599 images
#    ✔ Processed 98275/202599 images
#    ✔ Processed 98300/202599 images
#    ✔ Processed 98325/202599 images
#    ✔ Processed 98350/202599 images
#    ✔ Processed 98375/202599 images
#    ✔ Processed 98400/202599 images
#    ✔ Processed 98425/202599 images
#    ✔ Processed 98450/202599 images
#    ✔ Processed 98475/202599 images
#    ✔ Processed 98500/202599 images
#    ✔ Processed 98525/202599 images
#    ✔ Processed 98550/202599 images
#    ✔ Processed 98575/202599 images
#    ✔ Processed 98600/202599 images
#    ✔ Processed 98625/202599 images
#    ✔ Processed 98650/202599 images
#    ✔ Processed 98675/202599 images
#    ✔ Processed 98700/202599 images
#    ✔ Processed 98725/202599 images
#    ✔ Processed 98750/202599 images
#    ✔ Processed 98775/202599 images
#    ✔ Processed 98800/202599 images
#    ✔ Processed 98825/202599 images
#    ✔ Processed 98850/202599 images
#    ✔ Processed 98875/202599 images
#    ✔ Processed 98900/202599 images
#    ✔ Processed 98925/202599 images
#    ✔ Processed 98950/202599 images
#    ✔ Processed 98975/202599 images
#    ✔ Processed 99000/202599 images
#    ✔ Processed 99025/202599 images
#    ✔ Processed 99050/202599 images
#    ✔ Processed 99075/202599 images
#    ✔ Processed 99100/202599 images
#    ✔ Processed 99125/202599 images
#    ✔ Processed 99150/202599 images
#    ✔ Processed 99175/202599 images
#    ✔ Processed 99200/202599 images
#    ✔ Processed 99225/202599 images
#    ✔ Processed 99250/202599 images
#    ✔ Processed 99275/202599 images
#    ✔ Processed 99300/202599 images
#    ✔ Processed 99325/202599 images
#    ✔ Processed 99350/202599 images
#    ✔ Processed 99375/202599 images
#    ✔ Processed 99400/202599 images
#    ✔ Processed 99425/202599 images
#    ✔ Processed 99450/202599 images
#    ✔ Processed 99475/202599 images
#    ✔ Processed 99500/202599 images
#    ✔ Processed 99525/202599 images
#    ✔ Processed 99550/202599 images
#    ✔ Processed 99575/202599 images
#    ✔ Processed 99600/202599 images
#    ✔ Processed 99625/202599 images
#    ✔ Processed 99650/202599 images
#    ✔ Processed 99675/202599 images
#    ✔ Processed 99700/202599 images
#    ✔ Processed 99725/202599 images
#    ✔ Processed 99750/202599 images
#    ✔ Processed 99775/202599 images
#    ✔ Processed 99800/202599 images
#    ✔ Processed 99825/202599 images
#    ✔ Processed 99850/202599 images
#    ✔ Processed 99875/202599 images
#    ✔ Processed 99900/202599 images
#    ✔ Processed 99925/202599 images
#    ✔ Processed 99950/202599 images
#    ✔ Processed 99975/202599 images
#    ✔ Processed 100000/202599 images
#    ✔ Processed 100025/202599 images
#    ✔ Processed 100050/202599 images
#    ✔ Processed 100075/202599 images
#    ✔ Processed 100100/202599 images
#    ✔ Processed 100125/202599 images
#    ✔ Processed 100150/202599 images
#    ✔ Processed 100175/202599 images
#    ✔ Processed 100200/202599 images
#    ✔ Processed 100225/202599 images
#    ✔ Processed 100250/202599 images
#    ✔ Processed 100275/202599 images
#    ✔ Processed 100300/202599 images
#    ✔ Processed 100325/202599 images
#    ✔ Processed 100350/202599 images
#    ✔ Processed 100375/202599 images
#    ✔ Processed 100400/202599 images
#    ✔ Processed 100425/202599 images
#    ✔ Processed 100450/202599 images
#    ✔ Processed 100475/202599 images
#    ✔ Processed 100500/202599 images
#    ✔ Processed 100525/202599 images
#    ✔ Processed 100550/202599 images
#    ✔ Processed 100575/202599 images
#    ✔ Processed 100600/202599 images
#    ✔ Processed 100625/202599 images
#    ✔ Processed 100650/202599 images
#    ✔ Processed 100675/202599 images
#    ✔ Processed 100700/202599 images
#    ✔ Processed 100725/202599 images
#    ✔ Processed 100750/202599 images
#    ✔ Processed 100775/202599 images
#    ✔ Processed 100800/202599 images
#    ✔ Processed 100825/202599 images
#    ✔ Processed 100850/202599 images
#    ✔ Processed 100875/202599 images
#    ✔ Processed 100900/202599 images
#    ✔ Processed 100925/202599 images
#    ✔ Processed 100950/202599 images
#    ✔ Processed 100975/202599 images
#    ✔ Processed 101000/202599 images
#    ✔ Processed 101025/202599 images
#    ✔ Processed 101050/202599 images
#    ✔ Processed 101075/202599 images
#    ✔ Processed 101100/202599 images
#    ✔ Processed 101125/202599 images
#    ✔ Processed 101150/202599 images
#    ✔ Processed 101175/202599 images
#    ✔ Processed 101200/202599 images
#    ✔ Processed 101225/202599 images
#    ✔ Processed 101250/202599 images
#    ✔ Processed 101275/202599 images
#    ✔ Processed 101300/202599 images
#    ✔ Processed 101325/202599 images
#    ✔ Processed 101350/202599 images
#    ✔ Processed 101375/202599 images
#    ✔ Processed 101400/202599 images
#    ✔ Processed 101425/202599 images
#    ✔ Processed 101450/202599 images
#    ✔ Processed 101475/202599 images
#    ✔ Processed 101500/202599 images
#    ✔ Processed 101525/202599 images
#    ✔ Processed 101550/202599 images
#    ✔ Processed 101575/202599 images
#    ✔ Processed 101600/202599 images
#    ✔ Processed 101625/202599 images
#    ✔ Processed 101650/202599 images
#    ✔ Processed 101675/202599 images
#    ✔ Processed 101700/202599 images
#    ✔ Processed 101725/202599 images
#    ✔ Processed 101750/202599 images
#    ✔ Processed 101775/202599 images
#    ✔ Processed 101800/202599 images
#    ✔ Processed 101825/202599 images
#    ✔ Processed 101850/202599 images
#    ✔ Processed 101875/202599 images
#    ✔ Processed 101900/202599 images
#    ✔ Processed 101925/202599 images
#    ✔ Processed 101950/202599 images
#    ✔ Processed 101975/202599 images
#    ✔ Processed 102000/202599 images
#    ✔ Processed 102025/202599 images
#    ✔ Processed 102050/202599 images
#    ✔ Processed 102075/202599 images
#    ✔ Processed 102100/202599 images
#    ✔ Processed 102125/202599 images
#    ✔ Processed 102150/202599 images
#    ✔ Processed 102175/202599 images
#    ✔ Processed 102200/202599 images
#    ✔ Processed 102225/202599 images
#    ✔ Processed 102250/202599 images
#    ✔ Processed 102275/202599 images
#    ✔ Processed 102300/202599 images
#    ✔ Processed 102325/202599 images
#    ✔ Processed 102350/202599 images
#    ✔ Processed 102375/202599 images
#    ✔ Processed 102400/202599 images
#    ✔ Processed 102425/202599 images
#    ✔ Processed 102450/202599 images
#    ✔ Processed 102475/202599 images
#    ✔ Processed 102500/202599 images
#    ✔ Processed 102525/202599 images
#    ✔ Processed 102550/202599 images
#    ✔ Processed 102575/202599 images
#    ✔ Processed 102600/202599 images
#    ✔ Processed 102625/202599 images
#    ✔ Processed 102650/202599 images
#    ✔ Processed 102675/202599 images
#    ✔ Processed 102700/202599 images
#    ✔ Processed 102725/202599 images
#    ✔ Processed 102750/202599 images
#    ✔ Processed 102775/202599 images
#    ✔ Processed 102800/202599 images
#    ✔ Processed 102825/202599 images
#    ✔ Processed 102850/202599 images
#    ✔ Processed 102875/202599 images
#    ✔ Processed 102900/202599 images
#    ✔ Processed 102925/202599 images
#    ✔ Processed 102950/202599 images
#    ✔ Processed 102975/202599 images
#    ✔ Processed 103000/202599 images
#    ✔ Processed 103025/202599 images
#    ✔ Processed 103050/202599 images
#    ✔ Processed 103075/202599 images
#    ✔ Processed 103100/202599 images
#    ✔ Processed 103125/202599 images
#    ✔ Processed 103150/202599 images
#    ✔ Processed 103175/202599 images
#    ✔ Processed 103200/202599 images
#    ✔ Processed 103225/202599 images
#    ✔ Processed 103250/202599 images
#    ✔ Processed 103275/202599 images
#    ✔ Processed 103300/202599 images
#    ✔ Processed 103325/202599 images
#    ✔ Processed 103350/202599 images
#    ✔ Processed 103375/202599 images
#    ✔ Processed 103400/202599 images
#    ✔ Processed 103425/202599 images
#    ✔ Processed 103450/202599 images
#    ✔ Processed 103475/202599 images
#    ✔ Processed 103500/202599 images
#    ✔ Processed 103525/202599 images
#    ✔ Processed 103550/202599 images
#    ✔ Processed 103575/202599 images
#    ✔ Processed 103600/202599 images
#    ✔ Processed 103625/202599 images
#    ✔ Processed 103650/202599 images
#    ✔ Processed 103675/202599 images
#    ✔ Processed 103700/202599 images
#    ✔ Processed 103725/202599 images
#    ✔ Processed 103750/202599 images
#    ✔ Processed 103775/202599 images
#    ✔ Processed 103800/202599 images
#    ✔ Processed 103825/202599 images
#    ✔ Processed 103850/202599 images
#    ✔ Processed 103875/202599 images
#    ✔ Processed 103900/202599 images
#    ✔ Processed 103925/202599 images
#    ✔ Processed 103950/202599 images
#    ✔ Processed 103975/202599 images
#    ✔ Processed 104000/202599 images
#    ✔ Processed 104025/202599 images
#    ✔ Processed 104050/202599 images
#    ✔ Processed 104075/202599 images
#    ✔ Processed 104100/202599 images
#    ✔ Processed 104125/202599 images
#    ✔ Processed 104150/202599 images
#    ✔ Processed 104175/202599 images
#    ✔ Processed 104200/202599 images
#    ✔ Processed 104225/202599 images
#    ✔ Processed 104250/202599 images
#    ✔ Processed 104275/202599 images
#    ✔ Processed 104300/202599 images
#    ✔ Processed 104325/202599 images
#    ✔ Processed 104350/202599 images
#    ✔ Processed 104375/202599 images
#    ✔ Processed 104400/202599 images
#    ✔ Processed 104425/202599 images
#    ✔ Processed 104450/202599 images
#    ✔ Processed 104475/202599 images
#    ✔ Processed 104500/202599 images
#    ✔ Processed 104525/202599 images
#    ✔ Processed 104550/202599 images
#    ✔ Processed 104575/202599 images
#    ✔ Processed 104600/202599 images
#    ✔ Processed 104625/202599 images
#    ✔ Processed 104650/202599 images
#    ✔ Processed 104675/202599 images
#    ✔ Processed 104700/202599 images
#    ✔ Processed 104725/202599 images
#    ✔ Processed 104750/202599 images
#    ✔ Processed 104775/202599 images
#    ✔ Processed 104800/202599 images
#    ✔ Processed 104825/202599 images
#    ✔ Processed 104850/202599 images
#    ✔ Processed 104875/202599 images
#    ✔ Processed 104900/202599 images
#    ✔ Processed 104925/202599 images
#    ✔ Processed 104950/202599 images
#    ✔ Processed 104975/202599 images
#    ✔ Processed 105000/202599 images
#    ✔ Processed 105025/202599 images
#    ✔ Processed 105050/202599 images
#    ✔ Processed 105075/202599 images
#    ✔ Processed 105100/202599 images
#    ✔ Processed 105125/202599 images
#    ✔ Processed 105150/202599 images
#    ✔ Processed 105175/202599 images
#    ✔ Processed 105200/202599 images
#    ✔ Processed 105225/202599 images
#    ✔ Processed 105250/202599 images
#    ✔ Processed 105275/202599 images
#    ✔ Processed 105300/202599 images
#    ✔ Processed 105325/202599 images
#    ✔ Processed 105350/202599 images
#    ✔ Processed 105375/202599 images
#    ✔ Processed 105400/202599 images
#    ✔ Processed 105425/202599 images
#    ✔ Processed 105450/202599 images
#    ✔ Processed 105475/202599 images
#    ✔ Processed 105500/202599 images
#    ✔ Processed 105525/202599 images
#    ✔ Processed 105550/202599 images
#    ✔ Processed 105575/202599 images
#    ✔ Processed 105600/202599 images
#    ✔ Processed 105625/202599 images
#    ✔ Processed 105650/202599 images
#    ✔ Processed 105675/202599 images
#    ✔ Processed 105700/202599 images
#    ✔ Processed 105725/202599 images
#    ✔ Processed 105750/202599 images
#    ✔ Processed 105775/202599 images
#    ✔ Processed 105800/202599 images
#    ✔ Processed 105825/202599 images
#    ✔ Processed 105850/202599 images
#    ✔ Processed 105875/202599 images
#    ✔ Processed 105900/202599 images
#    ✔ Processed 105925/202599 images
#    ✔ Processed 105950/202599 images
#    ✔ Processed 105975/202599 images
#    ✔ Processed 106000/202599 images
#    ✔ Processed 106025/202599 images
#    ✔ Processed 106050/202599 images
#    ✔ Processed 106075/202599 images
#    ✔ Processed 106100/202599 images
#    ✔ Processed 106125/202599 images
#    ✔ Processed 106150/202599 images
#    ✔ Processed 106175/202599 images
#    ✔ Processed 106200/202599 images
#    ✔ Processed 106225/202599 images
#    ✔ Processed 106250/202599 images
#    ✔ Processed 106275/202599 images
#    ✔ Processed 106300/202599 images
#    ✔ Processed 106325/202599 images
#    ✔ Processed 106350/202599 images
#    ✔ Processed 106375/202599 images
#    ✔ Processed 106400/202599 images
#    ✔ Processed 106425/202599 images
#    ✔ Processed 106450/202599 images
#    ✔ Processed 106475/202599 images
#    ✔ Processed 106500/202599 images
#    ✔ Processed 106525/202599 images
#    ✔ Processed 106550/202599 images
#    ✔ Processed 106575/202599 images
#    ✔ Processed 106600/202599 images
#    ✔ Processed 106625/202599 images
#    ✔ Processed 106650/202599 images
#    ✔ Processed 106675/202599 images
#    ✔ Processed 106700/202599 images
#    ✔ Processed 106725/202599 images
#    ✔ Processed 106750/202599 images
#    ✔ Processed 106775/202599 images
#    ✔ Processed 106800/202599 images
#    ✔ Processed 106825/202599 images
#    ✔ Processed 106850/202599 images
#    ✔ Processed 106875/202599 images
#    ✔ Processed 106900/202599 images
#    ✔ Processed 106925/202599 images
#    ✔ Processed 106950/202599 images
#    ✔ Processed 106975/202599 images
#    ✔ Processed 107000/202599 images
#    ✔ Processed 107025/202599 images
#    ✔ Processed 107050/202599 images
#    ✔ Processed 107075/202599 images
#    ✔ Processed 107100/202599 images
#    ✔ Processed 107125/202599 images
#    ✔ Processed 107150/202599 images
#    ✔ Processed 107175/202599 images
#    ✔ Processed 107200/202599 images
#    ✔ Processed 107225/202599 images
#    ✔ Processed 107250/202599 images
#    ✔ Processed 107275/202599 images
#    ✔ Processed 107300/202599 images
#    ✔ Processed 107325/202599 images
#    ✔ Processed 107350/202599 images
#    ✔ Processed 107375/202599 images
#    ✔ Processed 107400/202599 images
#    ✔ Processed 107425/202599 images
#    ✔ Processed 107450/202599 images
#    ✔ Processed 107475/202599 images
#    ✔ Processed 107500/202599 images
#    ✔ Processed 107525/202599 images
#    ✔ Processed 107550/202599 images
#    ✔ Processed 107575/202599 images
#    ✔ Processed 107600/202599 images
#    ✔ Processed 107625/202599 images
#    ✔ Processed 107650/202599 images
#    ✔ Processed 107675/202599 images
#    ✔ Processed 107700/202599 images
#    ✔ Processed 107725/202599 images
#    ✔ Processed 107750/202599 images
#    ✔ Processed 107775/202599 images
#    ✔ Processed 107800/202599 images
#    ✔ Processed 107825/202599 images
#    ✔ Processed 107850/202599 images
#    ✔ Processed 107875/202599 images
#    ✔ Processed 107900/202599 images
#    ✔ Processed 107925/202599 images
#    ✔ Processed 107950/202599 images
#    ✔ Processed 107975/202599 images
#    ✔ Processed 108000/202599 images
#    ✔ Processed 108025/202599 images
#    ✔ Processed 108050/202599 images
#    ✔ Processed 108075/202599 images
#    ✔ Processed 108100/202599 images
#    ✔ Processed 108125/202599 images
#    ✔ Processed 108150/202599 images
#    ✔ Processed 108175/202599 images
#    ✔ Processed 108200/202599 images
#    ✔ Processed 108225/202599 images
#    ✔ Processed 108250/202599 images
#    ✔ Processed 108275/202599 images
#    ✔ Processed 108300/202599 images
#    ✔ Processed 108325/202599 images
#    ✔ Processed 108350/202599 images
#    ✔ Processed 108375/202599 images
#    ✔ Processed 108400/202599 images
#    ✔ Processed 108425/202599 images
#    ✔ Processed 108450/202599 images
#    ✔ Processed 108475/202599 images
#    ✔ Processed 108500/202599 images
#    ✔ Processed 108525/202599 images
#    ✔ Processed 108550/202599 images
#    ✔ Processed 108575/202599 images
#    ✔ Processed 108600/202599 images
#    ✔ Processed 108625/202599 images
#    ✔ Processed 108650/202599 images
#    ✔ Processed 108675/202599 images
#    ✔ Processed 108700/202599 images
#    ✔ Processed 108725/202599 images
#    ✔ Processed 108750/202599 images
#    ✔ Processed 108775/202599 images
#    ✔ Processed 108800/202599 images
#    ✔ Processed 108825/202599 images
#    ✔ Processed 108850/202599 images
#    ✔ Processed 108875/202599 images
#    ✔ Processed 108900/202599 images
#    ✔ Processed 108925/202599 images
#    ✔ Processed 108950/202599 images
#    ✔ Processed 108975/202599 images
#    ✔ Processed 109000/202599 images
#    ✔ Processed 109025/202599 images
#    ✔ Processed 109050/202599 images
#    ✔ Processed 109075/202599 images
#    ✔ Processed 109100/202599 images
#    ✔ Processed 109125/202599 images
#    ✔ Processed 109150/202599 images
#    ✔ Processed 109175/202599 images
#    ✔ Processed 109200/202599 images
#    ✔ Processed 109225/202599 images
#    ✔ Processed 109250/202599 images
#    ✔ Processed 109275/202599 images
#    ✔ Processed 109300/202599 images
#    ✔ Processed 109325/202599 images
#    ✔ Processed 109350/202599 images
#    ✔ Processed 109375/202599 images
#    ✔ Processed 109400/202599 images
#    ✔ Processed 109425/202599 images
#    ✔ Processed 109450/202599 images
#    ✔ Processed 109475/202599 images
#    ✔ Processed 109500/202599 images
#    ✔ Processed 109525/202599 images
#    ✔ Processed 109550/202599 images
#    ✔ Processed 109575/202599 images
#    ✔ Processed 109600/202599 images
#    ✔ Processed 109625/202599 images
#    ✔ Processed 109650/202599 images
#    ✔ Processed 109675/202599 images
#    ✔ Processed 109700/202599 images
#    ✔ Processed 109725/202599 images
#    ✔ Processed 109750/202599 images
#    ✔ Processed 109775/202599 images
#    ✔ Processed 109800/202599 images
#    ✔ Processed 109825/202599 images
#    ✔ Processed 109850/202599 images
#    ✔ Processed 109875/202599 images
#    ✔ Processed 109900/202599 images
#    ✔ Processed 109925/202599 images
#    ✔ Processed 109950/202599 images
#    ✔ Processed 109975/202599 images
#    ✔ Processed 110000/202599 images
#    ✔ Processed 110025/202599 images
#    ✔ Processed 110050/202599 images
#    ✔ Processed 110075/202599 images
#    ✔ Processed 110100/202599 images
#    ✔ Processed 110125/202599 images
#    ✔ Processed 110150/202599 images
#    ✔ Processed 110175/202599 images
#    ✔ Processed 110200/202599 images
#    ✔ Processed 110225/202599 images
#    ✔ Processed 110250/202599 images
#    ✔ Processed 110275/202599 images
#    ✔ Processed 110300/202599 images
#    ✔ Processed 110325/202599 images
#    ✔ Processed 110350/202599 images
#    ✔ Processed 110375/202599 images
#    ✔ Processed 110400/202599 images
#    ✔ Processed 110425/202599 images
#    ✔ Processed 110450/202599 images
#    ✔ Processed 110475/202599 images
#    ✔ Processed 110500/202599 images
#    ✔ Processed 110525/202599 images
#    ✔ Processed 110550/202599 images
#    ✔ Processed 110575/202599 images
#    ✔ Processed 110600/202599 images
#    ✔ Processed 110625/202599 images
#    ✔ Processed 110650/202599 images
#    ✔ Processed 110675/202599 images
#    ✔ Processed 110700/202599 images
#    ✔ Processed 110725/202599 images
#    ✔ Processed 110750/202599 images
#    ✔ Processed 110775/202599 images
#    ✔ Processed 110800/202599 images
#    ✔ Processed 110825/202599 images
#    ✔ Processed 110850/202599 images
#    ✔ Processed 110875/202599 images
#    ✔ Processed 110900/202599 images
#    ✔ Processed 110925/202599 images
#    ✔ Processed 110950/202599 images
#    ✔ Processed 110975/202599 images
#    ✔ Processed 111000/202599 images
#    ✔ Processed 111025/202599 images
#    ✔ Processed 111050/202599 images
#    ✔ Processed 111075/202599 images
#    ✔ Processed 111100/202599 images
#    ✔ Processed 111125/202599 images
#    ✔ Processed 111150/202599 images
#    ✔ Processed 111175/202599 images
#    ✔ Processed 111200/202599 images
#    ✔ Processed 111225/202599 images
#    ✔ Processed 111250/202599 images
#    ✔ Processed 111275/202599 images
#    ✔ Processed 111300/202599 images
#    ✔ Processed 111325/202599 images
#    ✔ Processed 111350/202599 images
#    ✔ Processed 111375/202599 images
#    ✔ Processed 111400/202599 images
#    ✔ Processed 111425/202599 images
#    ✔ Processed 111450/202599 images
#    ✔ Processed 111475/202599 images
#    ✔ Processed 111500/202599 images
#    ✔ Processed 111525/202599 images
#    ✔ Processed 111550/202599 images
#    ✔ Processed 111575/202599 images
#    ✔ Processed 111600/202599 images
#    ✔ Processed 111625/202599 images
#    ✔ Processed 111650/202599 images
#    ✔ Processed 111675/202599 images
#    ✔ Processed 111700/202599 images
#    ✔ Processed 111725/202599 images
# ...
#    ✔ Processed 192000/202599 images
#    ✔ Processed 192025/202599 images
#    ✔ Processed 192050/202599 images
#    ✔ Processed 192075/202599 images
#    ✔ Processed 192100/202599 images
#    ✔ Processed 192125/202599 images
#    ✔ Processed 192150/202599 images
#    ✔ Processed 192175/202599 images
#    ✔ Processed 192200/202599 images
#    ✔ Processed 192225/202599 images
#    ✔ Processed 192250/202599 images
#    ✔ Processed 192275/202599 images
#    ✔ Processed 192300/202599 images
#    ✔ Processed 192325/202599 images
#    ✔ Processed 192350/202599 images
#    ✔ Processed 192375/202599 images
#    ✔ Processed 192400/202599 images
#    ✔ Processed 192425/202599 images
#    ✔ Processed 192450/202599 images
#    ✔ Processed 192475/202599 images
#    ✔ Processed 192500/202599 images
#    ✔ Processed 192525/202599 images
#    ✔ Processed 192550/202599 images
#    ✔ Processed 192575/202599 images
#    ✔ Processed 192600/202599 images
#    ✔ Processed 192625/202599 images
#    ✔ Processed 192650/202599 images
#    ✔ Processed 192675/202599 images
#    ✔ Processed 192700/202599 images
#    ✔ Processed 192725/202599 images
#    ✔ Processed 192750/202599 images
#    ✔ Processed 192775/202599 images
#    ✔ Processed 192800/202599 images
#    ✔ Processed 192825/202599 images
#    ✔ Processed 192850/202599 images
#    ✔ Processed 192875/202599 images
#    ✔ Processed 192900/202599 images
#    ✔ Processed 192925/202599 images
#    ✔ Processed 192950/202599 images
#    ✔ Processed 192975/202599 images
#    ✔ Processed 193000/202599 images
#    ✔ Processed 193025/202599 images
#    ✔ Processed 193050/202599 images
#    ✔ Processed 193075/202599 images
#    ✔ Processed 193100/202599 images
#    ✔ Processed 193125/202599 images
#    ✔ Processed 193150/202599 images
#    ✔ Processed 193175/202599 images
#    ✔ Processed 193200/202599 images
#    ✔ Processed 193225/202599 images
#    ✔ Processed 193250/202599 images
#    ✔ Processed 193275/202599 images
#    ✔ Processed 193300/202599 images
#    ✔ Processed 193325/202599 images
#    ✔ Processed 193350/202599 images
#    ✔ Processed 193375/202599 images
#    ✔ Processed 193400/202599 images
#    ✔ Processed 193425/202599 images
#    ✔ Processed 193450/202599 images
#    ✔ Processed 193475/202599 images
#    ✔ Processed 193500/202599 images
#    ✔ Processed 193525/202599 images
#    ✔ Processed 193550/202599 images
#    ✔ Processed 193575/202599 images
#    ✔ Processed 193600/202599 images
#    ✔ Processed 193625/202599 images
#    ✔ Processed 193650/202599 images
#    ✔ Processed 193675/202599 images
#    ✔ Processed 193700/202599 images
#    ✔ Processed 193725/202599 images
#    ✔ Processed 193750/202599 images
#    ✔ Processed 193775/202599 images
#    ✔ Processed 193800/202599 images
#    ✔ Processed 193825/202599 images
#    ✔ Processed 193850/202599 images
#    ✔ Processed 193875/202599 images
#    ✔ Processed 193900/202599 images
#    ✔ Processed 193925/202599 images
#    ✔ Processed 193950/202599 images
#    ✔ Processed 193975/202599 images
#    ✔ Processed 194000/202599 images
#    ✔ Processed 194025/202599 images
#    ✔ Processed 194050/202599 images
#    ✔ Processed 194075/202599 images
#    ✔ Processed 194100/202599 images
#    ✔ Processed 194125/202599 images
#    ✔ Processed 194150/202599 images
#    ✔ Processed 194175/202599 images
#    ✔ Processed 194200/202599 images
#    ✔ Processed 194225/202599 images
#    ✔ Processed 194250/202599 images
#    ✔ Processed 194275/202599 images
#    ✔ Processed 194300/202599 images
#    ✔ Processed 194325/202599 images
#    ✔ Processed 194350/202599 images
#    ✔ Processed 194375/202599 images
#    ✔ Processed 194400/202599 images
#    ✔ Processed 194425/202599 images
#    ✔ Processed 194450/202599 images
#    ✔ Processed 194475/202599 images
#    ✔ Processed 194500/202599 images
#    ✔ Processed 194525/202599 images
#    ✔ Processed 194550/202599 images
#    ✔ Processed 194575/202599 images
#    ✔ Processed 194600/202599 images
#    ✔ Processed 194625/202599 images
#    ✔ Processed 194650/202599 images
#    ✔ Processed 194675/202599 images
#    ✔ Processed 194700/202599 images
#    ✔ Processed 194725/202599 images
#    ✔ Processed 194750/202599 images
#    ✔ Processed 194775/202599 images
#    ✔ Processed 194800/202599 images
#    ✔ Processed 194825/202599 images
#    ✔ Processed 194850/202599 images
#    ✔ Processed 194875/202599 images
#    ✔ Processed 194900/202599 images
#    ✔ Processed 194925/202599 images
#    ✔ Processed 194950/202599 images
#    ✔ Processed 194975/202599 images
#    ✔ Processed 195000/202599 images
#    ✔ Processed 195025/202599 images
#    ✔ Processed 195050/202599 images
#    ✔ Processed 195075/202599 images
#    ✔ Processed 195100/202599 images
#    ✔ Processed 195125/202599 images
#    ✔ Processed 195150/202599 images
#    ✔ Processed 195175/202599 images
#    ✔ Processed 195200/202599 images
#    ✔ Processed 195225/202599 images
#    ✔ Processed 195250/202599 images
#    ✔ Processed 195275/202599 images
#    ✔ Processed 195300/202599 images
#    ✔ Processed 195325/202599 images
#    ✔ Processed 195350/202599 images
#    ✔ Processed 195375/202599 images
#    ✔ Processed 195400/202599 images
#    ✔ Processed 195425/202599 images
#    ✔ Processed 195450/202599 images
#    ✔ Processed 195475/202599 images
#    ✔ Processed 195500/202599 images
#    ✔ Processed 195525/202599 images
#    ✔ Processed 195550/202599 images
#    ✔ Processed 195575/202599 images
#    ✔ Processed 195600/202599 images
#    ✔ Processed 195625/202599 images
#    ✔ Processed 195650/202599 images
#    ✔ Processed 195675/202599 images
#    ✔ Processed 195700/202599 images
#    ✔ Processed 195725/202599 images
#    ✔ Processed 195750/202599 images
#    ✔ Processed 195775/202599 images
#    ✔ Processed 195800/202599 images
#    ✔ Processed 195825/202599 images
#    ✔ Processed 195850/202599 images
#    ✔ Processed 195875/202599 images
#    ✔ Processed 195900/202599 images
#    ✔ Processed 195925/202599 images
#    ✔ Processed 195950/202599 images
#    ✔ Processed 195975/202599 images
#    ✔ Processed 196000/202599 images
#    ✔ Processed 196025/202599 images
#    ✔ Processed 196050/202599 images
#    ✔ Processed 196075/202599 images
#    ✔ Processed 196100/202599 images
#    ✔ Processed 196125/202599 images
#    ✔ Processed 196150/202599 images
#    ✔ Processed 196175/202599 images
#    ✔ Processed 196200/202599 images
#    ✔ Processed 196225/202599 images
#    ✔ Processed 196250/202599 images
#    ✔ Processed 196275/202599 images
#    ✔ Processed 196300/202599 images
#    ✔ Processed 196325/202599 images
#    ✔ Processed 196350/202599 images
#    ✔ Processed 196375/202599 images
#    ✔ Processed 196400/202599 images
#    ✔ Processed 196425/202599 images
#    ✔ Processed 196450/202599 images
#    ✔ Processed 196475/202599 images
#    ✔ Processed 196500/202599 images
#    ✔ Processed 196525/202599 images
#    ✔ Processed 196550/202599 images
#    ✔ Processed 196575/202599 images
#    ✔ Processed 196600/202599 images
#    ✔ Processed 196625/202599 images
#    ✔ Processed 196650/202599 images
#    ✔ Processed 196675/202599 images
#    ✔ Processed 196700/202599 images
#    ✔ Processed 196725/202599 images
#    ✔ Processed 196750/202599 images
#    ✔ Processed 196775/202599 images
#    ✔ Processed 196800/202599 images
#    ✔ Processed 196825/202599 images
#    ✔ Processed 196850/202599 images
#    ✔ Processed 196875/202599 images
#    ✔ Processed 196900/202599 images
#    ✔ Processed 196925/202599 images
#    ✔ Processed 196950/202599 images
#    ✔ Processed 196975/202599 images
#    ✔ Processed 197000/202599 images
#    ✔ Processed 197025/202599 images
#    ✔ Processed 197050/202599 images
#    ✔ Processed 197075/202599 images
#    ✔ Processed 197100/202599 images
#    ✔ Processed 197125/202599 images
#    ✔ Processed 197150/202599 images
#    ✔ Processed 197175/202599 images
#    ✔ Processed 197200/202599 images
#    ✔ Processed 197225/202599 images
#    ✔ Processed 197250/202599 images
#    ✔ Processed 197275/202599 images
#    ✔ Processed 197300/202599 images
#    ✔ Processed 197325/202599 images
#    ✔ Processed 197350/202599 images
#    ✔ Processed 197375/202599 images
#    ✔ Processed 197400/202599 images
#    ✔ Processed 197425/202599 images
#    ✔ Processed 197450/202599 images
#    ✔ Processed 197475/202599 images
#    ✔ Processed 197500/202599 images
#    ✔ Processed 197525/202599 images
#    ✔ Processed 197550/202599 images
#    ✔ Processed 197575/202599 images
#    ✔ Processed 197600/202599 images
#    ✔ Processed 197625/202599 images
#    ✔ Processed 197650/202599 images
#    ✔ Processed 197675/202599 images
#    ✔ Processed 197700/202599 images
#    ✔ Processed 197725/202599 images
#    ✔ Processed 197750/202599 images
#    ✔ Processed 197775/202599 images
#    ✔ Processed 197800/202599 images
#    ✔ Processed 197825/202599 images
#    ✔ Processed 197850/202599 images
#    ✔ Processed 197875/202599 images
#    ✔ Processed 197900/202599 images
#    ✔ Processed 197925/202599 images
#    ✔ Processed 197950/202599 images
#    ✔ Processed 197975/202599 images
#    ✔ Processed 198000/202599 images
#    ✔ Processed 198025/202599 images
#    ✔ Processed 198050/202599 images
#    ✔ Processed 198075/202599 images
#    ✔ Processed 198100/202599 images
#    ✔ Processed 198125/202599 images
#    ✔ Processed 198150/202599 images
#    ✔ Processed 198175/202599 images
#    ✔ Processed 198200/202599 images
#    ✔ Processed 198225/202599 images
#    ✔ Processed 198250/202599 images
#    ✔ Processed 198275/202599 images
#    ✔ Processed 198300/202599 images
#    ✔ Processed 198325/202599 images
#    ✔ Processed 198350/202599 images
#    ✔ Processed 198375/202599 images
#    ✔ Processed 198400/202599 images
#    ✔ Processed 198425/202599 images
#    ✔ Processed 198450/202599 images
#    ✔ Processed 198475/202599 images
#    ✔ Processed 198500/202599 images
#    ✔ Processed 198525/202599 images
#    ✔ Processed 198550/202599 images
#    ✔ Processed 198575/202599 images
#    ✔ Processed 198600/202599 images
#    ✔ Processed 198625/202599 images
#    ✔ Processed 198650/202599 images
#    ✔ Processed 198675/202599 images
#    ✔ Processed 198700/202599 images
#    ✔ Processed 198725/202599 images
#    ✔ Processed 198750/202599 images
#    ✔ Processed 198775/202599 images
#    ✔ Processed 198800/202599 images
#    ✔ Processed 198825/202599 images
#    ✔ Processed 198850/202599 images
#    ✔ Processed 198875/202599 images
#    ✔ Processed 198900/202599 images
#    ✔ Processed 198925/202599 images
#    ✔ Processed 198950/202599 images
#    ✔ Processed 198975/202599 images
#    ✔ Processed 199000/202599 images
#    ✔ Processed 199025/202599 images
#    ✔ Processed 199050/202599 images
#    ✔ Processed 199075/202599 images
#    ✔ Processed 199100/202599 images
#    ✔ Processed 199125/202599 images
#    ✔ Processed 199150/202599 images
#    ✔ Processed 199175/202599 images
#    ✔ Processed 199200/202599 images
#    ✔ Processed 199225/202599 images
#    ✔ Processed 199250/202599 images
#    ✔ Processed 199275/202599 images
#    ✔ Processed 199300/202599 images
#    ✔ Processed 199325/202599 images
#    ✔ Processed 199350/202599 images
#    ✔ Processed 199375/202599 images
#    ✔ Processed 199400/202599 images
#    ✔ Processed 199425/202599 images
#    ✔ Processed 199450/202599 images
#    ✔ Processed 199475/202599 images
#    ✔ Processed 199500/202599 images
#    ✔ Processed 199525/202599 images
#    ✔ Processed 199550/202599 images
#    ✔ Processed 199575/202599 images
#    ✔ Processed 199600/202599 images
#    ✔ Processed 199625/202599 images
#    ✔ Processed 199650/202599 images
#    ✔ Processed 199675/202599 images
#    ✔ Processed 199700/202599 images
#    ✔ Processed 199725/202599 images
#    ✔ Processed 199750/202599 images
#    ✔ Processed 199775/202599 images
#    ✔ Processed 199800/202599 images
#    ✔ Processed 199825/202599 images
#    ✔ Processed 199850/202599 images
#    ✔ Processed 199875/202599 images
#    ✔ Processed 199900/202599 images
#    ✔ Processed 199925/202599 images
#    ✔ Processed 199950/202599 images
#    ✔ Processed 199975/202599 images
#    ✔ Processed 200000/202599 images
#    ✔ Processed 200025/202599 images
#    ✔ Processed 200050/202599 images
#    ✔ Processed 200075/202599 images
#    ✔ Processed 200100/202599 images
#    ✔ Processed 200125/202599 images
#    ✔ Processed 200150/202599 images
#    ✔ Processed 200175/202599 images
#    ✔ Processed 200200/202599 images
#    ✔ Processed 200225/202599 images
#    ✔ Processed 200250/202599 images
#    ✔ Processed 200275/202599 images
#    ✔ Processed 200300/202599 images
#    ✔ Processed 200325/202599 images
#    ✔ Processed 200350/202599 images
#    ✔ Processed 200375/202599 images
#    ✔ Processed 200400/202599 images
#    ✔ Processed 200425/202599 images
#    ✔ Processed 200450/202599 images
#    ✔ Processed 200475/202599 images
#    ✔ Processed 200500/202599 images
#    ✔ Processed 200525/202599 images
#    ✔ Processed 200550/202599 images
#    ✔ Processed 200575/202599 images
#    ✔ Processed 200600/202599 images
#    ✔ Processed 200625/202599 images
#    ✔ Processed 200650/202599 images
#    ✔ Processed 200675/202599 images
#    ✔ Processed 200700/202599 images
#    ✔ Processed 200725/202599 images
#    ✔ Processed 200750/202599 images
#    ✔ Processed 200775/202599 images
#    ✔ Processed 200800/202599 images
#    ✔ Processed 200825/202599 images
#    ✔ Processed 200850/202599 images
#    ✔ Processed 200875/202599 images
#    ✔ Processed 200900/202599 images
#    ✔ Processed 200925/202599 images
#    ✔ Processed 200950/202599 images
#    ✔ Processed 200975/202599 images
#    ✔ Processed 201000/202599 images
#    ✔ Processed 201025/202599 images
#    ✔ Processed 201050/202599 images
#    ✔ Processed 201075/202599 images
#    ✔ Processed 201100/202599 images
#    ✔ Processed 201125/202599 images
#    ✔ Processed 201150/202599 images
#    ✔ Processed 201175/202599 images
#    ✔ Processed 201200/202599 images
#    ✔ Processed 201225/202599 images
#    ✔ Processed 201250/202599 images
#    ✔ Processed 201275/202599 images
#    ✔ Processed 201300/202599 images
#    ✔ Processed 201325/202599 images
#    ✔ Processed 201350/202599 images
#    ✔ Processed 201375/202599 images
#    ✔ Processed 201400/202599 images
#    ✔ Processed 201425/202599 images
#    ✔ Processed 201450/202599 images
#    ✔ Processed 201475/202599 images
#    ✔ Processed 201500/202599 images
#    ✔ Processed 201525/202599 images
#    ✔ Processed 201550/202599 images
#    ✔ Processed 201575/202599 images
#    ✔ Processed 201600/202599 images
#    ✔ Processed 201625/202599 images
#    ✔ Processed 201650/202599 images
#    ✔ Processed 201675/202599 images
#    ✔ Processed 201700/202599 images
#    ✔ Processed 201725/202599 images
#    ✔ Processed 201750/202599 images
#    ✔ Processed 201775/202599 images
#    ✔ Processed 201800/202599 images
#    ✔ Processed 201825/202599 images
#    ✔ Processed 201850/202599 images
#    ✔ Processed 201875/202599 images
#    ✔ Processed 201900/202599 images
#    ✔ Processed 201925/202599 images
#    ✔ Processed 201950/202599 images
#    ✔ Processed 201975/202599 images
#    ✔ Processed 202000/202599 images
#    ✔ Processed 202025/202599 images
#    ✔ Processed 202050/202599 images
#    ✔ Processed 202075/202599 images
#    ✔ Processed 202100/202599 images
#    ✔ Processed 202125/202599 images
#    ✔ Processed 202150/202599 images
#    ✔ Processed 202175/202599 images
#    ✔ Processed 202200/202599 images
#    ✔ Processed 202225/202599 images
#    ✔ Processed 202250/202599 images
#    ✔ Processed 202275/202599 images
#    ✔ Processed 202300/202599 images
#    ✔ Processed 202325/202599 images
#    ✔ Processed 202350/202599 images
#    ✔ Processed 202375/202599 images
#    ✔ Processed 202400/202599 images
#    ✔ Processed 202425/202599 images
#    ✔ Processed 202450/202599 images
#    ✔ Processed 202475/202599 images
#    ✔ Processed 202500/202599 images
#    ✔ Processed 202525/202599 images
#    ✔ Processed 202550/202599 images
#    ✔ Processed 202575/202599 images
#    ✔ Processed 202599/202599 images
#
#  EMBEDDINGS SAVED!
#    • File: /content/celeba_arcface_512d_embeddings.npz
#    • Num embeddings: 202599
#    • Embedding dimension: 512
#
# ============================================================
# === DOWNLOADING EMBEDDING FILES TO YOUR COMPUTER ===
# ============================================================
# 📥 LFW 512-D embeddings: lfw_arcface_512d_embeddings_20251129_001200.npz
# 📥 CelebA 512-D embeddings: celeba_arcface_512d_embeddings_20251129_001200.npz
#
# 🎉 DONE! You now have:
#    • lfw_arcface_512d_embeddings_YYYYMMDD_HHMMSS.npz
#    • celeba_arcface_512d_embeddings_YYYYMMDD_HHMMSS.npz
# Each file contains:
#    • 'filenames'  → image file names
#    • 'embeddings' → 512-D ArcFace feature vectors
